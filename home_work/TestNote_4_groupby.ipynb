# %%
import pandas as pd

df = pd.read_csv('../data/data_sf.xls')

# %%
small_df = df[df.columns[1:8]]
small_df.head(10)
# Out:
#                 Name  Age Nationality                 Club      Value    Wage  \
# 0           L. Messi   31   Argentina         FC Barcelona  110500000  565000
# 1  Cristiano Ronaldo   33    Portugal             Juventus   77000000  405000
# 2          Neymar Jr   26      Brazil  Paris Saint-Germain  118500000  290000
# 3             De Gea   27       Spain    Manchester United   72000000  260000
# 4       K. De Bruyne   27     Belgium      Manchester City  102000000  355000
# 5          E. Hazard   27     Belgium              Chelsea   93000000  340000
# 6          L. Modrić   32     Croatia          Real Madrid   67000000  420000
# 7          L. Suárez   31     Uruguay         FC Barcelona   80000000  455000
# 8       Sergio Ramos   32       Spain          Real Madrid   51000000  380000
# 9           J. Oblak   25    Slovenia      Atlético Madrid   68000000   94000
#
#   Position
# 0       RF
# 1       ST
# 2       LW
# 3       GK
# 4      RCM
# 5       LF
# 6      RCM
# ...

# %%
s = small_df['Club'].value_counts()
s
# Out:
# V-Varen Nagasaki     30
# Shonan Bellmare      30
# De Graafschap        29
# Vissel Kobe          29
# FC Emmen             29
#                      ..
# Cruzeiro              8
# GD Chaves             7
# Dinamo Zagreb         7
# Vitória Guimarães     7
# Atlético Mineiro      6
# Name: Club, Length: 650, dtype: int64

# %%
s.index
# Out:
# Index(['V-Varen Nagasaki', 'Shonan Bellmare', 'De Graafschap', 'Vissel Kobe',
#        'FC Emmen', 'Padova', 'Sagan Tosu', 'Southend United', 'Exeter City',
#        'SV Meppen',
#        ...
#        'Kasimpaşa SK', 'OGC Nice', 'FC Metz', 'Dijon FCO', 'Olympiacos CFP',
#        'Cruzeiro', 'GD Chaves', 'Dinamo Zagreb', 'Vitória Guimarães',
#        'Atlético Mineiro'],
#       dtype='object', length=650)

# %%
print('самая часто встречающаяся страна', s.index[0])
print('число уникальных стран', len(s.index))
# Out:
# самая часто встречающаяся страна V-Varen Nagasaki
# число уникальных стран 650

# %%
print('можно получить значение по конкретной стране', s['Germany'])
# Out:
# 3

# %%
print('можно фильтровать по значениям:')
s.loc[s == s[-1]]
# Out:
# можно фильтровать по значениям:
# Atlético Mineiro    6
# Name: Club, dtype: int64

# %%
small_df['Nationality'].value_counts(normalize=True)
# Out:
# England      0.106071
# Germany      0.071257
# Spain        0.052028
# France       0.047608
# Argentina    0.044506
#                ...
# Mauritius    0.000078
# Qatar        0.000078
# St Lucia     0.000078
# Oman         0.000078
# Belize       0.000078
# Name: Nationality, Length: 156, dtype: float64

# %%
pos = small_df['Position'].value_counts(normalize=True)

# %%
pos.loc[pos > 0.1]
# Out:
# GK    0.127239
# ST    0.117237
# CB    0.108785
# Name: Position, dtype: float64

# %%
p = pos.loc[pos < 0.01]
p['RAM']
# Out:
# 0.00038768705900597036

# %%
small_df = df[df.columns[1:8]].head(25)
s = small_df['Age'].value_counts()
display(s)
# Out:
# 27    5
# 32    5
# 31    3
# 26    3
# 29    2
# 24    2
# 33    2
# 30    1
# 28    1
# 25    1
# Name: Age, dtype: int64

# %%
s = small_df['Wage'].value_counts(bins=4)
display(s)
# Out:
# (211750.0, 329500.0]     9
# (93528.999, 211750.0]    8
# (329500.0, 447250.0]     6
# (447250.0, 565000.0]     2
# Name: Wage, dtype: int64

# %%
s.index[-1]
# Out:
# Interval(447250.0, 565000.0, closed='right')

# %%
s.index[3].right
# Out:
# 565000.0

# %%
small_df[(small_df['Wage'] > s.index[2].left) & (small_df['Wage'] <= s.index[2].right)]
# Out:
#                  Name  Age Nationality             Club      Value    Wage  \
# 1   Cristiano Ronaldo   33    Portugal         Juventus   77000000  405000
# 4        K. De Bruyne   27     Belgium  Manchester City  102000000  355000
# 5           E. Hazard   27     Belgium          Chelsea   93000000  340000
# 6           L. Modrić   32     Croatia      Real Madrid   67000000  420000
# 8        Sergio Ramos   32       Spain      Real Madrid   51000000  380000
# 11           T. Kroos   28     Germany      Real Madrid   76500000  355000
#
#    Position
# 1        ST
# 4       RCM
# 5        LF
# 6       RCM
# 8       RCB
# 11      LCM

# %%
ac = df['FKAccuracy'].value_counts(bins=5)

# %%
display(ac)
# Out:
# (21.2, 39.4]     4859
# (39.4, 57.6]     3957
# (57.6, 75.8]     2108
# (2.908, 21.2]    1760
# (75.8, 94.0]      213
# Name: FKAccuracy, dtype: int64

# %%
small_df['Nationality'].unique()
# Out:
# array(['Argentina', 'Portugal', 'Brazil', 'Spain', 'Belgium', 'Croatia',
#        'Uruguay', 'Slovenia', 'Poland', 'Germany', 'France', 'England',
#        'Italy'], dtype=object)

# %%
len(small_df['Nationality'].unique())
# Out:
# 13

# %%
small_df['Nationality'].nunique()
# Out:
# 13

# %% [markdown]
# Можно конвертировать Series в DataFrame при помощи метода reset_index()

# %%
s = df['Position'].value_counts()
s_df = s.reset_index()
s_df
# Out:
#    index  Position
# 0     GK      1641
# 1     ST      1512
# 2     CB      1403
# 3     CM      1067
# 4     LB      1002
# 5     RB       948
# 6     RM       766
# 7     LM       728
# 8    CDM       691
# 9    CAM       633
# 10   RCB       418
# 11   LCB       409
# 12    LW       242
# 13   RCM       240
# 14    RW       237
# 15   LCM       233
# 16   LDM       148
# 17   RDM       138
# 18    LS       121
# 19    RS       114
# 20   RWB        70
# 21   LWB        60
# 22    CF        51
# 23    LF         8
# 24    RF         6
# 25   LAM         6
# 26   RAM         5

# %%
s_df.columns = ['Position', 'Position_count']
s_df
# Out:
#    Position  Position_count
# 0        GK            1641
# 1        ST            1512
# 2        CB            1403
# 3        CM            1067
# 4        LB            1002
# 5        RB             948
# 6        RM             766
# 7        LM             728
# 8       CDM             691
# 9       CAM             633
# 10      RCB             418
# 11      LCB             409
# 12       LW             242
# 13      RCM             240
# 14       RW             237
# 15      LCM             233
# 16      LDM             148
# 17      RDM             138
# 18       LS             121
# 19       RS             114
# 20      RWB              70
# 21      LWB              60
# 22       CF              51
# 23       LF               8
# 24       RF               6
# 25      LAM               6
# 26      RAM               5

# %%
small_df = df[df['Nationality'] == 'Spain']
small_df['Wage'].value_counts(bins=4, normalize=True)
# Out:
# (620.999, 95750.0]      0.970194
# (95750.0, 190500.0]     0.016393
# (190500.0, 285250.0]    0.008942
# (285250.0, 380000.0]    0.004471
# Name: Wage, dtype: float64

# %%
small_df = df[df['Club'] == 'Manchester United']
s = small_df['Nationality'].nunique()
s
# Out:
# 13

# %%
df[(df['Nationality'] == 'Brazil') & (df['Club'] == 'Juventus')]['Name'].unique()
# Out:
# array(['Alex Sandro', 'Douglas Costa'], dtype=object)

# %%
df[df['Age'] > 35]['Club'].value_counts()
# Out:
# Hokkaido Consadole Sapporo       4
# Club Atlético Huracán            4
# Nagoya Grampus                   3
# Morecambe                        3
# San Martín de San Juan           3
#                                 ..
# FC Groningen                     1
# CD Antofagasta                   1
# Universidad de Chile             1
# La Berrichonne de Châteauroux    1
# Fortuna Düsseldorf               1
# Name: Club, Length: 212, dtype: int64

# %%
df[df['Nationality'] == 'Argentina']['Age'].value_counts(bins=4)
# Out:
# (22.25, 28.5]      200
# (15.974, 22.25]    197
# (28.5, 34.75]      128
# (34.75, 41.0]       49
# Name: Age, dtype: int64

# %%
df[df['Nationality'] == 'Spain']['Age'].value_counts(normalize=True)
# Out:
# 21    0.117735
# 22    0.095380
# 20    0.077496
# 23    0.071535
# 25    0.064083
# 27    0.062593
# 24    0.059613
# 28    0.053651
# 26    0.053651
# 29    0.047690
# 19    0.047690
# 18    0.038748
# 30    0.038748
# 31    0.032787
# 32    0.032787
# 33    0.031297
# 34    0.022355
# 17    0.013413
# 35    0.011923
# 36    0.010432
# 37    0.008942
# 39    0.002981
# 16    0.002981
# 38    0.001490
# Name: Age, dtype: float64

# %%
df.groupby(['Club']).groups['Ajax']
# Out:
# Int64Index([152, 188, 234, 300, 319, 352, 737, 1335, 3111, 3769, 4847, 4897,
#             5010],
#            dtype='int64')

# %%
grouped_df = df.groupby(['Club']).sum()

# %%
grouped_df.loc['Ajax']['Wage']
# Out:
# 158000

# %%
wd = df.groupby(['Club'])['Wage'].sum().sort_values(ascending=False)
wd.head(5)
# Out:
# Club
# Real Madrid          4138000
# FC Barcelona         3967000
# Manchester City      3097000
# Manchester United    2357000
# Juventus             2335000
# Name: Wage, dtype: int64

# %%
wgs = df.groupby(['Position'])['Wage'].sum().sort_values(ascending=False)
wgs['LS'] > 5000000
# Out:
# False

# %%
df.groupby(['Nationality'])[['Wage','Age','ShotPower']].mean().sort_values(['Wage'], ascending=False).head()
# Out:
#                             Wage        Age  ShotPower
# Nationality
# Dominican Republic  71000.000000  23.000000  75.500000
# Egypt               35545.454545  25.818182  59.363636
# Gabon               28900.000000  26.400000  56.900000
# Croatia             26722.222222  24.819444  54.305556
# Equatorial Guinea   25666.666667  28.000000  55.333333

# %%
df[df['Nationality'] == 'Dominican Republic'][['Club','Wage','Age','ShotPower']]
# Out:
#              Club    Wage  Age  ShotPower
# 291   Real Madrid  140000   24         85
# 6279   Córdoba CF    2000   22         66

# %%
df.groupby(['Position'])[['Wage', 'Value']].mean().sort_values(['Value'], ascending=False).head()
# Out:
#                    Wage         Value
# Position
# LF         75125.000000  2.736250e+07
# RF        119000.000000  2.636583e+07
# LAM        61000.000000  1.324583e+07
# RAM        11800.000000  8.345000e+06
# LS         15421.487603  5.848430e+06

# %%
df.groupby(['Nationality'])[['Club','Name']].nunique().head()
# Out:
#              Club  Name
# Nationality
# Afghanistan     4     4
# Albania        26    29
# Algeria        33    37
# Andorra         1     1
# Angola          9    10

# %%
df.groupby(['Club'])['Name'].count()
# Out:
# Club
#  SSV Jahn Regensburg     24
# 1. FC Heidenheim 1846    20
# 1. FC Kaiserslautern     23
# 1. FC Köln               10
# 1. FC Magdeburg          21
#                          ..
# Zagłębie Sosnowiec       25
# Çaykur Rizespor          22
# Örebro SK                26
# Östersunds FK            20
# Śląsk Wrocław            24
# Name: Name, Length: 650, dtype: int64

# %%
df.groupby(['Club'])['Dribbling'].median()
# Out:
# Club
#  SSV Jahn Regensburg     57.5
# 1. FC Heidenheim 1846    59.5
# 1. FC Kaiserslautern     54.0
# 1. FC Köln               60.5
# 1. FC Magdeburg          53.0
#                          ...
# Zagłębie Sosnowiec       58.0
# Çaykur Rizespor          62.0
# Örebro SK                55.0
# Östersunds FK            61.5
# Śląsk Wrocław            54.5
# Name: Dribbling, Length: 650, dtype: float64

# %%
df.groupby(['Club'])['Strength'].max()
# Out:
# Club
#  SSV Jahn Regensburg     92
# 1. FC Heidenheim 1846    86
# 1. FC Kaiserslautern     85
# 1. FC Köln               76
# 1. FC Magdeburg          86
#                          ..
# Zagłębie Sosnowiec       84
# Çaykur Rizespor          81
# Örebro SK                85
# Östersunds FK            88
# Śląsk Wrocław            85
# Name: Strength, Length: 650, dtype: int64

# %%
df.groupby(['Club'])['Balance'].min()
# Out:
# Club
#  SSV Jahn Regensburg     29
# 1. FC Heidenheim 1846    22
# 1. FC Kaiserslautern     29
# 1. FC Köln               31
# 1. FC Magdeburg          19
#                          ..
# Zagłębie Sosnowiec       28
# Çaykur Rizespor          39
# Örebro SK                34
# Östersunds FK            32
# Śląsk Wrocław            31
# Name: Balance, Length: 650, dtype: int64

# %%
wd = df.groupby(['Club'])['Wage'].agg(['mean', 'median'])
wdmm = wd[wd['mean'] == wd['median']]
len(wdmm.index)
# Out:
# 52

# %%
wdmm.sort_values(['mean'], ascending=False).head()
# Out:
#                 mean  median
# Club
# Cruzeiro     13000.0   13000
# Göztepe SK    7000.0    7000
# Brøndby IF    6000.0    6000
# Sunderland    4000.0    4000
# CD Feirense   4000.0    4000

# %%
df.groupby(['Club'])['Wage'].sum()['Chelsea']
# Out:
# 2035000

# %%
df.groupby(['Nationality', 'Age'])['Wage'].max()[('Argentina', 30)]
# Out:
# 300000

# %%
df[df['Age'] == 30].groupby(['Nationality'])['Wage'].max()['Argentina']
# Out:
# 300000

# %%
df[df['Nationality'] == 'Argentina'].groupby(['Age'])['Wage'].min()[30]
# Out:
# 1000

# %%
dfsb = df[df['Nationality'] == 'Argentina'].groupby(['Club'])[['Strength', 'Balance']].max()
dfsb.loc['FC Barcelona']
# Out:
# Strength    59
# Balance     95
# Name: FC Barcelona, dtype: int64

# %%
pivot = df.loc[
    df['Club'].isin(['FC Barcelona','Real Madrid','Juventus','Manchester United'])
].pivot_table(
    values=['Wage'], index=['Nationality'], columns=['Club'], aggfunc='sum'
)
display(pivot.head())
# Out:
#                            Wage
# Club               FC Barcelona  Juventus Manchester United Real Madrid
# Nationality
# Argentina              565000.0  205000.0          206000.0         NaN
# Belgium                110000.0       NaN          230000.0    240000.0
# Bosnia Herzegovina          NaN  180000.0               NaN         NaN
# Brazil                 465000.0  335000.0           91000.0    570000.0
# Chile                  205000.0       NaN          215000.0         NaN

# %%
df[
    df['Club'].isin(['FC Barcelona','Real Madrid','Juventus','Manchester United'])
].pivot_table(
    values=['Wage'],
    index=['Nationality'],
    columns=['Club'],
    aggfunc='sum',
    margins=True,
    fill_value=0
)
# Out:
#                            Wage                                         \
# Club               FC Barcelona Juventus Manchester United Real Madrid
# Nationality
# Argentina                565000   205000            206000           0
# Belgium                  110000        0            230000      240000
# Bosnia Herzegovina            0   180000                 0           0
# Brazil                   465000   335000             91000      570000
# Chile                    205000        0            215000           0
# Costa Rica                    0        0                 0      195000
# Croatia                  260000   160000                 0      420000
# Dominican Republic            0        0                 0      140000
# Ecuador                       0        0            120000           0
# England                       0        0            478000           0
# France                   495000   145000            375000      459000
# ...

# %%
df2 = df.pivot_table(
    columns='Position', 
    index='Club', 
    values='Wage', 
    aggfunc='max'
)
df2
# Out:
# Position                   CAM       CB      CDM      CF      CM       GK  \
# Club
#  SSV Jahn Regensburg       NaN   5000.0   5000.0     NaN  4000.0   5000.0
# 1. FC Heidenheim 1846   5000.0   7000.0      NaN     NaN  1000.0   4000.0
# 1. FC Kaiserslautern       NaN   1000.0   1000.0     NaN     NaN   1000.0
# 1. FC Köln                 NaN   1000.0  10000.0     NaN  3000.0  25000.0
# 1. FC Magdeburg            NaN   7000.0      NaN  4000.0     NaN   6000.0
# ...                        ...      ...      ...     ...     ...      ...
# Zagłębie Sosnowiec      2000.0   1000.0   1000.0     NaN     NaN   1000.0
# Çaykur Rizespor        11000.0  11000.0  13000.0     NaN     NaN   3000.0
# Örebro SK                  NaN   2000.0      NaN     NaN  1000.0   2000.0
# Östersunds FK           1000.0   1000.0      NaN  3000.0  8000.0   1000.0
# Śląsk Wrocław              NaN   1000.0   3000.0     NaN  1000.0   2000.0
#
# ...

# %%
df2.loc['Manchester City']
# Out:
# Position
# CAM     36000.0
# CB     170000.0
# CDM    185000.0
# CF          NaN
# CM     175000.0
# GK     125000.0
# LAM         NaN
# LB     105000.0
# LCB    135000.0
# LCM    285000.0
# LDM         NaN
# LF          NaN
# LM          NaN
# LS          NaN
# LW     195000.0
# LWB         NaN
# RAM         NaN
# RB     110000.0
# RCB         NaN
# RCM    355000.0
# RDM         NaN
# RF          NaN
# RM       7000.0
# RS          NaN
# RW     205000.0
# RWB         NaN
# ST     300000.0
# Name: Manchester City, dtype: float64

# %%
pivot = df[
    df['Club'].isin(['FC Barcelona','Real Madrid','Juventus','Manchester United'])
].pivot_table(
    values=['Name'],
    index=['Nationality'],
    columns=['Club'],
    aggfunc='count',
    fill_value=0
)
display(pivot)
# Out:
#                            Name
# Club               FC Barcelona Juventus Manchester United Real Madrid
# Nationality
# Argentina                     1        1                 2           0
# Belgium                       1        0                 1           1
# Bosnia Herzegovina            0        1                 0           0
# Brazil                        2        2                 1           2
# Chile                         1        0                 1           0
# Costa Rica                    0        0                 0           1
# Croatia                       1        1                 0           1
# Dominican Republic            0        0                 0           1
# Ecuador                       0        0                 1           0
# England                       0        0                 6           0
# France                        3        1                 2           3
# Germany                       1        1                 0           1
# ...

# %%
pivot.loc['Argentina']
#['Name']['Manchester United']
# Out:
#       Club
# Name  FC Barcelona         1
#       Juventus             1
#       Manchester United    2
#       Real Madrid          0
# Name: Argentina, dtype: int64

# %%
pos_pivot = df.pivot_table(
    values=['Name'],
    index=['Club'],
    columns=['Position'],
    aggfunc='count',
    fill_value=0
)

# %%
pos_pivot['Name']['GK'].mean()
# Out:
# 2.5246153846153847

# %%
dfp = pos_pivot['Name']

# %%
dfp[dfp['CM'] == 0]['CM'].value_counts()
# Out:
# 0    136
# Name: CM, dtype: int64

# %% [markdown]
# -----------------------------------

# %%
pivot = df.pivot_table(
    values='Wage',
    index=['Nationality'],
    columns=['Club'],
    aggfunc='sum'
)

# %%
pivot.loc['Russia']['AS Monaco']
# Out:
# 61000.0

# %%
pivot = df.pivot_table(
    values='SprintSpeed',
    index=['Club'],
    columns=['Position'],
    aggfunc='mean',
    margins=True,
    fill_value=0
)
pivot
# Out:
# Position                     CAM         CB        CDM         CF         CM  \
# Club
#  SSV Jahn Regensburg    0.000000  46.600000  82.000000   0.000000  61.000000
# 1. FC Heidenheim 1846  68.000000  61.333333   0.000000   0.000000  68.000000
# 1. FC Kaiserslautern    0.000000  59.000000  65.666667   0.000000   0.000000
# 1. FC Köln              0.000000  60.000000  32.000000   0.000000  68.500000
# 1. FC Magdeburg         0.000000  60.000000   0.000000  64.000000   0.000000
# ...                          ...        ...        ...        ...        ...
# Çaykur Rizespor        74.000000  58.000000  62.800000   0.000000   0.000000
# Örebro SK               0.000000  60.750000   0.000000   0.000000  63.000000
# Östersunds FK          67.000000  76.000000   0.000000  77.000000  56.333333
# Śląsk Wrocław           0.000000  62.000000  66.666667   0.000000  72.000000
# All                    68.236967  57.734854  60.813314  69.803922  64.299906
#
# ...

# %%
pivot.max(axis=0).sort_values(ascending=False).head()
# Out:
# Position
# RS    94.0
# RM    94.0
# LM    94.0
# LS    93.0
# LB    93.0
# dtype: float64

# %%
pivot['ST'].sort_values(ascending=False)
# Out:
# Club
# Vitória                  91.000000
# Sydney FC                88.000000
# CD Lugo                  87.000000
# Brøndby IF               84.666667
# Leicester City           84.500000
#                            ...
# Al Ittihad                0.000000
# Cagliari                  0.000000
# KAA Gent                  0.000000
# Sporting de Charleroi     0.000000
# Girona FC                 0.000000
# Name: ST, Length: 651, dtype: float64
