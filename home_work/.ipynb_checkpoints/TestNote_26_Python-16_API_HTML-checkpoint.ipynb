# %% [markdown]
# # Библиотека requests

# %%
#!pip install --user requests

# %%
import requests  

response = requests.get('https://www.cbr-xml-daily.ru/daily_json.js')

# %%
print(response, response.status_code)
# Out:
# <Response [200]> 200

# %%
response = requests.get('https://www.cbr-xml-daily.ru/daily.xml')

# %%
print(response, response.status_code)
# Out:
# <Response [200]> 200

# %% [markdown]
# # Читаем результат
#
# Мы сделали запрос и получили ответ. Давайте теперь посмотрим, как считывать текст.
#
# Адрес, по которому мы обращались, возвращает результат в json формате. Эти данные уже лежат в атрибуте text в полученном ответе response:

# %%
response = requests.get('https://www.cbr-xml-daily.ru/daily_json.js')    
print(response.text)
# Out:
# {
#     "Date": "2021-05-22T11:30:00+03:00",
#     "PreviousDate": "2021-05-21T11:30:00+03:00",
#     "PreviousURL": "\/\/www.cbr-xml-daily.ru\/archive\/2021\/05\/21\/daily_json.js",
#     "Timestamp": "2021-05-22T21:00:00+03:00",
#     "Valute": {
#         "AUD": {
#             "ID": "R01010",
#             "NumCode": "036",
#             "CharCode": "AUD",
#             "Nominal": 1,
#             "Name": "Австралийский доллар",
#             "Value": 56.9879,
#             "Previous": 57.0847
#         },
#         "AZN": {
#             "ID": "R01020A",
#             "NumCode": "944",
#             "CharCode": "AZN",
#             "Nominal": 1,
#             "Name": "Азербайджанский манат",
#             "Value": 43.308,
#             "Previous": 43.32
#         },
#         "GBP": {
#             "ID": "R01035",
#             "NumCode": "826",
#             "CharCode": "GBP",
#             "Nominal": 1,
#             "Name": "Фунт стерлингов Соединенного королевства",
#             "Value": 104.4104,
#             "Previous": 103.9904
#         },
#         "AMD": {
#             "ID": "R01060",
#             "NumCode": "051",
#             "CharCode": "AMD",
#             "Nominal": 100,
#             "Name": "Армянских драмов",
#             "Value": 14.1299,
#             "Previous": 14.1344
#         },
#         "BYN": {
#             "ID": "R01090B",
#             "NumCode": "933",
#             "CharCode": "BYN",
#             "Nominal": 1,
#             "Name": "Белорусский рубль",
#             "Value": 29.357,
#             "Previous": 29.2787
#         },
#         "BGN": {
#             "ID": "R01100",
#             "NumCode": "975",
#             "CharCode": "BGN",
#             "Nominal": 1,
#             "Name": "Болгарский лев",
#             "Value": 45.9647,
#             "Previous": 45.9143
#         },
#         "BRL": {
#             "ID": "R01115",
#             "NumCode": "986",
#             "CharCode": "BRL",
#             "Nominal": 1,
#             "Name": "Бразильский реал",
#             "Value": 13.9288,
#             "Previous": 13.8613
#         },
#         "HUF": {
#             "ID": "R01135",
#             "NumCode": "348",
#             "CharCode": "HUF",
#             "Nominal": 100,
#             "Name": "Венгерских форинтов",
#             "Value": 25.7,
#             "Previous": 25.6986
#         },
#         "HKD": {
#             "ID": "R01200",
#             "NumCode": "344",
#             "CharCode": "HKD",
#             "Nominal": 10,
#             "Name": "Гонконгских долларов",
#             "Value": 94.7675,
#             "Previous": 94.8121
#         },
#         "DKK": {
#             "ID": "R01215",
#             "NumCode": "208",
#             "CharCode": "DKK",
#             "Nominal": 1,
#             "Name": "Датская крона",
#             "Value": 12.0915,
#             "Previous": 12.0754
#         },
#         "USD": {
#             "ID": "R01235",
#             "NumCode": "840",
#             "CharCode": "USD",
#             "Nominal": 1,
#             "Name": "Доллар США",
#             "Value": 73.5803,
#             "Previous": 73.6007
#         },
#         "EUR": {
#             "ID": "R01239",
#             "NumCode": "978",
#             "CharCode": "EUR",
#             "Nominal": 1,
#             "Name": "Евро",
#             "Value": 89.9446,
#             "Previous": 89.7708
#         },
#         "INR": {
#             "ID": "R01270",
#             "NumCode": "356",
#             "CharCode": "INR",
#             "Nominal": 10,
#             "Name": "Индийских рупий",
#             "Value": 10.0764,
#             "Previous": 10.062
#         },
#         "KZT": {
#             "ID": "R01335",
#             "NumCode": "398",
#             "CharCode": "KZT",
#             "Nominal": 100,
#             "Name": "Казахстанских тенге",
#             "Value": 17.1534,
#             "Previous": 17.1581
#         },
#         "CAD": {
#             "ID": "R01350",
#             "NumCode": "124",
#             "CharCode": "CAD",
#             "Nominal": 1,
#             "Name": "Канадский доллар",
#             "Value": 60.8856,
#             "Previous": 60.7668
#         },
#         "KGS": {
#             "ID": "R01370",
#             "NumCode": "417",
#             "CharCode": "KGS",
#             "Nominal": 100,
#             "Name": "Киргизских сомов",
#             "Value": 87.6036,
#             "Previous": 87.6149
#         },
#         "CNY": {
#             "ID": "R01375",
#             "NumCode": "156",
#             "CharCode": "CNY",
#             "Nominal": 1,
#             "Name": "Китайский юань",
#             "Value": 11.4358,
#             "Previous": 11.4356
#         },
#         "MDL": {
#             "ID": "R01500",
#             "NumCode": "498",
#             "CharCode": "MDL",
#             "Nominal": 10,
#             "Name": "Молдавских леев",
#             "Value": 41.5943,
#             "Previous": 41.5588
#         },
#         "NOK": {
#             "ID": "R01535",
#             "NumCode": "578",
#             "CharCode": "NOK",
#             "Nominal": 10,
#             "Name": "Норвежских крон",
#             "Value": 88.3222,
#             "Previous": 88.6862
#         },
#         "PLN": {
#             "ID": "R01565",
#             "NumCode": "985",
#             "CharCode": "PLN",
#             "Nominal": 1,
#             "Name": "Польский злотый",
#             "Value": 19.9832,
#             "Previous": 19.8899
#         },
#         "RON": {
#             "ID": "R01585F",
#             "NumCode": "946",
#             "CharCode": "RON",
#             "Nominal": 1,
#             "Name": "Румынский лей",
#             "Value": 18.2427,
#             "Previous": 18.2203
#         },
#         "XDR": {
#             "ID": "R01589",
#             "NumCode": "960",
#             "CharCode": "XDR",
#             "Nominal": 1,
#             "Name": "СДР (специальные права заимствования)",
#             "Value": 106.1565,
#             "Previous": 106.2338
#         },
#         "SGD": {
#             "ID": "R01625",
#             "NumCode": "702",
#             "CharCode": "SGD",
#             "Nominal": 1,
#             "Name": "Сингапурский доллар",
#             "Value": 55.2405,
#             "Previous": 55.2268
#         },
#         "TJS": {
#             "ID": "R01670",
#             "NumCode": "972",
#             "CharCode": "TJS",
#             "Nominal": 10,
#             "Name": "Таджикских сомони",
#             "Value": 64.5158,
#             "Previous": 64.5337
#         },
#         "TRY": {
#             "ID": "R01700J",
#             "NumCode": "949",
#             "CharCode": "TRY",
#             "Nominal": 10,
#             "Name": "Турецких лир",
#             "Value": 87.8896,
#             "Previous": 87.8584
#         },
#         "TMT": {
#             "ID": "R01710A",
#             "NumCode": "934",
#             "CharCode": "TMT",
#             "Nominal": 1,
#             "Name": "Новый туркменский манат",
#             "Value": 21.053,
#             "Previous": 21.0589
#         },
#         "UZS": {
#             "ID": "R01717",
#             "NumCode": "860",
#             "CharCode": "UZS",
#             "Nominal": 10000,
#             "Name": "Узбекских сумов",
#             "Value": 69.4301,
#             "Previous": 69.5265
#         },
#         "UAH": {
#             "ID": "R01720",
#             "NumCode": "980",
#             "CharCode": "UAH",
#             "Nominal": 10,
#             "Name": "Украинских гривен",
#             "Value": 26.79,
#             "Previous": 26.7982
#         },
#         "CZK": {
#             "ID": "R01760",
#             "NumCode": "203",
#             "CharCode": "CZK",
#             "Nominal": 10,
#             "Name": "Чешских крон",
#             "Value": 35.292,
#             "Previous": 35.2443
#         },
#         "SEK": {
#             "ID": "R01770",
#             "NumCode": "752",
#             "CharCode": "SEK",
#             "Nominal": 10,
#             "Name": "Шведских крон",
#             "Value": 88.7633,
#             "Previous": 88.336
#         },
#         "CHF": {
#             "ID": "R01775",
#             "NumCode": "756",
#             "CharCode": "CHF",
#             "Nominal": 1,
#             "Name": "Швейцарский франк",
#             "Value": 82.0293,
#             "Previous": 81.7059
#         },
#         "ZAR": {
#             "ID": "R01810",
#             "NumCode": "710",
#             "CharCode": "ZAR",
#             "Nominal": 10,
#             "Name": "Южноафриканских рэндов",
#             "Value": 52.6141,
#             "Previous": 52.2907
#         },
#         "KRW": {
#             "ID": "R01815",
#             "NumCode": "410",
#             "CharCode": "KRW",
#             "Nominal": 1000,
#             "Name": "Вон Республики Корея",
#             "Value": 65.1932,
#             "Previous": 65.064
#         },
#         "JPY": {
#             "ID": "R01820",
#             "NumCode": "392",
#             "CharCode": "JPY",
#             "Nominal": 100,
#             "Name": "Японских иен",
#             "Value": 67.7192,
#             "Previous": 67.5546
#         }
#     }
# }

# %% [markdown]
# Вы можете посмотреть на полный текст, повторив запрос или на этой странице в вашем браузере.
#
# Сейчас текст хранится просто в строковой переменной. Далее мы можем превратить эту строку в словарь. Сделать это можно с помощью JSON-парсера python, либо воспользовавшись методом json, который уже встроен в объект ответа response:

# %%
currencies = response.json()  
print(currencies)
# Out:
# {'Date': '2021-05-22T11:30:00+03:00', 'PreviousDate': '2021-05-21T11:30:00+03:00', 'PreviousURL': '//www.cbr-xml-daily.ru/archive/2021/05/21/daily_json.js', 'Timestamp': '2021-05-22T21:00:00+03:00', 'Valute': {'AUD': {'ID': 'R01010', 'NumCode': '036', 'CharCode': 'AUD', 'Nominal': 1, 'Name': 'Австралийский доллар', 'Value': 56.9879, 'Previous': 57.0847}, 'AZN': {'ID': 'R01020A', 'NumCode': '944', 'CharCode': 'AZN', 'Nominal': 1, 'Name': 'Азербайджанский манат', 'Value': 43.308, 'Previous': 43.32}, 'GBP': {'ID': 'R01035', 'NumCode': '826', 'CharCode': 'GBP', 'Nominal': 1, 'Name': 'Фунт стерлингов Соединенного королевства', 'Value': 104.4104, 'Previous': 103.9904}, 'AMD': {'ID': 'R01060', 'NumCode': '051', 'CharCode': 'AMD', 'Nominal': 100, 'Name': 'Армянских драмов', 'Value': 14.1299, 'Previous': 14.1344}, 'BYN': {'ID': 'R01090B', 'NumCode': '933', 'CharCode': 'BYN', 'Nominal': 1, 'Name': 'Белорусский рубль', 'Value': 29.357, 'Previous': 29.2787}, 'BGN': {'ID': 'R01100', 'NumCode': '975', 'CharCode': 'BGN', 'Nominal': 1, 'Name': 'Болгарский лев', 'Value': 45.9647, 'Previous': 45.9143}, 'BRL': {'ID': 'R01115', 'NumCode': '986', 'CharCode': 'BRL', 'Nominal': 1, 'Name': 'Бразильский реал', 'Value': 13.9288, 'Previous': 13.8613}, 'HUF': {'ID': 'R01135', 'NumCode': '348', 'CharCode': 'HUF', 'Nominal': 100, 'Name': 'Венгерских форинтов', 'Value': 25.7, 'Previous': 25.6986}, 'HKD': {'ID': 'R01200', 'NumCode': '344', 'CharCode': 'HKD', 'Nominal': 10, 'Name': 'Гонконгских долларов', 'Value': 94.7675, 'Previous': 94.8121}, 'DKK': {'ID': 'R01215', 'NumCode': '208', 'CharCode': 'DKK', 'Nominal': 1, 'Name': 'Датская крона', 'Value': 12.0915, 'Previous': 12.0754}, 'USD': {'ID': 'R01235', 'NumCode': '840', 'CharCode': 'USD', 'Nominal': 1, 'Name': 'Доллар США', 'Value': 73.5803, 'Previous': 73.6007}, 'EUR': {'ID': 'R01239', 'NumCode': '978', 'CharCode': 'EUR', 'Nominal': 1, 'Name': 'Евро', 'Value': 89.9446, 'Previous': 89.7708}, 'INR': {'ID': 'R01270', 'NumCode': '356', 'CharCode': 'INR', 'Nominal': 10, 'Name': 'Индийских рупий', 'Value': 10.0764, 'Previous': 10.062}, 'KZT': {'ID': 'R01335', 'NumCode': '398', 'CharCode': 'KZT', 'Nominal': 100, 'Name': 'Казахстанских тенге', 'Value': 17.1534, 'Previous': 17.1581}, 'CAD': {'ID': 'R01350', 'NumCode': '124', 'CharCode': 'CAD', 'Nominal': 1, 'Name': 'Канадский доллар', 'Value': 60.8856, 'Previous': 60.7668}, 'KGS': {'ID': 'R01370', 'NumCode': '417', 'CharCode': 'KGS', 'Nominal': 100, 'Name': 'Киргизских сомов', 'Value': 87.6036, 'Previous': 87.6149}, 'CNY': {'ID': 'R01375', 'NumCode': '156', 'CharCode': 'CNY', 'Nominal': 1, 'Name': 'Китайский юань', 'Value': 11.4358, 'Previous': 11.4356}, 'MDL': {'ID': 'R01500', 'NumCode': '498', 'CharCode': 'MDL', 'Nominal': 10, 'Name': 'Молдавских леев', 'Value': 41.5943, 'Previous': 41.5588}, 'NOK': {'ID': 'R01535', 'NumCode': '578', 'CharCode': 'NOK', 'Nominal': 10, 'Name': 'Норвежских крон', 'Value': 88.3222, 'Previous': 88.6862}, 'PLN': {'ID': 'R01565', 'NumCode': '985', 'CharCode': 'PLN', 'Nominal': 1, 'Name': 'Польский злотый', 'Value': 19.9832, 'Previous': 19.8899}, 'RON': {'ID': 'R01585F', 'NumCode': '946', 'CharCode': 'RON', 'Nominal': 1, 'Name': 'Румынский лей', 'Value': 18.2427, 'Previous': 18.2203}, 'XDR': {'ID': 'R01589', 'NumCode': '960', 'CharCode': 'XDR', 'Nominal': 1, 'Name': 'СДР (специальные права заимствования)', 'Value': 106.1565, 'Previous': 106.2338}, 'SGD': {'ID': 'R01625', 'NumCode': '702', 'CharCode': 'SGD', 'Nominal': 1, 'Name': 'Сингапурский доллар', 'Value': 55.2405, 'Previous': 55.2268}, 'TJS': {'ID': 'R01670', 'NumCode': '972', 'CharCode': 'TJS', 'Nominal': 10, 'Name': 'Таджикских сомони', 'Value': 64.5158, 'Previous': 64.5337}, 'TRY': {'ID': 'R01700J', 'NumCode': '949', 'CharCode': 'TRY', 'Nominal': 10, 'Name': 'Турецких лир', 'Value': 87.8896, 'Previous': 87.8584}, 'TMT': {'ID': 'R01710A', 'NumCode': '934', 'CharCode': 'TMT', 'Nominal': 1, 'Name': 'Новый туркменский манат', 'Value': 21.053, 'Previous': 21.0589}, 'UZS': {'ID': 'R01 ...

# %% [markdown]
# Теперь данные лежат в словаре, и мы можем легко получать необходимые нам значения:

# %%
currencies['Valute']['UAH']
# Out:
# {'ID': 'R01720',
#  'NumCode': '980',
#  'CharCode': 'UAH',
#  'Nominal': 10,
#  'Name': 'Украинских гривен',
#  'Value': 26.79,
#  'Previous': 26.7982}

# %% [markdown]
# Данные получены, и задание выполнено.

# %% [markdown]
# **Задание 1**
#
# Повторите запросы, описанные в этой части, на своём компьютере. Что выведет на экран следующий код?

# %%
print(currencies['Valute']['CZK']['Name'])
# Out:
# Чешских крон

# %% [markdown]
# # Оформляем функцию
#
# В завершение давайте оформим наши вычисления в отдельную функцию, которой будет удобно пользоваться. На вход она должна принимать два параметра:
#
# 1. Название валюты currency. Например, 'EUR' или 'USD'.
#
# 2. Формат ответа format. При значении 'full' будем отдавать все, что знаем о валюте. Например, для currency = 'USD': {'CharCode': 'USD',
#    'ID': 'R01235',
#    'Name': 'Доллар США',
#    'Nominal': 1,
#    'NumCode': '840',
#    'Previous': 68.2505,
#    'Value': 69.0286}
#
# А при значении format = 'value' только значение ключа 'Value', т. е. курс: 69.0286.
#
# Оформим наши требования в коде:

# %%
def exchange_rates(currency, format='full'):    
    url = 'https://www.cbr-xml-daily.ru/daily_json.js'  
    response = requests.get(url).json()['Valute']    
    data = response[currency]     
    if format == 'full':    
        return data      
    elif format == 'value':    
        return data['Value']

# %%
exchange_rates('USD')
# Out:
# {'ID': 'R01235',
#  'NumCode': '840',
#  'CharCode': 'USD',
#  'Nominal': 1,
#  'Name': 'Доллар США',
#  'Value': 73.5803,
#  'Previous': 73.6007}

# %%
exchange_rates('USD', 'value')
# Out:
# 73.5803

# %% [markdown]
# **Задание 1**
#
# Напишите функцию currency_name, которая по ID валюты возвращает ее название на русском языке.

# %%
import pdb

def currency_name(currency_id):
    url = 'https://www.cbr-xml-daily.ru/daily_json.js'
    response = requests.get(url).json()['Valute']
    pdb.set_trace()
    for key, value in response.items():
        if value['ID'] == currency_id:
            return value['Name']

# %%
currency_name('R01700J')
#=> 'Турецких лир'
# Out:
# > <ipython-input-13-1e0fe76e0dea>(7)currency_name()
# -> for key, value in response.items():
# (Pdb) continue
# 'Турецких лир'

# %% [markdown]
# # HTML-страницы
#
# **Постановка задачи**
#
# Довольно часто приходится добывать информацию не из удобно форматированного json-файла, а прямо с HTML-страниц. Получить содержимое страницы в большинстве случаев несложно, труднее извлечь из HTML-кода нужную информацию. В качестве примера мы рассмотрим страницу новости, из которой будем доставать полезную информацию: 1) заголовок страницы; 2) дату публикации; 3) текст публикации; 4) ссылки на странице.
#
# **Получаем данные**
#
# Получить html страницу можно так же, как мы получали до этого json: используем библиотеку requests и метод GET:

# %%
import requests  
  
url = 'https://nplus1.ru/news/2019/06/04/slothbot'   
  
response = requests.get(url)  
  
# Убедимся, что мы успешно получили ответ     
print(response.status_code)    
# => 200   
  
# Выведем полученные данные    
print(response.text)
# Out:
# 200
# <!doctype html>
# <html class="no-js bg-fixed _no-bg" style="background-image:url(https://nplus1.ru/images/2019/06/04/b32b62189fb87cce895e229e1d6d27b4.jpeg)" lang="">
# <head>
#
#     <meta charset="utf-8">
#     <meta http-equiv="x-ua-compatible" content="ie=edge">
#     <meta name="viewport" content="width=device-width, initial-scale=1">
#         <meta name="apple-mobile-web-app-capable" content="yes">
#     <meta name="apple-mobile-web-app-status-bar-style" content="black">
#                 <meta name='wmail-verification' content='7991d7eb02d759f05b9050e111a7e3eb' />
#
#     <link rel="canonical" href="https://nplus1.ru/news/2019/06/04/slothbot" />
#
#         <title>Робота-ленивца научили лазать по паутине из тросов</title>
#
#     	    <meta itemprop="datePublished" content="2019-06-04"/>
#
# 	    <meta name="mediator_author" content="Григорий Копиев"/>
#
#         <!-- amp page -->
#     <link rel="amphtml" href="https://nplus1.ru/news/2019/06/04/slothbot/amp">
#
#
#         <!-- for Google -->
#         <meta name="description" content="Он сам добывает энергию с помощью солнечных панелей" />
#
#         <meta name="author" content="Григорий Копиев" />
#         <meta name="copyright" content="" />
#
#         <!-- for Facebook -->
#         <meta property="og:title" content="Робота-ленивца научили лазать по паутине из тросов" />
#                 <meta property="og:image" content="https://nplus1.ru/images/2019/06/04/000d995dad5ab0988b764af18abf6da5.jpeg" />
#         <meta property="og:url" content="https://nplus1.ru/news/2019/06/04/slothbot" />
#         <meta property="og:description" content="Он сам добывает энергию с помощью солнечных панелей" />
#         <!-- for Twitter -->
#         <meta name="twitter:card" content="summary_large_image">
#         <meta name="twitter:site" content="@nplusodin" />
#         <meta name="twitter:title" content="Робота-ленивца научили лазать по паутине из тросов" />
#         <meta name="twitter:description" content="Он сам добывает энергию с помощью солнечных панелей" />
#         <meta name="twitter:image" content="https://nplus1.ru/images/2019/06/04/000d995dad5ab0988b764af18abf6da5.jpeg" />
#
#         <meta name="yandex-verification" content="8c90b02c84ac3b72" />
#
#
#         <link rel='alternate' type='application/rss+xml' title='RSS' href='https://nplus1.ru/rss'>
#
#     <link rel="stylesheet" href="/css/font-awesome.min.css">
#     <link rel="stylesheet" href="/css/main.min.css?v=1621622616">
#     <link rel="stylesheet" href="/css/desktop.min.css?v=1452887696">
#     <link rel="stylesheet" href="/css/tablet.min.css?v=1499281342">
#     <link rel="stylesheet" href="/css/mobile.min.css?v=1603187018">
#
#     <script src="//ajax.googleapis.com/ajax/libs/jquery/1.11.2/jquery.min.js"></script>
#
#     <script src="//cdnjs.cloudflare.com/ajax/libs/modernizr/2.8.3/modernizr.min.js"></script>
#
#             <script type="text/javascript" src="/js/lib/adfox.asyn.code.ver3.js"> </script>
# 		<script type="text/javascript" src="/js/lib/adfox.asyn.code.scroll.js"> </script>
# 	    <script src="https://yastatic.net/pcode/adfox/loader.js" crossorigin="anonymous"></script>
#         <script async id="__lxGc__rtr" type="text/javascript" src="//s.clickiocdn.com/t/195458/360.js"></script>
#         <script async type="text/javascript" src="//s.luxupcdnc.com/t/common_402.js"></script>
#
# 		<!--  ad -->
# 		<script type="text/javascript">
# 		    var __colAdLoaded = false;
# 		    var __topAdLoaded = false;
#
# 		    var __id = "";
#
# 		    function detectAd(id){
# 		        var _ad = document.getElementById("AdFox_banner_"+id);
# 		    	    console.debug(_ad);
#
# 		        __id = id;
# 		        if(_ad != null && _ad.innerHTML == ""){
# 		            $(".col-ad").remove();
# 		        }
# 		        __colAdLoaded = true;
# 		    }
# 		    function detectAdTop(id){
# 		        __topAdLoaded = true;
# 		    }
# 		</script>
# 		<!-- /ad -->
#
#
#
#
#
# <script type="application/ld+json">{"@context":"http://schema.org","@type":"NewsArticle","mainEntityOfPage":{"@type":"WebPage","@id":"https://nplus1.ru/news/2019/06/04/slothbot"},"headline":"Робота-ленивца научили лазать по паутине из тросов","description":"Он сам добывает энергию с помощью солнечных панелей","image":"https://nplus1.ru/images/2019/06/04/000d995dad5ab0988b764af18abf6da5.jpeg","author":{"@type":"Person","name":"Григорий Копиев"},"publisher":{"@type":"Organization","name":"N+1","logo":{"@type":"ImageObject","url":"https://nplus1.ru/i/logo-alt.png"}},"datePublished":"2019-06-04"}</script>
# </head>
# <body style="background-image:url(https://nplus1.ru/images/2019/06/04/b32b62189fb87cce895e229e1d6d27b4.jpeg)" class="_inner  ">
#
# <div class="shadow-overlay"></div>
# <link property='' rel='stylesheet' href='//s.luxupcdnc.com/cp/all/cookies_policy.css' />
# <script type='text/javascript'>_cookies_policy = {dark:0,bottom:1,text:'Этот сайт использует cookies для улучшения качества работы',link:'Подробнее',href:'https://nplus1.ru/cookies-policy',button:'Закрыть'};</script>
# <script async type='text/javascript' src='//s.luxupcdnc.com/cp/all/cookies_policy.js'></script>
#
#
#
#
#
#
#
#     <div id="viewport">
# 	<div id="shadow"></div>
#         <div class="ad ad-top">
#
#
#
#
#
#                         	    <!-- bh1 -->
# <!--AdFox START-->
# <!--nplus1_dir-->
# <!--Площадка: https://nplus1.ru/ / * / *-->
# <!--Тип баннера: Верхняя перетяжка 100%-->
# <!--Расположение: <верх страницы>-->
# <div id="adfox_15000335664353901"></div>
# <script>
#     window.Ya.adfoxCode.create({
#         ownerId: 248569,
#         containerId: 'adfox_15000335664353901',
#         params: {
#             pp: 'g',
#             ps: 'cggm',
#             p2: 'fqtd',
#             puid1: ''
#         }
#     });
# </script>
#
#         </div>
#         <header id="header-mobile">
#
#             <div class="container">
#                 <a href="#" class="action-menu pull-left"><i class="icon icon-navicon"></i></a>
#                 <a href="/" class="link-logo"><img src="/i/logo-mobile.png"/></a>
#                 <a href="#" class="action-search pull-right"><i class="icon icon-search"></i></a>
#                 <form action="/search" method="get" class="form-search">
#                     <div class="control">
#                         <input type="text" name="q" placeholder="Найти" value=""/>
#                     </div>
#                     <a href="#" class="action-search-close">×</a>
#                 </form>
#             </div>
#             <nav class="nav-rubrics">
#     <ul>
#                 <li>
#             <a href="/rubric/astronomy" class="">Астрономия</a>
#         </li>
#                 <li>
#             <a href="/rubric/physics" class="">Физика</a>
#         </li>
#                 <li>
#             <a href="/rubric/biology" class="">Биология</a>
#         </li>
#                 <li>
#             <a href="/rubric/robots-drones" class="">Роботы и дроны</a>
#         </li>
#
#                                     <li>
#                     <a href="/theme/explainatorium" class="">Давайте разберемся</a>
#                 </li>
#                             <li>
#                     <a href="/theme/bookshelf" class="">Книжная полка</a>
#                 </li>
#                             <li>
#                     <a href="/theme/Courses" class="">Курсы</a>
#                 </li>
#                             <li>
#                     <a href="/theme/coronavirus-history" class="">Коронавирусные хроники</a>
#                 </li>
#                             <li>
#                     <a href="/theme/offline" class="">N + Offline</a>
#                 </li>
#
#             </ul>
# </nav>
#
#         </header>
#
#
#         <div id="layout" class="js-mediator-container">
#             <!-- header -->
#                         <header id="header" class="_middle">
#     <div class="row">
#
#         <div class="col col-logo">
#             <a href="/" class="link-logo"></a>
#         </div>
#         <div class="col col-nav-main">
#             <form action="/search" method="get" class="form-search">
#                 <div class="control">
#                     <input type="text" name="q" placeholder="Найти" value=""/>
#                 </div>
#                 <a href="#" class="action-search-close">×</a>
#             </form>
#
#             <nav class="nav-rubrics">
#     <ul>
#                 <li>
#             <a href="/rubric/astronomy" class="">Астрономия</a>
#         </li>
#                 <li>
#             <a href="/rubric/physics" class="">Физика</a>
#         </li>
#                 <li>
#             <a href="/rubric/biology" class="">Биология</a>
#         </li>
#                 <li>
#             <a href="/rubric/robots-drones" class="">Роботы и дроны</a>
#         </li>
#
#
#                 <li>
#             <a href="#" class="action-search"><i class="icon icon-search"></i></a>
#         </li>
#             </ul>
# </nav>            <nav class="nav-themes">
#     <ul>
#                 <li data-name="explainatorium">
#             <a href="/theme/explainatorium" class="">Давайте разберемся</a>
#         </li>
#                 <li data-name="bookshelf">
#             <a href="/theme/bookshelf" class="">Книжная полка</a>
#         </li>
#                 <li data-name="Courses">
#             <a href="/theme/Courses" class="">Курсы</a>
#         </li>
#                 <li data-name="coronavirus-history">
#             <a href="/theme/coronavirus-history" class="">Коронавирусные хроники</a>
#         </li>
#                 <li data-name="offline">
#             <a href="/theme/offline" class="">N + Offline</a>
#         </li>
#             </ul>
# </nav>
#         </div>
#     </div>
#         <div class="container line-up">
#         <div class="line line-second">
#                                             <a href="https://nplus1.ru/blog/2021/05/20/rebrikov-goes-on" class="action-line-toggle">
#                     <div class="heading"><span></span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2021/05/20/rebrikov-goes-on" class="container-link">
#                     <div class="heading"><span>Давайте разберемся</span></div>
#                     <div class="link"><span>Редактура продолжается</span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2021/05/18/la-marque-du-sacre" class="container-link">
#                     <div class="heading"><span>Книжная полка</span></div>
#                     <div class="link"><span>Жан-Пьер Дюпюи &laquo;Знак священного&raquo;</span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2021/05/17/terra-dokhov" class="container-link">
#                     <div class="heading"><span>Terra Cognita</span></div>
#                     <div class="link"><span>Как реновация Москвы не стала османизацией Парижа</span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2021/05/14/chnpp-neutron-stream" class="container-link">
#                     <div class="heading"><span>Давайте разберемся</span></div>
#                     <div class="link"><span>Эффект просушки: что происходит с радиоактивной лавой под реактором в Чернобыле</span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2021/05/13/not-a-soldier" class="container-link">
#                     <div class="heading"><span>Об археологии просто</span></div>
#                     <div class="link"><span>Не солдат, а морской инженер: как погибший в Геркулануме сменил чин и профессию</span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2021/05/12/russian-horseman" class="container-link">
#                     <div class="heading"><span>Книжная полка</span></div>
#                     <div class="link"><span>Бэлла Шапиро &laquo;Русский всадник в парадигме власти&raquo;</span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2021/05/11/controllability-of-ionization-energy" class="container-link">
#                     <div class="heading"><span>Физики смогли</span></div>
#                     <div class="link"><span>Менделееву и не снилось: что может сделать фотонный кристалл с энергией ионизации атома</span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2021/05/06/russian-sexual-culture" class="container-link">
#                     <div class="heading"><span>Книжная полка</span></div>
#                     <div class="link"><span>&laquo;Сметая запреты: очерки русской сексуальной культуры XI&ndash;XX веков&raquo;</span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2021/04/30/anvisa-vs-sputnikv" class="container-link">
#                     <div class="heading"><span>Давайте разберемся</span></div>
#                     <div class="link"><span>Здесь репликанты: чем российская вакцина &laquo;Спутник V&raquo; напугала бразильского регулятора</span></div>
#                 </a>
#                                                 		           	<a href="https://nplus1.ru/blog/2021/05/21/v1405-cas" class="container-link active">
#         	        	<div class="heading"><span>Космические дневники</span></div>
#             	    	<div class="link"><span>Кто подмигнул нам из Кассиопеи?</span></div>
# 		            </a>
#
#             <!-- here -->
#                     </div>
#
#     </div>
#     </header>                        <!-- /header -->
#             <!--  hero -->
#                             <!-- /hero -->
#             <!-- main section -->
#             <section id="main">
#
#
#     <div class="container _middle">
#         <div class="row" data-adaptive="1" data-tablet-class="row-wrap" data-mobile-class="row-wrap">
#             <div class="col col-3" data-adaptive="1" data-mobile-class="col-1">
#
#                 <article class="content" id="article" data-id="20774" data-visit="1" data-type="0">
#                                         <div class="meta">
#     <div class="tables">
#         <p class="table">
#                         <a data-rubric="robots-drones" href="/rubric/robots-drones">Роботы и дроны</a>
#                                             </p>
#         <p class="table">
#             <a href="/news/2019/06/04">
#                 <time itemprop="datePublished" content="2019-06-04" data-unix="1559662033">
#                     <span>18:27</span>
#                     <span>04 Июнь 2019</span>
#                 </time>
#             </a>
#         </p>
#         <p class="table">
#             <a href="/difficult/2.2">
#                 <span>Сложность</span>
#                 <span class="difficult-value">2.2</span>
#             </a>
#         </p>
#     </div>
# </div>
# <script type="text/javascript">
#     var _dlData = {custom_rubric: []};
#         _dlData.custom_author = 'Григорий Копиев';
#         _dlData.custom_difficult = '2.2';
#         _dlData.custom_rubric.push('Роботы и дроны');
#
#     window.dataLayer = window.dataLayer || [];
#     window.dataLayer.push(_dlData);
# </script>
#                                         <div class="share-mobile">
#                         <nav class="nav-share">
#     <ul class="social-likes">
# 		<li class="facebook"></li>
# 		<li class="twitter"></li>
# 		<li class="vkontakte"></li>
# 		<li class="odnoklassniki"></li>
#     </ul>
# </nav>
#                     </div>
#
#                     <header class="hero hero-lite">
#                         <div>
#                             <h1>Робота-ленивца научили лазать по паутине из тросов</h1>
#                         </div>
#                     </header>
#                                         <div class="body js-mediator-article">
#                                                                                                                             <div class="article-image">
#                             <figure>
#                                 <img src="https://nplus1.ru/images/2019/06/04/b32b62189fb87cce895e229e1d6d27b4.jpeg"/>
#                                                                 <figcaption>
#                                     <p class="title"></p>
#                                     <p class="credits">Allison Carter, Georgia Tech</p>
#                                 </figcaption>
#                                                             </figure>
#                         </div>
#
#                                                     <!-- -->
#                                                         <!-- -->
#
#                                                                                             <p>Американские инженеры разработали робота-ленивца, способного лазать по&nbsp;тросам и&nbsp;перемещаться с&nbsp;одного троса на&nbsp;другой. Благодаря относительно малому потреблению энергии и&nbsp;использованию солнечных панелей подобного робота можно практически неограниченное время использовать для наблюдений на деревьях в лесу, рассказывают авторы <a href="https://ieeexplore.ieee.org/document/8642808" target="_blank" rel="nofollow">статьи</a>, представленной на&nbsp;конференции ICRA 2019.</p>
# <p>Создание роботов, способных лазать по&nbsp;тросам&nbsp;— важная технологическая задача, наработки из&nbsp;которой потенциально применимы во&nbsp;многих областях. К&nbsp;примеру, в&nbsp;2016 году в&nbsp;России <a href="https://nplus1.ru/news/2016/09/28/robot" target="_blank">создали</a> робота для проверки высоковольтных линий электропередачи. Дрон спускает такого робота на&nbsp;грозозащитный трос, после чего тот самостоятельно перемещается вдоль основных проводов и&nbsp;осматривает&nbsp;их. Кроме того, потенциально таких роботов можно применять для исследований в&nbsp;густых лесах, в&nbsp;которых ветки соседних деревьев соприкасаются.</p>
# <p>Инженеры из&nbsp;Технологического института Джорджии под руководством Магнуса Эгерштедта (Magnus Egerstedt) вдохновились ленивцами и&nbsp;решили создать энергоэффективного робота, на&nbsp;основе которого можно было&nbsp;бы создать робота, способного лазать по&nbsp;веткам. Робот состоит из&nbsp;двух частей и передвигается благодаря колесу в&nbsp;каждой части, соприкасающемуся с&nbsp;тросом.<br></p>
# <p><iframe frameborder="0" src="//www.youtube.com/embed/Sx-WL6BIK3s" width="620" height="349" allowfullscreen="true" class="embed-responsive-item"></iframe><br></p>
# <p>Кроме того, в&nbsp;каждой части робота есть две полноценные шестерни и&nbsp;две связанные с&nbsp;ними, но&nbsp;с&nbsp;вырезанным сектором. Внутрь такой шестерни продет
# трос. При движении вперед шестерня расположена таким образом, чтобы трос не&nbsp;мог выйти за&nbsp;ее&nbsp;пределы. Если&nbsp;же роботу необходимо перейти на&nbsp;смежный трос, шестерня поворачивается так, чтобы вырез располагался горизонтально. Перемещаться между смежными тросами роботу помогает еще один двигатель в&nbsp;петле, соединяющей две части.<br></p>
# <p><div class="incut incut-gallery " data-id="20774">
#     <div class="swiper-container">
#         <div class="swiper-wrapper">
#                         <div class="swiper-slide">
#                 <figure>
#                     <div class="img">
#                         <img src="https://nplus1.ru/images/2019/06/04/e5fbb06230c74d541b319677af5ccd79.jpg"/>
#                     </div>
#                     <figcaption>
#                     <p class="title">Компоненты одной из двух частей робота</p>
#
#                                             	    <p class="credits">Gennaro Notomista et al. / IEEE Robotics and Automation Letters, 2019</p>
#
#                     </figcaption>
#                 </figure>
#                 <div class="share-incut">
# <div class="title"><i class="fa fa-share"></i><span>Поделиться</span></div>
# <nav class="nav-share">
#     <ul class="social-likes" data-title="Робота-ленивца научили лазать по паутине из тросов">
# 		<li class="facebook" data-service='facebook' data-image='https://nplus1.ru/images/2019/06/04/e5fbb06230c74d541b319677af5ccd79.jpg', data-description='Gennaro Notomista et al. / IEEE Robotics and Automation Letters, 2019'></li>
# 		<li class="twitter" data-service='twitter' data-image='https://nplus1.ru/images/2019/06/04/e5fbb06230c74d541b319677af5ccd79.jpg', data-description='Gennaro Notomista et al. / IEEE Robotics and Automation Letters, 2019'></li>
# 		<li class="vkontakte" data-service='vkontakte' data-image='https://nplus1.ru/images/2019/06/04/e5fbb06230c74d541b319677af5ccd79.jpg', data-description='Gennaro Notomista et al. / IEEE Robotics and Automation Letters, 2019'></li>
# 		<li class="odnoklassniki" data-service='odnoklassniki' data-image='https://nplus1.ru/images/2019/06/04/e5fbb06230c74d541b319677af5ccd79.jpg', data-description='Gennaro Notomista et al. / IEEE Robotics and Automation Letters, 2019'></li>
#             </ul>
# </nav>
# </div>
#             </div>
#                     </div>
#         <div class="pagination">
#             <div class="swiper-button-prev"></div>
#             <div class="swiper-counter"></div>
#             <div class="swiper-button-next"></div>
#         </div>
#     </div>
# </div>Для питания робот использует аккумулятор емкостью 1000 миллиампер-часов, а&nbsp;также две солнечные панели, располагающиеся по&nbsp;бокам одной из&nbsp;частей. Разработчики отмечают, что благодаря применению колес для движения по&nbsp;тросам, а&nbsp;также пассивному механизму удержания, робот имеет большую энергоэффективность, чем другие роботы, предназначенные для перемещения по&nbsp;тросам.<br></p>
# <p><div class="incut incut-gallery " data-id="20774">
#     <div class="swiper-container">
#         <div class="swiper-wrapper">
#                         <div class="swiper-slide">
#                 <figure>
#                     <div class="img">
#                         <img src="https://nplus1.ru/images/2019/06/04/54a85341c9518ba141a7bbbf5e4566e4.jpg"/>
#                     </div>
#                     <figcaption>
#                     <p class="title">Механизм блокировки троса</p>
#
#                                             	    <p class="credits">Gennaro Notomista et al. / IEEE Robotics and Automation Letters, 2019</p>
#
#                     </figcaption>
#                 </figure>
#                 <div class="share-incut">
# <div class="title"><i class="fa fa-share"></i><span>Поделиться</span></div>
# <nav class="nav-share">
#     <ul class="social-likes" data-title="Робота-ленивца научили лазать по паутине из тросов">
# 		<li class="facebook" data-service='facebook' data-image='https://nplus1.ru/images/2019/06/04/54a85341c9518ba141a7bbbf5e4566e4.jpg', data-description='Gennaro Notomista et al. / IEEE Robotics and Automation Letters, 2019'></li>
# 		<li class="twitter" data-service='twitter' data-image='https://nplus1.ru/images/2019/06/04/54a85341c9518ba141a7bbbf5e4566e4.jpg', data-description='Gennaro Notomista et al. / IEEE Robotics and Automation Letters, 2019'></li>
# 		<li class="vkontakte" data-service='vkontakte' data-image='https://nplus1.ru/images/2019/06/04/54a85341c9518ba141a7bbbf5e4566e4.jpg', data-description='Gennaro Notomista et al. / IEEE Robotics and Automation Letters, 2019'></li>
# 		<li class="odnoklassniki" data-service='odnoklassniki' data-image='https://nplus1.ru/images/2019/06/04/54a85341c9518ba141a7bbbf5e4566e4.jpg', data-description='Gennaro Notomista et al. / IEEE Robotics and Automation Letters, 2019'></li>
#             </ul>
# </nav>
# </div>
#             </div>
#                     </div>
#         <div class="pagination">
#             <div class="swiper-button-prev"></div>
#             <div class="swiper-counter"></div>
#             <div class="swiper-button-next"></div>
#         </div>
#     </div>
# </div>Кроме создания аппаратной платформы инженеры также написали для робота программное обеспечение, позволяющее ему самому прокладывать путь по&nbsp;тросам. Пользователь может указать точку, за&nbsp;которой необходимо наблюдать, после чего робот, имея карту системы тросов, самостоятельно рассчитает путь до&nbsp;наиболее близкой к заданной точке наблюдательной позиции.</p>
# <p>Ранее инженеры из&nbsp;Технологического института Джорджии <a href="https://nplus1.ru/news/2017/04/13/tarzan" target="_blank" title="Link: https://nplus1.ru/news/2017/04/13/tarzan">создали</a> другого робота-ленивца для работы на&nbsp;тросе. Он&nbsp;так&nbsp;же состоит из&nbsp;двух частей, но&nbsp;имеет совершенно другую конструкцию и&nbsp;принцип работы. Он&nbsp;способен зацепляться концом одной части за&nbsp;трос и&nbsp;раскачивать другую, чтобы затем зацепиться&nbsp;ей. После этого он&nbsp;может отпустить первую часть и&nbsp;снова начать раскачиваться для того, чтобы двигаться дальше.<br></p>
# <p><i>Григорий Копиев</i></p>
#
#
#
#
#                                             </div>
#                 </article>
#
#
# 				    <!-- ba1 -->
# <!--AdFox START-->
# <!--nplus1_dir-->
# <!--Площадка: https://nplus1.ru/ / * / *-->
# <!--Тип баннера: CLICKIO html5-->
# <!--Расположение: мобильный-->
# <div id="adfox_155980540701252236"></div>
# <script>
#     window.Ya.adfoxCode.createAdaptive({
#         ownerId: 248569,
#         containerId: 'adfox_155980540701252236',
#         params: {
#             pp: 'ssg',
#             ps: 'cggm',
#             p2: 'fpum',
#             puid1: ''
#         }
#     }, ['phone'], {
#         tabletWidth: 1024,
#         phoneWidth: 767,
#         isAutoReloads: false
#     });
# </script>
#
# 		                <meter class="bottom"></meter>
#             </div>
#             <div class="col col-1 sidebar" data-adaptive="1" data-tablet-class="col-full">
#                                 <nav class="nav-share">
#     <ul class="social-likes">
# 		<li class="facebook"></li>
# 		<li class="twitter"></li>
# 		<li class="vkontakte"></li>
# 		<li class="odnoklassniki"></li>
#     </ul>
# </nav>
#
#                 <meter class="top"></meter>
#                                         <div id="latest" data-adaptive="1" data-tablet-class="fixed" data-mobile-class="fixed">
#
#                 <div class="ad">
#                                                                 	                            	<!-- ba2 -->
# <!--AdFox START-->
# <!--nplus1_dir-->
# <!--Площадка: https://nplus1.ru/ / * / *-->
# <!--Тип баннера: CLICKIO html5-->
# <!--Расположение: <верх страницы>-->
# <div id="adfox_153934342663011746"></div>
# <script>
#     (function(w, n) {
#     w[n] = w[n] || [];
#     w[n].push({
#         ownerId: 248569,
#         containerId: 'adfox_153934342663011746',
#         params: {
#             pp: 'g',
#             ps: 'cggm',
#             p2: 'fpum',
#             puid1: ''
#         }
#     });})(window, 'adfoxAsyncParams');
# </script>
#
#
#                     	                                                                </div>
#
#
#                         <h2 class="_tablet-hidden _mobile-hidden">Свежее</h2>
#                         <div class="latest-container">
#                         <article class="item item-news item-news-latest-first  _exist-image" data-relevance="" data-image="" >
#
#     <a href="/news/2021/05/22/backtrack" data-id="29133" >
#         <div class="caption">
#                                                                     	                		<img src="https://nplus1.ru/images/2021/05/22/d4eecc4a244f80d36808528ad46b9da9.gif"/>
#
#
#
#                                     <div>
#                         <div class="date">
#                             <span class="name" title="2021-05-22">17:20</span>
#                         </div>
#                         <h3>Чехол с тачпадом подключили к смартфону через экран</h3>
#                     </div>
#
#
#
#
#
#                                                 </div>
#     </a>
#     </article>                                                                                <article class="item item-news item-news-  _exist-image" data-relevance="" data-image="" >
#
#     <a href="/news/2021/05/22/aerion" data-id="29134" >
#         <div class="caption">
#
#
#                                 <div class="date">
#                     <span class="name" title="2021-05-22">14:18</span>
#                 </div>
#
#                                     <h3>Разработчики закрыли проект сверхзвукового пассажирского самолета Aerion</h3>
#
#
#
#
#
#                                                 </div>
#     </a>
#     </article>                                                        <article class="item item-news item-news-  _exist-image" data-relevance="" data-image="" >
#
#     <a href="/news/2021/05/22/churong-on-mars-now" data-id="29132" >
#         <div class="caption">
#
#
#                                 <div class="date">
#                     <span class="name" title="2021-05-22">13:25</span>
#                 </div>
#
#                                     <h3>Китайский ровер &laquo;Чжужун&raquo; съехал на поверхность Марса</h3>
#
#
#
#
#
#                                                 </div>
#     </a>
#     </article>                                                        <article class="item item-news item-news-  _exist-image" data-relevance="" data-image="" >
#
#     <a href="/news/2021/05/22/change-5-lagrange-photos" data-id="29080" >
#         <div class="caption">
#
#
#                                 <div class="date">
#                     <span class="name" title="2021-05-22">12:20</span>
#                 </div>
#
#                                     <h3>&laquo;Чанъэ-5&raquo; прислал фотографии из первой точки Лагранжа</h3>
#
#
#
#
#
#                                                 </div>
#     </a>
#     </article>                                                        <article class="item item-news item-news-  _exist-image" data-relevance="" data-image="" >
#
#     <a href="/news/2021/05/22/crispr-edit-cholesterol" data-id="29131" >
#         <div class="caption">
#
#
#                                 <div class="date">
#                     <span class="name" title="2021-05-22">11:02</span>
#                 </div>
#
#                                     <h3>Генетическое редактирование спасло приматов от повышенного уровня холестерина</h3>
#
#
#
#
#
#                                                 </div>
#     </a>
#     </article>                                                </div>
#
#
#
#
#
#
#                     </div>
#
#
#
#                 </div>
#
#                 <footer class="article-footer">
#                     <div class="row">
#                         <div class="col col-3" data-adaptive="1" data-mobile-class="col-1">
#                             <p>Нашли опечатку? Выделите фрагмент и нажмите Ctrl+Enter.</p>
#                         </div>
#                         <div class="col col-1 _mobile-hidden _tablet-hidden">
#                             <nav class="nav-share">
#     <ul class="social-likes">
# 		<li class="facebook"></li>
# 		<li class="twitter"></li>
# 		<li class="vkontakte"></li>
# 		<li class="odnoklassniki"></li>
#     </ul>
# </nav>
#                         </div>
#                     </div>
#                 </footer>
#
#                 <div class="ad ad-footer">
#                     			                                                                                        </div>
#
#
#             </div>
#
#
#             <div class="row row-wrap">
#                             </div>
#             <div class="row row-wrap">
#                 <div class="col col-full" data-adaptive="1"  data-mobile-class="col-1">
#
#                                     </div>
#             </div>
#             <div class="row" data-adaptive="1" data-tablet-class="row-wrap" data-mobile-class="row-wrap" data-type="also">
#                 <div class="col col-3" data-adaptive="1" data-mobile-class="col-1">
#
#                                         <section id="also">
#                                                 <h4 class="pull-left">Читайте также</h4>
#                         <div class="col col-also">
#                                                             <article class="item item-news item-news-ill  _exist-image" data-relevance="" data-image="" >
#
#     <a href="/news/2021/05/21/Super-resolution-imaging" data-id="29102" >
#         <div class="caption">
#                             <div style="background-image:url(https://nplus1.ru/images/2021/05/20/15e8e4a42a659db94b6deea91a62b97a.jpg)" class="ill"></div>
#
#
#
#                                     <h3>Сверхвысокое разрешение в микроскопии стало возможно без флуоресценции</h3>
#
#
#
#
#
#                                                 </div>
#     </a>
#     </article>                                                            <article class="item item-news item-news-ill  _exist-image" data-relevance="" data-image="" >
#
#     <a href="/news/2021/05/22/backtrack" data-id="29133" >
#         <div class="caption">
#                             <div style="background-image:url(https://nplus1.ru/images/2021/05/22/d4eecc4a244f80d36808528ad46b9da9.gif)" class="ill"></div>
#
#
#
#                                     <h3>Чехол с тачпадом подключили к смартфону через экран</h3>
#
#
#
#
#
#                                                 </div>
#     </a>
#     </article>                                                            <article class="item item-news item-news-ill  _exist-image" data-relevance="" data-image="" >
#
#     <a href="/news/2021/05/21/borisov-metals" data-id="29109" >
#         <div class="caption">
#                             <div style="background-image:url(https://nplus1.ru/images/2021/05/20/60cda9165fbfbde447bfb2111316ad6b.jpg)" class="ill"></div>
#
#
#
#                                     <h3>Астрономы нашли в холодных комах комет атомы железа и никеля</h3>
#
#
#
#
#
#                                                 </div>
#     </a>
#     </article>                                                    </div>
#
#                     </section>
#                                     </div>
#                 <div class="col col-1" data-adaptive="1" data-tablet-class="col-full _indent-bottom">
#                     <section id="next">
#                         <div class="col col-1" data-adaptive="1" data-tablet-class="col-2">
#                                                         <article class="item item-article item-article-secondary  _exist-image" data-relevance="" data-image="https://nplus1.ru/images/2021/05/21/9161c8857ed9db7cc033f1ac24c029d8.gif" style=background-image:url(https://nplus1.ru/images/2021/05/21/e99abd8df46ef5ff6ffe6388cd655fdf.gif)>
#
#     <a href="/material/2021/05/21/sakharov-conditions" data-id="29117" >
#         <div class="caption">
#                                                                                     <h3>Вселенная вместо ничто</h3>
#                     <p class="subtitle">Как Андрей Сахаров отвечал на вопрос о причине существования материи</p>
#                                     </div>
#     </a>
#         <nav class="nav-rubricator">
#         <ul>
#
#                         <li>
#                 <a class="link-rubric" href="/rubric/physics">Физика</a>
#             </li>
#                                 </ul>
#     </nav>
#     </article>                                                    </div>
#                     </section>
#                 </div>
#             </div>
#         </div>
#     <!--/div-->
#
#     <div id="_mistake">
#         <input type="hidden" name="_token" value="8yGFLFG5nc5NQ2VoP6vwxIiLLVKt0h3WmFFXIdru">
#         <input type="hidden" name="id_news" value="20774">
#         <input type="hidden" name="id_author" value="102">
#         <input type="hidden" name="id_editor" value="0">
#     </div>
#     <div id="_post">
#         <input type="hidden" name="_token" value="8yGFLFG5nc5NQ2VoP6vwxIiLLVKt0h3WmFFXIdru">
#         <input type="hidden" name="id_news" value="20774">
#     </div>
#             </section>
#             <!-- / main section -->
#
#
#             <div id="wrapper-footer">
#             <section id="difficult" class="_middle">
#     <!-- Slider main container -->
#     <div class="swiper-container">
#         <!-- Additional required wrapper -->
#         <div class="swiper-wrapper">
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">9.1</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2021/05/15/proton-mass-radius">Физики извлекли из эксперимента массовый радиус протона</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">7.6</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/blog/2021/05/11/controllability-of-ionization-energy">Менделееву и не снилось: что может сделать фотонный кристалл с энергией ионизации атома </a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">7.4</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2021/05/21/Super-resolution-imaging">Сверхвысокое разрешение в микроскопии стало возможно без флуоресценции</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">7.2</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2021/05/13/z-genome">Геномы бактериальных вирусов с альтернативными нуклеотидами оказались не такими редкими</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">6.8</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2021/05/12/pb-neutron-skin">Ядро свинца оказалось &laquo;толстокожим&raquo;</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">6.4</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2021/05/14/5qubits-simulates-photon-transport">Квантовый симулятор справился с непривычной для него задачей</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">6.3</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/material/2021/05/21/sakharov-conditions">Вселенная вместо ничто</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">6.1</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/blog/2021/05/14/chnpp-neutron-stream">Эффект просушки: что происходит с радиоактивной лавой под реактором в Чернобыле</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">5.5</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2021/05/21/polypept">Из полипептидов сделали перерабатываемые аккумуляторы </a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">5.4</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2021/05/21/tusayan-neural-networks">Археологи научили нейросеть классифицировать древнюю керамику</a></h3>
#             </div>
#
#         </div>
#         <!-- If we need pagination -->
#         <div class="swiper-pagination"></div>
#         <div class="swiper-button-prev"></div>
#         <div class="swiper-button-next"></div>
#     </div>
#     <h6>Самое сложное</h6>
# </section>
#
#
#             <div class="ad ad-col border">
#                     	    </div>
#
#             <!-- footer -->
#             <footer id="footer">
#     <div class="row" data-adaptive="1" data-middle-class="row-wrap" data-tablet-class="row-wrap" data-mobile-class="row-wrap">
#         <div class="col col-logo">
#             <a href="/" class="link-logo"><img src="/i/logo-alt.png"/></a>
#         </div>
#         <div class="col col-footer-desc">
#             <nav class="nav-pages">
#                 <ul>
#                     <li>
#                         <a href="/about">О нас</a>
#                     </li>
#                     <li>
#                         <a href="https://nplus.pro" target="_blank">N + Production</a>
#                     </li>
#                     <li>
#                         <a href="/adv">Рекламодателям</a>
#                     </li>
#                     <li>
#                         <a href="/rules">Наши материалы</a>
#                     </li>
#                     <li>
#                         <a href="/vacancy">Вакансии</a>
#                     </li>
#                     <li>
#                         <a href="/difficult">Сложность</a>
#                     </li>
#                 </ul>
#             </nav>
#             <div class="desc">
#                 <p>&copy; 2021 <i>N&nbsp;+&nbsp;1</i> Интернет-издание &nbsp; Свидетельство о регистрации СМИ Эл № ФС77-67614</p>
#
#                     <p>Использование всех текстовых материалов без изменений в некоммерческих целях разрешается со ссылкой на <i>N&nbsp;+&nbsp;1</i>.
#                         Все аудиовизуальные произведения являются собственностью своих авторов и правообладателей и используются
#                         только в образовательных и информационных целях. Если вы являетесь собственником того или иного произведения
#                         и не согласны с его размещением на нашем сайте, пожалуйста, напишите на kirill@nplus1.ru</p>
#                     <p>Материалы, опубликованные в разделе «Блоги», отражают позиции их авторов, которые могут не совпадать с мнением редакции.</p>
#                     <p>Сайт может содержать контент, не предназначенный для лиц младше 18 лет.</p>
#                     <p>
#                         <a href="https://nplus1.ru/personal-data-policy" class="pd">Политика обработки персональных данных пользователей сайта</a>
#                     </p>
#                     <p>
#                         <script async type="text/javascript" src="//s.luxupcdnc.com/t/consent_195458.js"></script>
#                         <a href="#" onclick="if(window.__lxG__consent__ !== undefined) {window.__lxG__consent__.showConsent()} else {alert('This function works only for users from the European Economic Area (EEA).')}; return false">Change privacy settings</a>
#                     </p>
#
#                 <p>
#                                     </p>
#             </div>
#         </div>
#         <div class="col col-1 pull-right">
#             <nav class="nav-social">
#                 <ul>
#                     <li>
#                         <a href="https://t.me/nplusone"><i class="fa fa-telegram"></i></a>
#                     </li>
#                     <li>
#                         <a href="http://vk.com/nplusone"><i class="fa fa-vk"></i></a>
#                     </li>
#                     <li>
#                         <a href="https://www.facebook.com/nplusone"><i class="fa fa-facebook"></i></a>
#                     </li>
#                     <li>
#                         <a href="https://twitter.com/nplusodin"><i class="fa fa-twitter"></i></a>
#                     </li>
#                     <li>
#                         <a href="https://ok.ru/nplus1"><i class="fa fa-odnoklassniki"></i></a>
#                     </li>
#                     <li>
#                         <a href="https://soundcloud.com/nplus_1"><i class="fa fa-soundcloud"></i></a>
#                     </li>
#                     <li>
#                         <a href="/rss"><i class="fa fa-rss"></i></a>
#                     </li>
#                 </ul>
#             </nav>
#             <div class="partners">
#
#
#                 <!-- Rating@Mail.ru counter -->
# <script type="text/javascript">
# var _tmr = window._tmr || (window._tmr = []);
# _tmr.push({id: "3084572", type: "pageView", start: (new Date()).getTime()});
# (function (d, w, id) {
#   if (d.getElementById(id)) return;
#   var ts = d.createElement("script"); ts.type = "text/javascript"; ts.async = true; ts.id = id;
#   ts.src = "https://top-fwz1.mail.ru/js/code.js";
#   var f = function () {var s = d.getElementsByTagName("script")[0]; s.parentNode.insertBefore(ts, s);};
#   if (w.opera == "[object Opera]") { d.addEventListener("DOMContentLoaded", f, false); } else { f(); }
# })(document, window, "topmailru-code");
# </script><noscript><div>
# <img src="https://top-fwz1.mail.ru/counter?id=3084572;js=na" style="border:0;position:absolute;left:-9999px;" alt="Top.Mail.Ru" />
# </div></noscript>
# <!-- //Rating@Mail.ru counter -->
#
#
#
#             </div>
#         </div>
#     </div>
# </footer>            <!-- / footer -->
#             </div>
#         </div>
#
#     </div>
#
#
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-MNJC58');</script>
# <!-- End Google Tag Manager -->
#
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-MNJC58"
# height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
#
#
#
#     <noscript><div><img src="//mc.yandex.ru/watch/29654565" style="position:absolute; left:-9999px;" alt="" /></div></noscript>
#
#
# 	</div>
#
#
#
# <script src="/js/lib/js.cookie.js"></script>
# <script src="/js/lib/jquery.swap.js"></script>
# <script src="/js/lib/swiper.jquery.min.js"></script>
# <script src="/js/lib/svg.js"></script>
# <script src="/js/lib/jquery.mobile-events.min.js"></script>
# <script src="/js/lib/social-likes.min.js"></script>
# <script src="/js/lib/jquery.sticky.js"></script>
#
#
# <script src="/js/lib/ts.js"></script>
# <script src="/js/lib/js.cookie.js"></script>
# <script type="text/javascript" async src="https://relap.io/api/v6/head.js?token=sTVMyshMYp9i7-rv"></script>
#
#
# <script async src="https://cdn.onthe.io/io.js/QCyUUwp6IVuR"></script>
# <script>
# window._io_config = window._io_config || {};
# window._io_config["0.2.0"] = window._io_config["0.2.0"] || [];
# window._io_config["0.2.0"].push({
#     page_url: document.location.toString(),
#     page_url_canonical: document.querySelector('link[rel="canonical"]').href,
#     page_title: document.querySelector('title').innerHTML,
#     page_type: "article",
#     page_language: "ru",
#     article_authors: [document.querySelector('meta[name="author"]').content || ''],
#     article_publication_date: (new Date(document.querySelector('meta[itemprop="datePublished"]').content).toUTCString()).toString()
# });
# </script>
#
# <!--   project scripts -->
# <script src="/js/main.min.js?v=1592278962"></script>
# <!-- / project scripts -->
#
#
#
#
# <!-- Quantcast Tag -->
# <script type="text/javascript">
# var _qevents = _qevents || [];
#
# (function() {
# var elem = document.createElement('script');
# elem.src = (document.location.protocol == "https:" ? "https://secure" : "http://edge") + ".quantserve.com/quant.js";
# elem.async = true;
# elem.type = "text/javascript";
# var scpt = document.getElementsByTagName('script')[0];
# scpt.parentNode.insertBefore(elem, scpt);
# })();
#
# _qevents.push({
# qacct:"p-s3ftDEFzEW5x7"
# });
# </script>
#
# <noscript>
# <div style="display:none;">
# <img src="//pixel.quantserve.com/pixel/p-s3ftDEFzEW5x7.gif" border="0" height="1" width="1" alt="Quantcast"/>
# </div>
# </noscript>
# <!-- End Quantcast tag -->
# </body>
# </html>

# %% [markdown]
# Мы получили большую строку с текстом в формате html, который используется для визуальной разметки. Это позволяет делать информацию более наглядной для людей, но в отличие от json, мы не можем просто преобразовать его напрямую в словарь. Далее мы посмотрим, как извлекать информацию из подобных страниц

# %% [markdown]
# # Основы HTML
#
# Прежде чем перейти к поиску информации в html, давайте вспомним, что он из себя представляет.
#
# HTML – формат разметки страниц, созданный специально для интернета. Он позволяет разбивать страницу на блоки: мы размечаем, что окажется в боковой колонке, а что – посередине  и т.д.  Также он используется для описания стилей отображения: например, что будет отображаться как заголовок с большим текстом, а что – как обычный текст.
#
# HTML является близким родственником XML. Разметка делается с помощью так называемых тэгов, которые помещаются в угловые скобки, и сами, в свою очередь, являются как бы скобками для текста внутри.
#
#     <h2> Это заголовок </h2>
#     <div> А это обычный текст </div>
#
# У корректной html страницы есть заголовок (head) и тело страницы (body). В заголовке заключается техническая информация, подключаются скрипты и стили. В теле находится текст и данные, которые непосредственно  отображаются на странице в браузере.
#
# Разметка небольшой страницы выглядит примерно так:
#
#     <!DOCTYPE html>
#     <html lang="ru">
#         <header>
#             <title>Название страницы</title>
#             <meta charset="UTF-8">
#         </header>
#
#         <body>
#             <h1>Заголовок страницы</h1>
#             <p>Какой-то текст</p>
#         </body>
#     </html>
#
# Тут стоит заметить, что тэги образуют иерархическую структуру, т.е. одни тэги расположены внутри других. В примере выше тэг
#
#     <p> находится внутри тэга <body>
#
# Кроме того, у тэгов могут быть атрибуты, они пишутся внутри открывающегося тэга. Самые популярные атрибуты – это class и id.
#
#     <h1 id="big-title">Заголовок страницы</h1>
#     <p class="red-back">Какой-то текст</p>
#
# К счастью, нам и не нужно как-то подробно знать html, чтобы забирать информацию. Достаточно понимать, что:
#
#  - есть тэги с разными именами;
#  - у тэгов бывают атрибуты, вроде class и id;
#  - тэги образуют иерархическую структуру, то есть одни тэги вложены в другие.

# %% [markdown]
# # Библиотека BeautifulSoup
#
# Для поиска данных на странице воспользуемся библиотекой BeautifulSoup. Она позволяет по названию тэгов и их атрибутов получать содержащийся в них текст.
#
# Она не является частью стандартной библиотеки, поэтому для начала её нужно установить с помощью пакетного менеджера, например, введя в консоли:

# %%
# !pip install --user beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.6/site-packages (4.8.1)
# Requirement already satisfied: soupsieve>=1.2 in /opt/conda/lib/python3.6/site-packages (from beautifulsoup4) (1.9.3)

# %% [markdown]
# Теперь мы можем получать данные из страницы. Давайте получим title (это строка, отображающая в браузерах на закладках)

# %%
# Импортируем наши библиотеки    
from bs4 import BeautifulSoup    
import requests    
    
# Получаем данные, как и ранее    
url = 'https://nplus1.ru/news/2019/06/04/slothbot'   
response = requests.get(url)    
    
# Теперь создадим объект BeautifulSoup, указывая html парсер    
page = BeautifulSoup(response.text, 'html.parser')    
    
# Всё готово, чтобы получать данные из страницы    
# Для начала получим title, отображающийся на закладках браузера    
print(page.title)  
# => <title>Робота-ленивца научили лазать по паутине из тросов</title>  
    
# Мы получили тэг. Чтобы достать из него текст, вызовем атрибут text    
page.title.text    
# => 'Робота-ленивца научили лазать по паутине из тросов'
# Out:
# <title>Робота-ленивца научили лазать по паутине из тросов</title>
# 'Робота-ленивца научили лазать по паутине из тросов'

# %% [markdown]
# # Данные со страницы
#
# ## Читаем заголовок
#
# Мы получили данные из title, но как нам забрать текст с самой страницы? Мы можем сделать это, запросив содержимое определённых тэгов.
#
# Пусть мы знаем, что заголовок статьи находится в тэге h1. Тогда мы можем получить его текст с помощью метода find

# %%
print(page.find('h1').text)
# Out:
# Робота-ленивца научили лазать по паутине из тросов

# %% [markdown]
# Воспользовавшись этим подходом, давайте получим время написания статьи. Смотрим, в каком она тэге
#
# Видим, что это тэг time. Получим данные.

# %%
print(page.find('time').text)
# Out:
# 18:27
# 04 Июнь 2019

# %% [markdown]
# **Задание 2** - Автоматический сбор заголовков
#
# Напишите функцию wiki_header, которая по адресу страницы возвращает заголовок для статей на википедии

# %%
def wiki_header(url):
    response = requests.get(url)
    page = BeautifulSoup(response.text, 'html.parser') 
    
    return page.find('h1').text

# %%
wiki_header('https://en.wikipedia.org/wiki/Operating_system')
# => 'Operating system'
# Out:
# 'Operating system'

# %% [markdown]
# # Больше данных
#
# **Больше данных**
#
# Мы рассмотрели базовый поиск конкретного элемента. Могут встречаться другие вариации:
#
# когда нам нужно получить много похожих элементов;
# когда тэг атрибута неуникальный, тогда нам нужно использовать атрибуты (id, class), либо использовать вложенность.
# Посмотрим на практике, что делать в случае, когда тэг элемента неуникальный. Пусть мы хотим получить сам текст статьи. Мы видим, что он находится в тэге div
#
# Тэги div очень распространённые, их много на странице. Если мы просто используем find, то получим первый попавшийся, но это не то, что нам надо.

# %%
print(page.find('div').text)  
# window.Ya.adfoxCode.create({  
#     ownerId: 248569,  
#     containerId: 'adfox_15000335664353901',  
#     params: {  
#         pp: 'g',  
# ...

# %% [markdown]
# Тут мы можем заметить, что у искомого текста есть свой класс GeneralMaterial-body. Воспользуемся этим:  в метод find можно передать аргумент class_

# %%
print(page.find('div', class_='body').text)  
# => Allison Carter, Georgia Tech  
# Американские инженеры&nbsp;разработали робота-ленивца, способного лазать  
# ...
# Out:
# Allison Carter, Georgia Tech
#
#
#
#
#
# Американские инженеры разработали робота-ленивца, способного лазать по тросам и перемещаться с одного троса на другой. Благодаря относительно малому потреблению энергии и использованию солнечных панелей подобного робота можно практически неограниченное время использовать для наблюдений на деревьях в лесу, рассказывают авторы статьи, представленной на конференции ICRA 2019.
# Создание роботов, способных лазать по тросам — важная технологическая задача, наработки из которой потенциально применимы во многих областях. К примеру, в 2016 году в России создали робота для проверки высоковольтных линий электропередачи. Дрон спускает такого робота на грозозащитный трос, после чего тот самостоятельно перемещается вдоль основных проводов и осматривает их. Кроме того, потенциально таких роботов можно применять для исследований в густых лесах, в которых ветки соседних деревьев соприкасаются.
# Инженеры из Технологического института Джорджии под руководством Магнуса Эгерштедта (Magnus Egerstedt) вдохновились ленивцами и решили создать энергоэффективного робота, на основе которого можно было бы создать робота, способного лазать по веткам. Робот состоит из двух частей и передвигается благодаря колесу в каждой части, соприкасающемуся с тросом.
#
# Кроме того, в каждой части робота есть две полноценные шестерни и две связанные с ними, но с вырезанным сектором. Внутрь такой шестерни продет
# трос. При движении вперед шестерня расположена таким образом, чтобы трос не мог выйти за ее пределы. Если же роботу необходимо перейти на смежный трос, шестерня поворачивается так, чтобы вырез располагался горизонтально. Перемещаться между смежными тросами роботу помогает еще один двигатель в петле, соединяющей две части.
#
#
#
#
#
#
#
#
#
# Компоненты одной из двух частей робота
# Gennaro Notomista et al. / IEEE Robotics and Automation Letters, 2019
#
#
#
# Поделиться
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Для питания робот использует аккумулятор емкостью 1000 миллиампер-часов, а также две солнечные панели, располагающиеся по бокам одной из частей. Разработчики отмечают, что благодаря применению колес для движения по тросам, а также пассивному механизму удержания, робот имеет большую энергоэффективность, чем другие роботы, предназначенные для перемещения по тросам.
#
#
#
#
#
#
#
#
#
# Механизм блокировки троса
# Gennaro Notomista et al. / IEEE Robotics and Automation Letters, 2019
#
#
#
# Поделиться
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Кроме создания аппаратной платформы инженеры также написали для робота программное обеспечение, позволяющее ему самому прокладывать путь по тросам. Пользователь может указать точку, за которой необходимо наблюдать, после чего робот, имея карту системы тросов, самостоятельно рассчитает путь до наиболее близкой к заданной точке наблюдательной позиции.
# Ранее инженеры из Технологического института Джорджии создали другого робота-ленивца для работы на тросе. Он так же состоит из двух частей, но имеет совершенно другую конструкцию и принцип работы. Он способен зацепляться концом одной части за трос и раскачивать другую, чтобы затем зацепиться ей. После этого он может отпустить первую часть и снова начать раскачиваться для того, чтобы двигаться дальше.
# Григорий Копиев

# %% [markdown]
# Отлично, сработало. Аналогично работает и с id, мы могли бы написать что-то вроде page.find('div', id='maincontent')

# %% [markdown]
# **Задание 1.** Поиск элемента
#
# У вас есть переменная page, в которой хранится содержимое html-страницы. На странице есть элемент в тэге span, у которого атрибут id равен 'target'. Напишите строчку кода, которая присвоит текст этого элемента переменной value.
#
# Запишите ваш код в одну строку без пробелов. Используйте апострофы для передачи параметров, содержащих значение тэга и его id.

# %%
value = page.find('span', id='target').text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-92295c402b83> in <module>
# ----> 1 value = page.find('span', id='target').text
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %% [markdown]
# # Сбор нескольких элементов
#
# **Собираем все ссылки на странице**
#
# Рассмотрим случай, когда нам нужно сразу много элементов. Пусть мы хотим получить название всех ссылок на странице [https://en.wikipedia.org/wiki/List_of_programming_languages] в википедии про языки программирования.
#
# Для ссылок существует тэг
#
#     <a></a>
# Давайте попробуем использовать find

# %%
url = 'https://en.wikipedia.org/wiki/List_of_programming_languages'  

response = requests.get(url)  
page = BeautifulSoup(response.text, 'html.parser')  
page.find('a')
# Out:
# <a id="top"></a>

# %% [markdown]
# Что-то пошло не так, и мы получили только одну ссылку, хотя на странице их явно больше. Это происходит, потому что метод find возвращает только первый подходящий элемент. Если нам надо их больше, нужно воспользоваться методом find_all

# %%
links = page.find_all('a')  
# Посмотрим, сколько всего мы получили  
print(len(links))
# => 935
  
# Посмотрим на некоторые из ссылок  
print([link.text for link in links[500:510]])  
# => ['Oxygene', 'Oz', 'edit', 'P', 'P4', 'P′′', 'ParaSail (programming language)', 'PARI/GP', 'Pascal', 'Pascal Script']
# Out:
# 927
# ['Orwell', 'Oxygene', 'Oz', 'edit', 'P', 'P4', 'P′′', 'ParaSail (programming language)', 'PARI/GP', 'Pascal']

# %% [markdown]
# Ещё одна полезная вещь:  последовательный поиск, т.е. мы можем найти сначала один элемент, а потом сделать внутри него второй поиск. Давайте выведем названия всех ссылок для языков программирования, которые начинаются на литеру "A".

# %%
# Получаем все элементы с тегом 'div' и классом 'div-col'  
all_blocks = page.find_all('div', class_='div-col')  
  
# Выбираем первый по счету блок  
first_block = all_blocks[0]  
# Берём оттуда ссылки (ограничимся первыми десятью)
links = first_block.find_all('a')
print([link.text for link in links[:10]])
# => ['1C:Enterprise programming language']
# Out:
# ['A.NET (A#/A sharp)', 'A-0 System', 'A+ (A (plus)', 'ABAP', 'ABC', 'ABC ALGOL', 'ACC', 'Accent (Rational Synergy)', 'Ace DASL (Distributed Application Specification Language)', 'Action!']

# %% [markdown]
# В заключение заметим, что **BeautifulSoup** – достаточно мощная библиотека. Мы рассмотрели базовые возможности, но полный список гораздо шире. С ним можно ознакомиться в официальной документации [https://www.crummy.com/software/BeautifulSoup/bs4/doc/].

# %% [markdown]
# **Задание 1 - Актёры**
#
# Напишите функцию get_actors, которая по ссылке на страницу фильма на кинопоиске (https://www.kinopoisk.ru/lists/films/?is-redirected=1) возвращает список актёров из колонки справа.
#
# **NB: Если делать запросы слишком часто, Кинопоиск начинает выдавать капчу, поэтому старайтесь при отладке не делать больше одного запроса в секунду.**
#
# **ВНИМАНИЕ! В настоящий момент времени на сайте Кинопоиска изменилась структура контента и применяется более интеллектуальная капча. Задание находится на стадии доработки и не обязательно для выполнения.**

# %%
url_1 = 'https://www.kinopoisk.ru/film/326/'
url_2 = 'https://www.kinopoisk.ru/film/327/'
url_3 = 'https://www.kinopoisk.ru/film/328/'

# %%
# Импортируем наши библиотеки    
from bs4 import BeautifulSoup    
import requests    

def get_actors(url):
    # Получаем данные
    response = requests.get(url)    

    # Теперь создадим объект BeautifulSoup, указывая html парсер    
    page = BeautifulSoup(response.text, 'html.parser')   
    
    actors = page.find_all('a', itemprop='actor')
    
    return [actor.text for actor in actors]

# %%
print(get_actors(url_3))

# %%
get_actors('https://www.kinopoisk.ru/film/42326/')
# => ['Мария Виноградова', 'Олег Табаков', 'Лев Дуров', 'Борис Новиков', 'Герман Качин', 'Валентина Талызина']

# %%
get_actors('https://www.kinopoisk.ru/film/326/')
# => ['Тим Роббинс', 'Морган Фриман', 'Боб Гантон', 'Уильям Сэдлер', 'Клэнси Браун', 'Джил Беллоуз', 
# 'Марк Ролстон', 'Джеймс Уитмор', 'Джеффри ДеМанн', 'Ларри Бранденбург', '...', 'Диомид Виноградов', 
# 'Игорь Старосельцев', 'Никита Прозоровский', 'Олег Вирозуб', 'Василий Дахненко', '...']

# %% [markdown]
# # HTML-таблицы
#
# Постановка задачи
#
# При работе с web-страницами было бы здорово получать содержимое  таблиц в виде датафрейма. Рассмотрим страницу Центрального банка РФ cbr.ru. Наша задача будет состоять в том, чтобы получить одну из таблиц виджетов в виде датафрейма. Например, таблицу цен на драгоценные металлы.

# %% [markdown]
# Метод read_html из pandas умеет автоматически находить на HTML-странице таблицы и возвращать их списком из датафреймов:

# %%
import pandas as pd  

url = 'https://www.cbr.ru/key-indicators/'  
# Таблица с драгметаллами оказалась второй по счёту  
pd.read_html(url)[1]
# Out:
#                  0           1           2
# 0  рублей за грамм  21.05.2021  22.05.2021
# 1       Золото  Au    4 423,47    4 441,88
# 2      Серебро  Ag        6564        6577
# 3      Платина  Pt    2 851,41    2 822,23
# 4     Палладий  Pd    6 772,40    6 699,55

# %% [markdown]
# Если этого не происходит, но вы уверены в том, что порядок таблиц на странице неизменен, то можно вручную найти нужную таблицу на странице. Этому случаю посвящены следующие шаги.

# %% [markdown]
# **Задание 1 - Курсы валют через read_html**
#
# Попробуйте запустить pandas для заданного выше url. Какая строчка вернёт таблицу с курсами валют?

# %%
pd.read_html(url)[0]
# Out:
#                  0           1           2
# 0           валюта  21.05.2021  22.05.2021
# 1  Доллар США  USD      736007      735803
# 2        Евро  EUR      897708      899446

# %% [markdown]
# **Поиск таблицы с помощью BeautifulSoup**
#
# Более надёжным решением является сначала получить только текст таблицы и передавать в pandas только её. Так же, как и в предыдущем разделе, используем requests и BeautifulSoup, чтобы получить данные со страницы.
#
# А теперь — внимание! В случае работы с сайтом Центробанка нам нужно будет учесть ещё один нюанс. С недавнего времени администраторы стали блокировать обращения к сайту, поступающие не от «живых» пользователей, а от компьютерных программ (в том числе от той, которую мы собираемся написать прямо сейчас). Есть ли шанс в таких условиях всё-таки получить данные, не открывая страницу в браузере?
#
# Безусловно, это возможно. Безвыходных положений вообще не бывает, особенно в программировании! Один из способов справиться с ситуацией — «притвориться» браузером :).
#
# Каждый запрос, отправляемый с помощью команды get, имеет заголовок. Если заголовок не задан явно, то он создаётся автоматически, и туда добавляется информация в том числе о том, кто является субъектом (или источником) запроса — человек или программа. Чтобы «притвориться» браузером, нам просто нужно вручную дописать нужные сведения в этот заголовок. Подробнее о таком подходе можно почитать в этой статье (https://habr.com/ru/company/ods/blog/346632/).
#
# Итоговый вариант кода после добавления заголовка должен выглядеть так:

# %%
from bs4 import BeautifulSoup  
import pandas as pd  
import requests  
  
url = 'https://www.cbr.ru/key-indicators/'
soup = BeautifulSoup(requests.get(url, headers={'User-Agent': 'Mozilla/5.0'}).text, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
# <meta content="telephone=no" name="format-detection">
# <meta content="ru" name="zoom:lang">
# <title>Ключевые показатели | Банк России</title>
# <meta content="/common/images/share-1.jpg" property="og:image"/>
# <link href="/common/libs/jquery-ui/jquery-ui.min.css?v=v3348762655" media="all" rel="stylesheet" type="text/css"/>
# <!--[if IE 9]><link rel="stylesheet" type="text/css" href="/common/style/main-ie9.css?v=v2888097257" media="all"><![endif]-->
# <!--[if gt IE 9]><!--><link href="/common/style/main.css?v=v3078198100" media="all" rel="stylesheet" type="text/css"/><!--<![endif]-->
# <script src="/common/libs/jquery-3.4.1.min.js?v=v906141912" type="text/javascript"></script>
# <script src="/common/libs/jquery-ui/jquery-ui.min.js?v=v906141912" type="text/javascript"></script>
# <script src="/common/libs/jquery.inputmask.min.js?v=v089173232" type="text/javascript"></script>
# <script src="/common/scripts/vendor.js?v=v4054459027" type="text/javascript"></script>
# <script src="/common/libs/jquery.floatThead.min.js?v=v3348762655" type="text/javascript"></script>
# <script src="/common/scripts/main.min.js?v=v3111727806" type="text/javascript"></script>
# <script src="/common/libs/localization-ru.js?v=v2635091603" type="text/javascript"></script>
# <script src="/js/jquery.cookie.min.js?v=v4260771145" type="text/javascript"></script>
# <script src="/js/site.js?v=v2009763665" type="text/javascript"></script>
# <script type="text/javascript">
#     $(function () {
#         var $menu = $('[data-menu]'),
#             $menuItemBtn = $menu.find('[data-menu-item-btn]'),
#             $menuShow = $('[data-menu-show]'),
#             $menuClose = $('[data-menu-close]');
#         var config = $menu.data('config');
#
#         $menu.find('.header_right').html($('#header .header_right').html());
#
#         $menuShow.on('click.cms_loadwholesite', function (event) {
#             loadWholeSite(true);
#         });
#         $menuShow.on('mouseenter.cms_loadwholesite', function (event) {
#             loadWholeSite(false);
#         });
#
#         var xhr = null, g_openMenu = false;
#         function loadWholeSite(openmenu) {
#             g_openMenu = g_openMenu || openmenu;
#             $menuShow.off('click.cms_loadwholesite mouseenter.cms_loadwholesite');
#             if (xhr === null) {
#                 $('.menu_wrap .networks-circle').html($('.networks-circle.footer_networks').html());
#                 $('.menu_wrap .header_search').html($('.header .offsetMenu .header_search').html());
#
#                 xhr = $.ajax(config.url, {
#                     dataType: "html",
#                     method: "get",
#                     success: function (html) {
#                         $('[data-cms-wholesite-placeholder]').replaceWith(html);
#
#                         $menu.find('.menu_tab[data-tabs-tab]').each(function () {
#                             var tab = $(this).data('tabs-tab');
#                             $(this).toggle($menu.find('[data-tabs-content="' + tab + '"]').length != 0);
#                         });
#
#                         app.init($menu);
#
#                         for (var i in config.catalogPath) {
#                             $menu.find('li[data-catalog-id="' + config.catalogPath[i] + '"]')
#                                 .addClass("_active");
#                             $menu.find('li[data-catalog-id="' + config.catalogPath[i] + '"]')
#                                 .closest('[data-tabs-content]')
#                                 .trigger('open-anchor');
#                         }
#
#
#                         xhr = true;
#                     },
#                     error: function () {
#                         xhr = null;
#                     }
#                 });
#             }
#         }
#     });
#     </script>
# <script>
#     if (window.localStorage) {
#         if (localStorage.getItem('vision-impaired'))
#             document.getElementsByTagName('html')[0].className += ' vision-impaired';
#     }
# </script>
# <script>
#     document.documentElement.style.setProperty('--scrollbar-width', '17px');
#     setTimeout(function () {
#
#         var div = document.createElement('div');
#
#         div.style.overflowY = 'scroll';
#         div.style.width = '50px';
#         div.style.height = '50px';
#
#
#         div.style.visibility = 'hidden';
#
#         document.body.appendChild(div);
#         var scrollWidth = Math.max(div.offsetWidth - div.clientWidth, 0.15);
#         document.body.removeChild(div);
#
#         document.documentElement.style.setProperty('--scrollbar-width', scrollWidth + 'px');
#     }, 0);
# </script>
# </meta></meta></head>
# <body>
# <!-- Yandex.Metrika counter -->
# <script type="text/javascript">
#        (function(m,e,t,r,i,k,a){m[i]=m[i]||function(){(m[i].a=m[i].a||[]).push(arguments)};
#        m[i].l=1*new Date();k=e.createElement(t),a=e.getElementsByTagName(t)[0],k.async=1,k.src=r,a.parentNode.insertBefore(k,a)})
#        (window, document, "script", "https://mc.yandex.ru/metrika/tag.js", "ym");
#
#        ym(5774506, "init", {
#             clickmap:true,
#             trackLinks:true,
#             accurateTrackBounce:true,
#             webvisor:true
#        });
#     </script>
# <noscript><div><img alt="" src="https://mc.yandex.ru/watch/5774506" style="position:absolute; left:-9999px;"/></div></noscript>
# <!-- /Yandex.Metrika counter -->
# <div class="header-print">
# <div class="offsetMenu">
# <div class="header-print_inner">
# <img alt="cbr" class="header-print_logo" src="/common/images/logo.svg"/>
# <ul class="header-print_contacts">
# <li>ул. Неглинная, 12, Москва, 107016</li>
# <li><nobr class="phone">8 800 300-30-00</nobr></li>
# <li>www.cbr.ru</li>
# </ul>
# </div>
# </div>
# </div>
# <header class="header" id="header">
# <div class="top-line" data-top-line="">
# <div class="offsetMenu">
# <div class="col-md-23 offset-md-1">
# <div class="top-line_inner header_inner">
# <div class="row">
# <div class="col-xl-5 col-md-9">
# <div class="header_left">
# <div class="header_menu" data-menu-show=""></div>
# <a class="header_logo" href="/"></a>
# </div>
# </div>
# <div class="col-xl-17 col-md-13 offset-md-1 header_block">
# <div class="header_search">
# <a class="header_search_btn" data-search-form-show="" href="#" title="поиск">
# <div class="header_search_icon"></div><span class="d-none d-xl-block">Поиск по сайту</span>
# </a>
# </div>
# <div class="d-none d-md-block">
# <div class="header_right">
# <div class="header_link"><a href="/reception/">Интернет-приемная</a></div>
# <div class="header_lang">
# <div class="header_lang_item _active"><span><!--noindex-->RU<!--/noindex--></span></div>
# <div class="header_lang_item"><a href="/Localization/SwitchLanguage?url=%2Fkey-indicators%2F&amp;from=ru-RU&amp;to=en-GB"><!--noindex-->EN<!--/noindex--></a></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="offsetMenu">
# <div class="col-md-23 offset-md-1">
# <div class="header_inner">
# <div class="row">
# <div class="col-xl-5 col-md-9">
# <div class="header_left">
# <div class="header_menu" data-menu-show=""></div>
# <a class="header_logo" href="/"></a>
# </div>
# </div>
# <div class="col-xl-17 col-md-13 offset-md-1 header_block">
# <div class="header_search">
# <a class="header_search_btn" data-search-form-show="" href="#" title="поиск">
# <div class="header_search_icon"></div><span class="d-none d-xl-block">Поиск по сайту</span>
# </a>
# </div>
# <div class="d-none d-md-block">
# <div class="header_right">
# <div class="header_link"><a href="/reception/">Интернет-приемная</a></div>
# <div class="header_lang">
# <div class="header_lang_item _active"><span><!--noindex-->RU<!--/noindex--></span></div>
# <div class="header_lang_item"><a href="/Localization/SwitchLanguage?url=%2Fkey-indicators%2F&amp;from=ru-RU&amp;to=en-GB"><!--noindex-->EN<!--/noindex--></a></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </header>
# <form action="/search/" class="search-form" data-search-form="" method="get">
# <div class="offsetMenu">
# <div class="col-md-23 offset-md-1">
# <div class="search-form_inner">
# <div class="search-form_title">Что вы хотите найти?</div>
# <div class="search-form_content">
# <div class="search-form_block">
# <div class="search-form_icon"></div>
# <div class="search-form_field">
# <input data-search-form-input="" name="text" placeholder="Начните писать" type="text"/>
# </div>
# </div>
# <div class="search-form_btn">
# <button class="b-btn _blue" data-search-form-btn="">Искать</button>
# </div>
# </div>
# </div>
# </div>
# </div>
# </form>
# <div class="menu_wrap" data-config='{"catalogPath":[19457],"url":"/Catalog/SiteMap/GetWholeSiteHtml?blockId=59191\u0026t=1"}' data-menu="">
# <div class="offsetMenu">
# <div class="header_menu _close menu_close d-none d-md-block" data-menu-close=""></div>
# <div class="header_inner top-line_inner d-block d-md-none">
# <div class="row">
# <div class="col-xl-5 col-md-9">
# <div class="header_left">
# <div class="header_menu _close" data-menu-close=""></div><a class="header_logo" href="/"></a>
# </div>
# </div>
# <div class="col-xl-17 col-md-13 offset-md-1 header_block">
# <div class="header_search"></div>
# </div>
# </div>
# </div>
# <div class="menu row" data-tabs="data-tabs">
# <div class="menu_quick col-md-7">
# <div class="menu_quick_tabs">
# <a class="menu_tab _active" data-tabs-tab="Activity" href="#">Деятельность</a>
# <a class="menu_tab" data-tabs-tab="FinancialMarkets" href="#">Финансовые рынки</a>
# <a class="menu_tab" data-tabs-tab="Documents" href="#">Документы и данные</a>
# <a class="menu_tab" data-tabs-tab="AboutBank" href="#">О Банке России</a>
# <a class="menu_tab" data-tabs-tab="Services" href="#">Сервисы</a>
# </div>
# <div class="menu_quick_links">
# <div class="inner_links"><a href="/allcovid/" style="color:red" title="Новости">Коронавирус: поддержка экономики, бизнеса, граждан</a></div>
# <div class="phones"><a class="menu_phone_val" href="tel:+74993003000">
# <div class="plus">+</div>7 499 300-30-00</a><a class="menu_phone_val" href="tel:88003003000">8 800 300-30-00</a><a class="menu_phone_val" href="tel:300">300</a><span>Бесплатно для звонков с мобильных телефонов</span></div>
# <div class="inner_links">
# <a href="/news/" title="Новости">Новости</a>
# <a href="/rbr/" title="Решения Банка России">Решения Банка России</a>
# <a href="/contacts/" title="Контактная информация">Контактная информация</a>
# <a href="/sitemap" title="Карта сайта">Карта сайта</a>
# <a href="/about/" title="О сайте">О сайте</a>
# </div>
# <div class="networks-circle">
# <a class="networks-circle_item _fb" href="https://www.facebook.com/cbr.ru/" title="Facebook"></a>
# <a class="networks-circle_item _ig" href="https://www.instagram.com/cbrf_official/" title="Instagram"></a>
# <a class="networks-circle_item _vk" href="https://vk.com/cbr_official" title="ВКонтакте"></a>
# <a class="networks-circle_item _tw" href="https://twitter.com/bank_of_russia" title="Twitter"></a>
# <a class="networks-circle_item _yt" href="https://www.youtube.com/user/BankofRussia" title="Youtube"></a>
# </div>
# </div>
# </div>
# <div class="d-md-none link-above">
# <div class="header_right"></div>
# </div>
# <div class="menu_content_container col-md with-centered-loader" data-cms-wholesite-placeholder="">
# </div>
# </div>
# </div>
# </div>
# <main id="content">
# <div class="offsetMenu">
# <div class="container-fluid">
# <div class="col-md-23 offset-md-1">
# <!--index-->
# <h1><span class="referenceable">Ключевые показатели</span>
# </h1>
# <div class="key-indicators_intro row">
# <div class="indicator col-md-15">
# <div class="title">Инфляция</div>
# <div class="rates row">
# <div class="rate col-md-7">
# <div class="denotement-path">
# <div class="denotement" data-tooltip="" data-tooltip-class="mobile-hide" data-tooltip-content="&lt;p&gt;Цель по инфляции устанавливается для показателя инфляции, отражающего темп прироста потребительских цен к соответствующему месяцу предыдущего года&lt;/p&gt;" data-tooltip-type="black">Цель по инфляции</div>
# <div class="path"></div>
# </div>
# <div class="value">4,0%
# 						</div>
# </div>
# <div class="rate col-md-7 offset-md-1">
# <div class="denotement-path">
# <div class="denotement" data-tooltip="" data-tooltip-class="mobile-hide" data-tooltip-content="&lt;p&gt;Показатель инфляции отражает темп прироста потребительских цен к соответствующему месяцу предыдущего года&lt;/p&gt;&lt;p&gt;(источник: &lt;a href='https://www.gks.ru/price'&gt;Федеральная служба государственной статистики&lt;/a&gt;)&lt;/p&gt;" data-tooltip-type="black">Апрель 2021</div>
# <div class="path"></div>
# </div>
# <div class="value">5,5%
# 						</div>
# </div>
# </div>
# </div>
# <div class="indicator col-md-7 offset-md-1">
# <div class="title"><a href="/hd_base/KeyRate/">Ключевая ставка</a><div class="link-arr"></div>
# </div>
# <div class="rates row">
# <div class="rate col-md-7">
# <div class="denotement-path">
# <div class="denotement">
# 								с 26.04.2021</div>
# <div class="path"></div>
# </div>
# <div class="value">5,00%
# 						</div>
# </div>
# </div>
# </div>
# </div>
# <div class="dropdown">
# <div class="dropdown_title _active">Основные индикаторы финансового рынка</div>
# <div class="dropdown_content" style="display: block;">
# <div class="key-indicator"><a href="/currency_base/">Курсы валют</a><div class="link-arr"></div>
# </div>
# <div class="key-indicator_content offset-md-2">
# <div class="key-indicator_table_wrapper">
# <div class="table key-indicator_table">
# <table>
# <tbody>
# <tr class="denotements">
# <td class="value td-w-13">валюта</td>
# <td class="value td-w-4 _end">21.05.2021</td>
# <td class="value td-w-4 _end">22.05.2021</td>
# </tr>
# <tr>
# <td class="value td-w-13 _inner">
# <div class="d-flex title-subinfo">
# <div class="col-md-5">Доллар США</div>
# <div class="col-md-3 offset-md-1 _subinfo">USD</div>
# </div>
# </td>
# <td class="value td-w-4 _bold _end mono-num">73,6007</td>
# <td class="value td-w-4 _bold _end mono-num _with-icon _down _green">73,5803</td>
# </tr>
# <tr>
# <td class="value td-w-13 _inner">
# <div class="d-flex title-subinfo">
# <div class="col-md-5">Евро</div>
# <div class="col-md-3 offset-md-1 _subinfo">EUR</div>
# </div>
# </td>
# <td class="value td-w-4 _bold _end mono-num">89,7708</td>
# <td class="value td-w-4 _bold _end mono-num _with-icon _up _red">89,9446</td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# </div>
# <div class="key-indicator"><a href="/hd_base/metall/">Учетные цены на драгоценные металлы</a><div class="link-arr"></div>
# </div>
# <div class="key-indicator_content offset-md-2">
# <div class="key-indicator_table_wrapper">
# <div class="table key-indicator_table">
# <table>
# <tbody>
# <tr class="denotements">
# <td class="value td-w-13">рублей за грамм</td>
# <td class="value td-w-4 _end">21.05.2021</td>
# <td class="value td-w-4 _end">22.05.2021</td>
# </tr>
# <tr>
# <td class="value td-w-9 _inner">
# <div class="d-flex title-subinfo">
# <div class="col-md-5">Золото</div>
# <div class="col-md-3 offset-md-1 _subinfo">Au</div>
# </div>
# </td>
# <td class="value td-w-4 _bold _end mono-num">4 423,47</td>
# <td class="value td-w-4 _bold _end mono-num _with-icon _up">4 441,88</td>
# </tr>
# <tr>
# <td class="value td-w-9 _inner">
# <div class="d-flex title-subinfo">
# <div class="col-md-5">Серебро</div>
# <div class="col-md-3 offset-md-1 _subinfo">Ag</div>
# </div>
# </td>
# <td class="value td-w-4 _bold _end mono-num">65,64</td>
# <td class="value td-w-4 _bold _end mono-num _with-icon _up">65,77</td>
# </tr>
# <tr>
# <td class="value td-w-9 _inner">
# <div class="d-flex title-subinfo">
# <div class="col-md-5">Платина</div>
# <div class="col-md-3 offset-md-1 _subinfo">Pt</div>
# </div>
# </td>
# <td class="value td-w-4 _bold _end mono-num">2 851,41</td>
# <td class="value td-w-4 _bold _end mono-num _with-icon _down">2 822,23</td>
# </tr>
# <tr>
# <td class="value td-w-9 _inner">
# <div class="d-flex title-subinfo">
# <div class="col-md-5">Палладий</div>
# <div class="col-md-3 offset-md-1 _subinfo">Pd</div>
# </div>
# </td>
# <td class="value td-w-4 _bold _end mono-num">6 772,40</td>
# <td class="value td-w-4 _bold _end mono-num _with-icon _down">6 699,55</td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# </div>
# <div class="key-indicator"><a href="/statistics/finr/#a_73575">Ставки межбанковского кредитного рынка</a><div class="link-arr"></div>
# </div>
# <div class="key-indicator_content offset-md-2">
# <div class="key-indicator_table_wrapper">
# <div class="table key-indicator_table">
# <table>
# <tbody>
# <tr class="denotements">
# <td class="value">% годовых</td>
# <td class="value _end">1 день</td>
# <td class="value _end">2-7 дней</td>
# <td class="value _end">8-30 дней</td>
# </tr>
# <tr>
# <td class="value td-w-9 _inner">
# <div class="d-flex flex-column flex-md-row title-date">
# <div class="col-md-5"><a href="/hd_base/mkr/mkr_base/">MIACR</a></div>
# <div class="_date col-md-3 offset-md-1 _subinfo">
# 													за
# 													20.05.2021</div>
# </div>
# </td>
# <td class="value _bold _end td-w-4 mono-num">4,85</td>
# <td class="value _bold _end td-w-4 mono-num">4,58</td>
# <td class="value _bold _end td-w-4 mono-num"> — </td>
# </tr>
# <tr>
# <td class="value td-w-9 _inner">
# <div class="d-flex flex-column flex-md-row title-date">
# <div class="col-md-5"><a href="/hd_base/ruonia/">RUONIA</a></div>
# <div class="_date col-md-3 offset-md-1 _subinfo">
# 													за
# 													20.05.2021</div>
# </div>
# </td>
# <td class="value _bold _end mono-num _with-icon _down">4,81</td>
# <td class="value _end"></td>
# <td class="value _end"></td>
# </tr>
# <tr class="denotements">
# <td class="value td-w-9">% годовых</td>
# <td class="value _end">1 день</td>
# <td class="value _end">1 неделя</td>
# <td class="value _end">1 месяц</td>
# </tr>
# <tr>
# <td class="value td-w-9 _inner">
# <div class="d-flex flex-column flex-md-row title-date">
# <div class="col-md-5"><a href="/hd_base/mosprime/">MosPrime Rate</a></div>
# <div class="_date col-md-3 offset-md-1 _subinfo">
# 													на
# 													21.05.2021</div>
# </div>
# </td>
# <td class="value _bold _end mono-num">5,05</td>
# <td class="value _bold _end mono-num">5,13</td>
# <td class="value _bold _end mono-num">5,27</td>
# </tr>
# <tr class="denotements">
# <td class="value td-w-9">% годовых</td>
# <td class="value _end">1 неделя</td>
# <td class="value _end">2 недели</td>
# <td class="value _end">1 месяц</td>
# </tr>
# <tr>
# <td class="value td-w-9 _inner">
# <div class="d-flex flex-column flex-md-row title-date">
# <div class="col-md-5"><a href="/hd_base/roisfix/">ROISfix</a></div>
# <div class="_date col-md-3 offset-md-1 _subinfo">
# 													на
# 													21.05.2021</div>
# </div>
# </td>
# <td class="value _bold _end mono-num">4,85</td>
# <td class="value _bold _end mono-num">4,85</td>
# <td class="value _bold _end mono-num">4,95</td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="dropdown">
# <div class="dropdown_title">Международные резервы Российской Федерации</div>
# <div class="dropdown_content">
# <div class="key-indicator_content offset-md-2">
# <div class="key-indicator_table_wrapper">
# <div class="table key-indicator_table">
# <table>
# <tbody>
# <tr class="denotements">
# <td class="value">млрд долл. США</td>
# <td class="value"></td>
# </tr>
# <tr>
# <td class="value"><a href="/hd_base/mrrf/mrrf_7d/">14.05.2021</a></td>
# <td class="value _bold _end mono-num">593,9</td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="dropdown">
# <div class="dropdown_title">Показатели ликвидности банковского сектора</div>
# <div class="dropdown_content">
# <div class="key-indicator_content offset-md-2">
# <div class="key-indicator_table_wrapper">
# <div class="table key-indicator_table">
# <table>
# <tbody>
# <tr class="denotements">
# <td class="value">млрд руб.</td>
# <td class="value"></td>
# </tr>
# <tr>
# <td class="value td-w-17 _inner">
# <div class="d-flex flex-column flex-md-row title-date">
# <div class="col-md-13"><a href="/hd_base/bliquidity/">Структурный дефицит/профицит ликвидности банковского сектора</a></div>
# <div class="col-md-3 offset-md-1 _subinfo">
# 													на
# 													21.05.2021</div>
# </div>
# </td>
# <td class="value _bold _end mono-num">-886,2</td>
# </tr>
# <tr>
# <td class="value _without_border _without_border-mob"><a href="/hd_base/ostat_base/">Сведения об остатках средств на корреспондентских счетах кредитных организаций</a></td>
# <td class="value _without_border"></td>
# </tr>
# <tr class="dash-group">
# <td class="value _without_border td-w-17 _inner">
# <div class="d-flex flex-column flex-md-row title-date">
# <div class="with-dash col-md-13">по Российской Федерации</div>
# <div class="col-md-3 offset-md-1 _subinfo">
# 													на
# 													21.05.2021</div>
# </div>
# </td>
# <td class="value _without_border _bold _end mono-num">3 694,5</td>
# </tr>
# <tr class="dash-group">
# <td class="value td-w-17 _inner">
# <div class="d-flex flex-column flex-md-row title-date">
# <div class="with-dash col-md-13">по Московскому региону</div>
# <div class="col-md-3 offset-md-1 _subinfo">
# 													на
# 													21.05.2021</div>
# </div>
# </td>
# <td class="value _bold _end mono-num">3 477,7</td>
# </tr>
# <tr>
# <td class="value td-w-17 _inner">
# <div class="d-flex flex-column flex-md-row title-date">
# <div class="col-md-13"><a href="/hd_base/dv/?TP=3">Объем предоставленных внутридневных кредитов</a></div>
# <div class="col-md-3 offset-md-1 _subinfo">
# 													на
# 													20.05.2021</div>
# </div>
# </td>
# <td class="value _bold _end mono-num">161,1</td>
# </tr>
# <tr>
# <td class="value td-w-17 _inner">
# <div class="d-flex flex-column flex-md-row title-date">
# <div class="col-md-13"><a href="/hd_base/ostat_depo_new/">Депозиты банков в Банке России</a></div>
# <div class="col-md-3 offset-md-1 _subinfo">
# 													на
# 													21.05.2021</div>
# </div>
# </td>
# <td class="value _bold _end mono-num">1 058,7</td>
# </tr>
# <tr>
# <td class="value td-w-17 _inner">
# <div class="d-flex flex-column flex-md-row title-date">
# <div class="col-md-13"><a href="/hd_base/obr/obrcictotal/">ОБР в обращении</a></div>
# <div class="col-md-3 offset-md-1 _subinfo">
# 													на
# 													21.05.2021</div>
# </div>
# </td>
# <td class="value _bold _end mono-num">668,7</td>
# </tr>
# <tr>
# <td class="value td-w-17 _inner">
# <div class="d-flex flex-column flex-md-row title-date">
# <div class="col-md-13"><a href="/hd_base/saldo/">Сальдо операций Банка России по предоставлению/абсорбированию ликвидности</a></div>
# <div class="col-md-3 offset-md-1 _subinfo">
# 													на
# 													21.05.2021</div>
# </div>
# </td>
# <td class="value _bold _end mono-num _with-icon _up">-197,8</td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="dropdown">
# <div class="dropdown_title">Требования Банка России к кредитным организациям</div>
# <div class="dropdown_content">
# <div class="key-indicator_content offset-md-2">
# <div class="key-indicator_table_wrapper">
# <div class="table key-indicator_table">
# <table>
# <tbody>
# <tr class="denotements">
# <td class="value">млн руб.</td>
# <td class="value"></td>
# </tr>
# <tr>
# <td class="value td-w-17 _inner">
# <div class="d-flex flex-column flex-md-row title-date">
# <div class="col-md-9"><a href="/hd_base/dv/?P1=2">По кредитам овернайт</a></div>
# <div class="col-md-3 offset-md-1 _subinfo">
# 													на
# 													21.05.2021</div>
# </div>
# </td>
# <td class="value _bold _end mono-num">0,0</td>
# </tr>
# <tr>
# <td class="value td-w-17 _inner">
# <div class="d-flex flex-column flex-md-row title-date">
# <div class="col-md-9"><a href="/hd_base/dv/?P1=3">По ломбардным кредитам</a></div>
# <div class="col-md-3 offset-md-1 _subinfo">
# 													на
# 													21.05.2021</div>
# </div>
# </td>
# <td class="value _bold _end mono-num">0,0</td>
# </tr>
# <tr>
# <td class="value td-w-17 _without_border _inner">
# <div class="d-flex flex-column flex-md-row title-date">
# <div class="col-md-9"><a href="/hd_base/repo_debt/">По операциям РЕПО</a></div>
# <div class="col-md-3 offset-md-1 _subinfo">
# 													на
# 													21.05.2021</div>
# </div>
# </td>
# <td class="value _without_border _bold _end"></td>
# </tr>
# <tr class="dash-group">
# <td class="value _without_border td-w-17 with-dash">на аукционной основе</td>
# <td class="value _without_border _bold _end mono-num">153 845,4</td>
# </tr>
# <tr class="dash-group">
# <td class="value td-w-17 with-dash">по фиксированной ставке</td>
# <td class="value _bold _end mono-num">150,0</td>
# </tr>
# <tr>
# <td class="value td-w-17 _inner">
# <div class="d-flex flex-column flex-md-row title-date">
# <div class="col-md-9"><a href="/hd_base/swapdaytotal/">По сделкам «валютный своп»</a></div>
# <div class="col-md-3 offset-md-1 _subinfo">
# 													на
# 													21.05.2021</div>
# </div>
# </td>
# <td class="value _bold _end mono-num">0,0</td>
# </tr>
# <tr>
# <td class="value td-w-17 _inner">
# <div class="d-flex flex-column flex-md-row title-date">
# <div class="col-md-9"><a href="/hd_base/unsecloansdebt/">По кредитам без обеспечения</a></div>
# <div class="col-md-3 offset-md-1 _subinfo">
# 													на
# 													31.12.2010</div>
# </div>
# </td>
# <td class="value _bold _end mono-num">0,0</td>
# </tr>
# <tr>
# <td class="value td-w-17 _inner">
# <div class="d-flex flex-column flex-md-row title-date">
# <div class="col-md-9"><a href="/hd_base/dv/?P1=4">По другим кредитам</a></div>
# <div class="col-md-3 offset-md-1 _subinfo">
# 													на
# 													21.05.2021</div>
# </div>
# </td>
# <td class="value _bold _end mono-num">687 232,1</td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="document-regular">
# <div class="document-regular_inner">
# <div class="document-regular_top">
# <div class="document-regular_left_icon"></div>
# <div class="document-regular_date">май 2021 </div>
# </div>
# <div class="body-2 document-regular_main">
# <div class="document-regular_texts">
# <div class="document-regular_name" data-toggle=""><a href="/statistics/bank_sector/ibudv/"><span class="document-regular_name_visible">Базовый уровень доходности вкладов</span></a></div>
# <div class="document-regular_comment"></div>
# </div>
# </div>
# </div>
# </div>
# <div class="document-regular">
# <div class="document-regular_inner">
# <div class="document-regular_top">
# <div class="document-regular_left_icon"></div>
# <div class="document-regular_date">14.05.2021</div>
# </div>
# <div class="body-2 document-regular_main">
# <div class="document-regular_texts">
# <div class="document-regular_name" data-toggle=""><a href="/statistics/bank_sector/psk/"><span class="document-regular_name_visible">Среднерыночные значения полной стоимости потребительского кредита (займа)</span></a></div>
# <div class="document-regular_comment"></div>
# </div>
# </div>
# </div>
# </div>
# <!--/index-->
# <div class="page-info">
# <!--noindex-->
# <div class="page-info_helpful" data-feedback-url="/Content/PageInfo/RegisterFeedback" data-page-feedback="">
# <!--noindex-->
# <div class="helpful" data-helpful="">
#         Страница была полезной?
#         <div class="helpful_btns">
# <button class="helpful_btn _yes" data-helpful-btn="yes"><i class="helpful_icon"></i><span>Да</span></button>
# <button class="helpful_btn _no" data-helpful-btn="no"><i class="helpful_icon"></i><span>Нет</span></button>
# </div>
# </div>
# <!--/noindex-->
# </div>
# <!--/noindex-->
# </div>
# </div>
# </div>
# </div>
# </main>
# <footer class="footer" id="footer">
# <div class="offsetMenu">
# <div class="footer_main">
# <div class="col-md-23 col-xl-22 offset-md-1 offset-xl-2">
# <div class="footer_top">
# <a class="footer_logo" href="/"></a>
# <div class="footer_up gotoUp">
# <div class="footer_up_title">Наверх</div>
# <div class="footer_up_icon"></div>
# </div>
# </div>
# <div class="footer_contacts">
# <div class="footer_address">ул. Неглинная, 12, Москва, 107016</div>
# <div class="footer_phones">
# <div class="footer_phone"><a class="footer_phone_val" href="tel:88003003000">8 800 300-30-00</a><span>(круглосуточно, бесплатно для звонков из регионов России)</span></div>
# <div class="footer_phone"><a class="footer_phone_val" href="tel:+74993003000">+7 499 300-30-00</a><span>(круглосуточно, в соответствии с тарифами вашего оператора)</span></div>
# <div class="footer_phone"><a class="footer_phone_val" href="tel:300">300</a><span>(круглосуточно, бесплатно для звонков с мобильных телефонов)</span></div>
# </div>
# </div>
# <div class="footer_main_block">
# <div class="footer_left-menu">
# <div class="footer_left-menu_item"><a href="/lk_uio/">Личный кабинет участников рынка</a></div>
# <div class="footer_left-menu_item"><a href="/about_br/irp/">Отношения с инвесторами</a></div>
# <div class="footer_left-menu_item"><a href="/rbr/list_inside/">Перечень инсайдерской информации Банка России</a></div>
# <div class="footer_left-menu_item"><a href="/analytics/na_vr/">Официальное опубликование нормативных актов Банка России</a></div>
# <div class="footer_left-menu_item"><a href="/project_na/">Проекты нормативных актов Банка России</a></div>
# <div class="footer_left-menu_item"><a href="/other/holidays/">Перечень нерабочих праздничных дней и перенесенных выходных дней</a></div>
# </div>
# <div class="networks-circle footer_networks">
# <a class="networks-circle_item _fb" href="https://www.facebook.com/cbr.ru/"></a>
# <a class="networks-circle_item _ig" href="https://www.instagram.com/cbrf_official/" title="Instagram"></a>
# <a class="networks-circle_item _vk" href="https://vk.com/cbr_official"></a>
# <a class="networks-circle_item _tw" href="https://twitter.com/bank_of_russia"></a>
# <a class="networks-circle_item _yt" href="https://www.youtube.com/user/BankofRussia"></a>
# </div>
# </div>
# <div class="footer_menu">
# <div class="footer_menu_items">
# <div class="footer_menu_item"><a href="/about/">О сайте</a></div>
# <div class="footer_menu_item"><a href="/contacts/">Контакты</a></div>
# <div class="footer_menu_item"><a href="/about_br/anticor/">Противодействие коррупции</a></div>
# <div class="footer_menu_item"><a href="/development/">Технические ресурсы</a></div>
# </div>
# <div class="footer_menu_item _visually-impaired"><a href="#" title="Версия для слабовидящих"><span class="visually-impaired-on">Версия для слабовидящих</span><span class="visually-impaired-off">Обычная версия</span></a></div>
# </div>
# </div>
# </div>
# <div class="footer_bottom">
# <div class="col-md-23 col-xl-22 offset-md-1 offset-xl-2 row">
# <div class="footer_bottom_text col-md-12 col-xl-11">© Банк России, 2000–2021.</div>
# <div class="footer_bottom_aic col-md-11">Дизайн сайта — <a href="https://aic.ru" target="_blank"><img src="/common/images/icons/aic-logo.svg"/></a></div>
# </div>
# </div>
# </div>
# </footer>
# <div class="popup-cookies" data-popup-cookies="">
# <div class="popup-cookies_title">
#             На сайте Банка России используются файлы cookie
#         </div>
# <div class="popup-cookies_subtitle">
#             Оставаясь на <a href="/">www.cbr.ru</a>, вы принимаете
#             <a href="/user_agreement/">пользовательское соглашение</a>
# </div>
# <button class="btn _medium _blue" data-popup-cookies-btn="">
#             Подтвердить
#         </button>
# </div>
# <!--[if IE 9]><script>$('body').addClass('ie9')</script><![endif]-->
# <script src="/Modules/Content/Scripts/PageInfo.js?v=v3116962712" type="text/javascript"></script>
# <script type="text/javascript">
#         $(function () {
#             Content_PageInfo.init($('[data-page-feedback]'));
#         });
#     </script>
# </body>
# </html>

# %% [markdown]
# Нам необходимо добраться до кода таблицы, который начинается с тэга <table>. Таблиц на странице много, поэтому указываем путь к таблице виджета драгоценных металлов применяя знания полученные ранее:

# %%
all_blocks = soup.find_all('div', class_='key-indicator_content offset-md-2')
# Данные таблицы с драгметаллами находятся во втором блоке
data = all_blocks[1].find('table')

# %%
# Сейчас наша таблица записана в HTML-коде:
data
# Out:
# <table>
# <tbody>
# <tr class="denotements">
# <td class="value td-w-13">рублей за грамм</td>
# <td class="value td-w-4 _end">21.05.2021</td>
# <td class="value td-w-4 _end">22.05.2021</td>
# </tr>
# <tr>
# <td class="value td-w-9 _inner">
# <div class="d-flex title-subinfo">
# <div class="col-md-5">Золото</div>
# <div class="col-md-3 offset-md-1 _subinfo">Au</div>
# </div>
# </td>
# <td class="value td-w-4 _bold _end mono-num">4 423,47</td>
# <td class="value td-w-4 _bold _end mono-num _with-icon _up">4 441,88</td>
# </tr>
# <tr>
# <td class="value td-w-9 _inner">
# <div class="d-flex title-subinfo">
# <div class="col-md-5">Серебро</div>
# <div class="col-md-3 offset-md-1 _subinfo">Ag</div>
# </div>
# </td>
# <td class="value td-w-4 _bold _end mono-num">65,64</td>
# <td class="value td-w-4 _bold _end mono-num _with-icon _up">65,77</td>
# </tr>
# <tr>
# <td class="value td-w-9 _inner">
# <div class="d-flex title-subinfo">
# <div class="col-md-5">Платина</div>
# <div class="col-md-3 offset-md-1 _subinfo">Pt</div>
# </div>
# </td>
# <td class="value td-w-4 _bold _end mono-num">2 851,41</td>
# <td class="value td-w-4 _bold _end mono-num _with-icon _down">2 822,23</td>
# </tr>
# <tr>
# <td class="value td-w-9 _inner">
# <div class="d-flex title-subinfo">
# <div class="col-md-5">Палладий</div>
# <div class="col-md-3 offset-md-1 _subinfo">Pd</div>
# </div>
# </td>
# <td class="value td-w-4 _bold _end mono-num">6 772,40</td>
# <td class="value td-w-4 _bold _end mono-num _with-icon _down">6 699,55</td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# Для перевода ее в датафрейм используем метод read_html. Метод возвращает список датафреймов. В нашем случае датафрейм будет только один, поэтому сразу берем первый элемент:

# %%
df = pd.read_html(str(data))[0]  
df
# Out:
#                  0           1           2
# 0  рублей за грамм  21.05.2021  22.05.2021
# 1        Золото Au    4 423,47    4 441,88
# 2       Серебро Ag        6564        6577
# 3       Платина Pt    2 851,41    2 822,23
# 4      Палладий Pd    6 772,40    6 699,55

# %% [markdown]
# Датафрейм получен! Теперь можно работать с ним средствами Pandas.

# %% [markdown]
# **Задание 2 - Рейтинг банков**
#
# Напишите программу, которая забирает данные из таблицы рейтинга банков с https://www.banki.ru/banks/ratings/, делает из него датафрейм и сохраняет его в переменую df.

# %%
from bs4 import BeautifulSoup  
import pandas as pd  
import requests
# 12                                      1 247 598 880
# 13                                      1 059 701 409
# 14                                        973 464 962
# 15                                        872 924 975
# 16                                        753 451 535
# 17                                        735 858 199
# ...
# 44                                        144 685 682
# 45                                        141 456 317
# 46                                        143 489 195
# 47                                        138 416 751
# 48                                        149 176 418
# 49                                        129 876 511
#
#          изменение
#        тыс. рублей        %
# 0   +1 018 996 868   +2,98%
# 1     +203 844 846   +1,19%
# 2     +206 071 729   +2,78%
# 3     +552 718 877  +10,70%
# 4     +134 021 630   +2,78%
# 5     +117 674 032   +3,03%
# 6      +81 157 070   +2,62%
# 7      +94 687 236   +3,44%
# 8       +5 999 130   +0,37%
# 9      +22 347 919   +1,56%
# 10     +55 667 719   +4,04%
# 11     −49 261 650   −3,74%
# 12      −8 188 238   −0,65%
# 13     +13 836 807   +1,32%
# 14     −21 978 533   −2,21%
# 15     +16 043 465   +1,87%
# 16     +17 727 806   +2,41%
# 17     +35 067 099   +5,00%
# 18     +69 669 482  +11,97%
# 19     +28 640 082   +4,82%
# 20     +27 770 240   +4,79%
# 21     −12 528 990   −2,05%
# 22     +10 109 765   +1,90%
# 23      +9 830 450   +1,85%
# 24      −8 678 308   −1,68%
# 25      +9 123 126   +1,95%
# 26        +668 897   +0,19%
# 27      +5 756 649   +1,68%
# 28      +4 990 795   +1,63%
# 29    −127 821 045  −30,21%
# 30        +573 494   +0,20%
# 31      −9 343 056   −3,24%
# 32      +9 727 112   +3,87%
# 33      +1 765 094   +0,74%
# 34      −3 875 602   −1,72%
# 35      +8 911 059   +4,21%
# 36     +10 192 794   +4,92%
# 37      +4 858 398   +2,59%
# 38      +2 065 425   +1,12%
# 39      −1 348 840   −0,74%
# 40      −6 607 614   −3,69%
# 41      −5 411 755   −3,23%
# 42      +4 633 299   +3,09%
# 43        +854 436   +0,56%
# 44          +6 658   +0,00%
# 45        +153 921   +0,11%
# 46      −4 635 755   −3,23%
# 47      −2 979 288   −2,15%
# 48     −16 444 628  −11,02%
# 49        +318 667   +0,25%

# %%
from bs4 import BeautifulSoup  
import pandas as pd  
import requests  
  
url = 'https://www.banki.ru/banks/ratings/'
soup = BeautifulSoup(requests.get(url, headers={'User-Agent': 'Mozilla/5.0'}).text, 'html.parser')  

all_blocks = soup.find_all('div', class_='layout-column-full')

# Данные таблицы с драгметаллами находятся во втором блоке
data = all_blocks[2].find('table') 

df = pd.read_html(str(data))[0]  
df
# Out:
#     место                  название банка лицензия №, Регион  \
#     место                  название банка лицензия №, Регион
# 0       1            СберБанк лицензия № 1481, Москва и обл.
# 1       2        ВТБ лицензия № 1000, Санкт-Петербург и обл.
# 2       3          Газпромбанк лицензия № 354, Москва и обл.
# 3       4  Национальный Клиринговый Центр лицензия № 3466...
# 4       5          Альфа-Банк лицензия № 1326, Москва и обл.
# 5       6      Россельхозбанк лицензия № 3349, Москва и обл.
# 6       7  Московский Кредитный Банк лицензия № 1978, Мос...
# 7       8       Банк Открытие лицензия № 2209, Москва и обл.
# 8       9        Совкомбанк лицензия № 963, Костромская обл.
# 9      10      Райффайзенбанк лицензия № 3292, Москва и обл.
# 10     11             Росбанк лицензия № 2272, Москва и обл.
# 11     12         ЮниКредит Банк лицензия № 1, Москва и обл.
# 12     13               Траст лицензия № 3279, Москва и обл.
# 13     14      Россия лицензия № 328, Санкт-Петербург и обл.
# 14     15  Всероссийский Банк Развития Регионов лицензия ...
# 15     16       Тинькофф Банк лицензия № 2673, Москва и обл.
# 16     17  Санкт-Петербург лицензия № 436, Санкт-Петербур...
# 17     18            Ситибанк лицензия № 2557, Москва и обл.
# 18  19 +2         Банк ДОМ.РФ лицензия № 2312, Москва и обл.
#
# 20     +27 770 240   +4,79%
# 21     −12 528 990   −2,05%
# 22     +10 109 765   +1,90%
# 23      +9 830 450   +1,85%
# 24      −8 678 308   −1,68%
# 25      +9 123 126   +1,95%
# 26        +668 897   +0,19%
# 27      +5 756 649   +1,68%
# 28      +4 990 795   +1,63%
# 29    −127 821 045  −30,21%
# 30        +573 494   +0,20%
# 31      −9 343 056   −3,24%
# 32      +9 727 112   +3,87%
# 33      +1 765 094   +0,74%
# 34      −3 875 602   −1,72%
# 35      +8 911 059   +4,21%
# 36     +10 192 794   +4,92%
# 37      +4 858 398   +2,59%
# 38      +2 065 425   +1,12%
# 39      −1 348 840   −0,74%
# 40      −6 607 614   −3,69%
# 41      −5 411 755   −3,23%
# 42      +4 633 299   +3,09%
# 43        +854 436   +0,56%
# 44          +6 658   +0,00%
# 45        +153 921   +0,11%
# 46      −4 635 755   −3,23%
# 47      −2 979 288   −2,15%
# 48     −16 444 628  −11,02%
# 49        +318 667   +0,25%

# %% [markdown]
# # Введение в API
#
#
# В предыдущих разделах мы собирали полезную информацию с различных сайтов с выделением правильных тэгов – это довольно трудоёмкая задача. Кроме того, подобные программы могут ломаться в случаях, когда меняется дизайн сайта, его разметка, или владельцы сайтов защищаются от ботов капчей.
#
# К счастью, многие крупные сайты предоставляют доступ к так называемым API (application programming interface, программный интерфейс приложения). Это специальные разделы сайта, где информацию можно получать без разметки, формат запросов – ответов зафиксирован, и они созданы специально, чтобы облегчить жизнь сторонним разработчикам.
#
# Мы уже видели, как https://www.cbr-xml-daily.ru возвращает данные о валютах в json-формате, и это может считаться API. В этом разделе мы на примере ВКонтакте посмотрим особенности API, характерные для более крупных сайтов.

# %% [markdown]
# **Сервисный токен**
#
# Для того чтобы начать работать с API ВКонтакте, необходимо получить сервисный токен (ключ) авторизации.
#
# Авторизация применяется практически во всех API, чтобы отдавать данные только их владельцу или контролировать количество запросов в единицу времени. Сервисный токен для нашей задачи создается вместе с новым приложением. Приложение мы делать, конечно, не будем. Оно нужно только для получения токена, чтобы сделать необходимые выгрузки.
#
# Зайдите на страницу https://vk.com/editapp?act=create, чтобы создать приложение (вы должны быть авторизованы ВКонтакте). Дайте приложению любое название и оставьте значение платформы "Standalone-приложение":
#
# После подтверждения создания приложения в приложении ВК или по СМС зайдите в настройки:
#
# <img src="../images/vk1.jpg" alt="Binary-cross-entropy" width="900" align="center">
#
# Нужный нам токен лежит в поле "Сервисный ключ доступа".
#
# <img src="../images/vk2.png" alt="Binary-cross-entropy" width="900" align="center">

# %%
# Важно! текущий токен недействительный, необходимо забрать из ЛК в ВК.
TOKEN = 'c60034b6c60034b6c60034b65cc677c114cc600c60034b6a6aa14a2974fc49a17952359'

# %% [markdown]
# **Запрос к API**
#
# Для примера работы с API мы будем получать данные для статистических отчетов произвольной группы, например:
#
#  - соотношение мужчин и женщин в группе;
#  - статистика географии пользователей;
#  - другие данные для аналитики групп конкурентов.
#
# Сначала рассмотрим работу API на простом примере, на основе которого работают многие системы.
#
# Перейдите по следующей ссылке в браузере, подставив вместо слова "TOKEN" сервисный токен из прошлого шага:
#
#     https://api.vk.com/method/users.get?user_id=1&v=5.95&access_token=TOKEN
#
# Результат:
#
#     {"response":[{"first_name":"Павел","id":1,"last_name":"Дуров","can_access_closed":true,"is_closed":false}]}
#
# Сейчас мы сделали **GET-запрос** к API ВКонтакте, который состоит из следующих частей:
#
#  - https://api.vk.com/method — домен и URL запроса API: обычно не меняется;
#  - users.get — название метода, который отдает определенный отчет; нашем случае это метод для получения информации о пользователе;
#  - user_id и v — параметры запроса: идентификатор пользователя, о котором хотим получить информацию, и номер версии API;
#  - token, который выдается только пользователям, имеющим право просматривать определенные данные, например, показания счетчиков Яндекс, метрики вашего проекта: на все остальные запросы без корректного токена система отвечает отказом.
#
# Если мы посмотрим документацию метода users.get (https://vk.com/dev/users.get), то увидим, что в ней описано множество других параметров, которые можно получить о пользователе: дата рождения, пол, родной город и другие.
#
# Словом, всё то, что мы видим на странице пользователя в интерфейсе или приложении ВКонтакте (конечно, если пользователь их указал). Добавим к запросу дату рождения и пол (согласно документации, эти параметры надо перечислять в поле fields):
#
#     https://api.vk.com/method/users.get?user_id=1&v=5.95&fields=sex,bdate&access_token=TOKEN
#
# Результат:
#
#     {"response":[{"id":1,"first_name":"Павел","last_name":"Дуров","is_closed":false,"can_access_closed":true,"sex":2,"bdate":"10.10.1984"}]}
#
# Примечание: значение 2 у параметра 'sex' означает мужской пол.

# %%
'https://api.vk.com/method/users.get?user_id=1&v=5.95&access_token=' + TOKEN
# Out:
# 'https://api.vk.com/method/users.get?user_id=1&v=5.95&access_token=c60034b6c60034b6c60034b65cc677c114cc600c60034b6a6aa14a2974fc49a17952359'

# %%
'https://api.vk.com/method/users.get?user_id=1&v=5.95&fields=sex,bdate&access_token=' + TOKEN
# Out:
# 'https://api.vk.com/method/users.get?user_id=1&v=5.95&fields=sex,bdate&access_token=c60034b6c60034b6c60034b65cc677c114cc600c60034b6a6aa14a2974fc49a17952359'

# %% [markdown]
# **Задание 1 - ID страны**
#
# Какое значение ID у страны, указанной в профиле Павла Дурова (ID отдается вместе с названием страны)? Укажите ответ в виде целого числа.

# %%
'https://api.vk.com/method/users.get?user_id=1&v=5.95&fields=sex,bdate,country&access_token=' + TOKEN
# Out:
# 'https://api.vk.com/method/users.get?user_id=1&v=5.95&fields=sex,bdate,country&access_token=c60034b6c60034b6c60034b65cc677c114cc600c60034b6a6aa14a2974fc49a17952359'

# %%
# {"response":[{"first_name":"Павел","id":1,"last_name":"Дуров","can_access_closed":true,"is_closed":false,
# "sex":2,"bdate":"10.10.1984","country":{"id":1,"title":"Россия"}}]}

# %% [markdown]
# # Запрос к API из кода
#
# Мы делали запрос в браузере, теперь давайте сделаем запрос из кода. Будем пользоваться всё той же библиотекой requests.

# %%
import requests  
  
url = 'https://api.vk.com/method/users.get'   
params = {'user_id': 1, 'v': 5.95, 'fields': 'sex,bdate', 'access_token': TOKEN, 'lang': 'ru'}  
  
# Мы можем выставить параметры запроса через аргумент params  
response = requests.get(url, params=params)  
response.text  
# => '{"response":[{"id":1,"first_name":"Павел","last_name":"Дуров","is_closed":false,"can_access_closed":true,"sex":2,"bdate":"10.10.1984"}]}'
# Out:
# '{"response":[{"first_name":"Павел","id":1,"last_name":"Дуров","can_access_closed":true,"is_closed":false,"sex":2,"bdate":"10.10.1984"}]}'

# %% [markdown]
# Мы получили строку в формате JSON. Как мы помним по первому разделу, её можно преобразовать в словарь методом json и после этого обращаться к различным полям. Кроме того, такие большие вложенные словари нагляднее выводить с помощью функции pprint (~pretty print, красивый вывод), которым мы и воспользуемся

# %%
from pprint import pprint  
  
pprint(response.json())  
# =>   
# {'response': [{'bdate': '10.10.1984',  
#                'can_access_closed': True,  
#                'first_name': 'Павел',  
#                'id': 1,  
#                'is_closed': False,
#                'last_name': 'Дуров',  
#                'sex': 2}]}  
  
user = response.json()['response'][0]  
  
# Выведем дату рождения  
print(user['bdate'])  
# => 10.10.1984  
  
# Выведем имя  
print(user['first_name'])  
# => Павел
# Out:
# {'response': [{'bdate': '10.10.1984',
#                'can_access_closed': True,
#                'first_name': 'Павел',
#                'id': 1,
#                'is_closed': False,
#                'last_name': 'Дуров',
#                'sex': 2}]}
# 10.10.1984
# Павел

# %% [markdown]
# Данный метод позволяет запрашивать сразу много пользователей (до 1000).  Для этого нужно использовать параметр user_ids и передавать id через запятую в строковом формате, например: '1,2,3'.

# %%
ids = ",".join(map(str, range(1, 4)))  
print(ids)  
# => 1,2,3  
  
params = {'user_ids': ids, 'v': 5.95, 'fields': 'bday', 'access_token': TOKEN, 'lang': 'ru'}  
  
pprint(requests.get(url, params=params).json()) 
# {'response': [{'can_access_closed': True,  
#                'first_name': 'Павел',  
#                'id': 1,  
#                ''is_closed': False',  
#                'last_name': 'Дуров'},  
#               {'can_access_closed': False,  
#                'first_name': 'Александра',  
#                'id': 2,  
#                'is_closed': True,  
#                'last_name': 'Владимирова'},  
#               {'deactivated': 'deleted',  
#                'first_name': 'DELETED',  
#                'id': 3,  
#                'last_name': ''}]}
# Out:
# 1,2,3
# {'response': [{'can_access_closed': True,
#                'first_name': 'Павел',
#                'id': 1,
#                'is_closed': False,
#                'last_name': 'Дуров'},
#               {'can_access_closed': False,
#                'first_name': 'Александра',
#                'id': 2,
#                'is_closed': True,
#                'last_name': 'Владимирова'},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 3,
#                'last_name': ''}]}

# %% [markdown]
# **Задание 1 - Гендерный баланс**
#
# Используя API, определите долю женщин(sex=1) среди пользователей с id от 1 до 500. Иногда вам будут попадать пользователи, у которых пол не указан (sex=0), их не нужно учитывать в общем числе.
#
# В ответе укажите число, округлив до двух знаков после запятой, например, 0.55
#
# Пример: если у нас будет 300 пользователей sex=1, 100 пользователей с sex=2 и 100 пользователей с sex=0, то в ответе должно быть 0.75

# %%
ids = ",".join(map(str, range(1, 501)))   
  
params = {'user_ids': ids, 'v': 5.95, 'fields': 'sex', 'access_token': TOKEN, 'lang': 'ru'}  
  
users = requests.get(url, params=params).json()['response']

users_sex = [user['sex'] for user in users]
users_sex[:20]
# Out:
# [2, 1, 0, 0, 2, 2, 2, 2, 1, 2, 2, 2, 0, 2, 2, 1, 2, 2, 1, 2]

# %%
from collections import Counter  

counter = Counter(users_sex) 

sex_rate = counter[1] / (counter[1] + counter[2])
round(sex_rate, 2)
# Out:
# 0.48

# %% [markdown]
# # Ограничения API
#
# В прошлом блоке мы собрали информацию о небольшом наборе пользователей. Теперь перейдем к более реальной задаче — сбору данных о пользователях группы ВКонтакте.
#
# Стоит отметить, что есть много сервисов, которые выгружают похожую статистику из соцсетей. Однако им свойственны недостатки универсальных решений:
#
#  - не могут учитывать всех особенностей вашего проекта;
#  - считают фиксированный набор метрик, дополнительную обработку данных приходится делать вам;
#  - не всегда бесплатны и вряд ли позволят работать с большими объемами данных.
#
# **В этом разделе мы научимся считать произвольные метрики групп, собирая данные из API.**
#
# В текущем шаге мы научимся работать с двумя ограничениями, которые свойственны практически всем системам:
#
#  - ограничение на количество вызовов в единицу времени;
#  - ограничение на количество выгружаемых строк за один запрос.
#
# Ограничение на количество запросов в секунду сделано для того, чтобы избежать чрезмерной нагрузки на серверы системы. В ряде случаев небольшое количество отчетов можно выгрузить, уложившись в этот лимит (например, как мы получили информацию о 500 пользователях в прошлом упражнении). Однако второе ограничение не удастся «обойти» в случае выгрузки больших отчетов. Например, чтобы получить список всех пользователей очень популярной группы, серверу, возможно, придется отправить вам разом лист из миллионов записей.
#
# Давайте рассмотрим, как работать с этими ограничениями на примере выгрузки списка пользователей группы https://vk.com/vk.
#
# Посмотрим в документации, какие методы нам доступны для групп (https://vk.com/dev/groups). Для получения списка пользователей группы видим метод groups.getMembers (https://vk.com/dev/groups.getMembers).
#
# Согласно документации, обязательным параметром является ID или короткое имя группы. В нашем случае это vk: https://vk.com/vk. Тестируем, как работает метод в самом простом случае:

# %%
import requests  

url = 'https://api.vk.com/method/groups.getMembers'  
params = {  
    'group_id': 'vk',  
    'v': 5.95,  
    'access_token': TOKEN  
}  

response = requests.get(url, params=params)  
data = response.json()  
print(data)  
# => {'response': {'count': 11240724, 'items': [5, 6, 10, 19, 34, 47, 54, 79, 177, 193, 205, 219... 
  
len(data['response']['items'])  
# => 1000
# Out:
# {'response': {'count': 11547449, 'items': [5, 6, 10, 19, 34, 47, 54, 79, 177, 193, 198, 205, 219, 239, 243, 254, 345, 404, 406, 407, 467, 485, 510, 550, 619, 628, 640, 643, 690, 702, 720, 721, 724, 744, 804, 809, 831, 832, 847, 900, 905, 907, 914, 943, 952, 958, 966, 976, 979, 1000, 1018, 1023, 1032, 1033, 1038, 1039, 1059, 1097, 1131, 1139, 1140, 1159, 1174, 1188, 1290, 1301, 1333, 1334, 1336, 1351, 1359, 1386, 1388, 1406, 1411, 1418, 1432, 1494, 1500, 1531, 1543, 1568, 1586, 1590, 1593, 1598, 1610, 1615, 1632, 1634, 1650, 1679, 1690, 1697, 1698, 1699, 1700, 1721, 1740, 1754, 1796, 1814, 1820, 1829, 1834, 1839, 1840, 1843, 1858, 1863, 1868, 1869, 1889, 1917, 1943, 1947, 1955, 1969, 2019, 2028, 2050, 2051, 2052, 2059, 2077, 2103, 2145, 2150, 2195, 2201, 2202, 2230, 2236, 2273, 2281, 2294, 2296, 2298, 2376, 2389, 2395, 2403, 2412, 2436, 2456, 2466, 2470, 2484, 2515, 2527, 2539, 2571, 2576, 2592, 2601, 2622, 2644, 2654, 2692, 2706, 2745, 2755, 2767, 2787, 2797, 2827, 2858, 2896, 2909, 2919, 2922, 2953, 2962, 2982, 3001, 3006, 3041, 3130, 3135, 3140, 3172, 3186, 3203, 3213, 3231, 3250, 3254, 3316, 3320, 3321, 3328, 3331, 3364, 3372, 3373, 3384, 3388, 3402, 3420, 3422, 3427, 3436, 3450, 3458, 3472, 3483, 3486, 3491, 3492, 3520, 3545, 3556, 3581, 3597, 3626, 3637, 3646, 3653, 3657, 3658, 3675, 3684, 3690, 3697, 3713, 3719, 3786, 3820, 3824, 3836, 3837, 3851, 3863, 3904, 3909, 3938, 3948, 3979, 4004, 4010, 4023, 4026, 4041, 4047, 4048, 4108, 4130, 4150, 4157, 4189, 4192, 4262, 4282, 4326, 4360, 4439, 4440, 4447, 4485, 4505, 4521, 4528, 4530, 4537, 4543, 4554, 4558, 4563, 4564, 4583, 4599, 4601, 4625, 4640, 4668, 4669, 4670, 4672, 4689, 4693, 4728, 4731, 4754, 4767, 4769, 4818, 4857, 4862, 4866, 4881, 4921, 4923, 4928, 4947, 4981, 4985, 5011, 5017, 5024, 5067, 5073, 5161, 5166, 5183, 5262, 5273, 5280, 5286, 5354, 5386, 5387, 5392, 5394, 5399, 5401, 5430, 5432, 5436, 5438, 5472, 5479, 5481, 5527, 5546, 5547, 5585, 5590, 5606, 5615, 5629, 5634, 5665, 5690, 5701, 5733, 5768, 5775, 5803, 5819, 5846, 5850, 5896, 5914, 5916, 5932, 5934, 5944, 5959, 5965, 5990, 5991, 5997, 6000, 6021, 6037, 6046, 6086, 6099, 6107, 6111, 6154, 6161, 6167, 6181, 6186, 6187, 6203, 6260, 6265, 6293, 6323, 6333, 6339, 6379, 6380, 6390, 6477, 6492, 6520, 6547, 6557, 6564, 6595, 6604, 6627, 6635, 6670, 6683, 6689, 6701, 6703, 6715, 6797, 6801, 6862, 6950, 6960, 6994, 7012, 7036, 7040, 7050, 7052, 7068, 7099, 7112, 7115, 7117, 7188, 7200, 7208, 7226, 7227, 7286, 7290, 7338, 7402, 7404, 7428, 7451, 7481, 7492, 7500, 7525, 7543, 7547, 7557, 7595, 7615, 7661, 7666, 7725, 7737, 7755, 7768, 7777, 7830, 7833, 7847, 7855, 7858, 7860, 7962, 7982, 7998, 8019, 8066, 8080, 8093, 8149, 8157, 8166, 8167, 8181, 8182, 8195, 8201, 8224, 8240, 8266, 8273, 8298, 8310, 8321, 8323, 8347, 8348, 8377, 8398, 8418, 8422, 8436, 8443, 8479, 8484, 8490, 8505, 8518, 8536, 8544, 8576, 8610, 8636, 8642, 8656, 8658, 8704, 8718, 8727, 8738, 8752, 8777, 8792, 8813, 8875, 8883, 8910, 8937, 8959, 8972, 9000, 9014, 9016, 9079, 9095, 9100, 9110, 9111, 9115, 9173, 9187, 9189, 9222, 9246, 9256, 9319, 9355, 9399, 9412, 9435, 9444, 9447, 9450, 9459, 9466, 9469, 9499, 9527, 9532, 9536, 9547, 9556, 9566, 9569, 9571, 9579, 9699, 9723, 9737, 9741, 9748, 9775, 9778, 9782, 9847, 9894, 9900, 9954, 9981, 9993, 10090, 10117, 10155, 10162, 10217, 10272, 10284, 10286, 10302, 10350, 10351, 10354, 10365, 10366, 10376, 10516, 10518, 10570, 10596, 10607, 10615, 10639, 10682, 10697, 10741, 10749, 10767, 10811, 10833, 10887, 10919, 10955, 10956, 10961, 10972, 10999, 11027, 11059, 11064, 11068, 11081, 11084, 11150, 11187, 11191, 11236, 11243, 11271, 11303, 11446, 11451, 11483, 11568, 11649, 11727, 11747, 11754, 11763, 11768, 11782, 11792, 11865, 11964, 11983, 12005, 12029, 12036, 12097, 12133, 12150, 12159, 12172, 12213, 12252, 12255, 12264, 12316, 12332, 12345, 12353, 12367, 12407, 12441, 12454, 12456, 12473, 12477, 12545, 12560, 12570, 12617, 12625, 12707, 12716, 12718, 12736, 12748, 12762, 12797, 12803, 12808, 12817, 12 ...
# 1000

# %%
# Всего пользователей: data['response']['count']
data['response']['count']
# Out:
# 11547458

# %% [markdown]
# **Получаем всех пользователей**
#
# Мы видим, что всего пользователей в группе больше 11 000 000, а получили мы только первую тысячу пользователей группы. Судя по описанию параметра count в документации, это максимум, который может отдать API за один раз.
#
# Для получения следующей тысячи пользователей воспользуемся параметрами count и offset: будем в цикле выгружать по 1000 пользователей (count будет всегда равен 1000), а в каждом следующем шаге цикла увеличим смещение offset на величину count.
#
# Сначала напишем цикл выгрузки первых 20 пользователей со значением count = 5. Т.е. цикл будет выгружать за 1 запрос по 5 пользователей, пока не выгрузит первые 20. Это позволит нам проверить корректность работы цикла перед тем, как делать большие и долгие выгрузки.
#
# Давайте выведем на экран первые 20 пользователей из нашей первой попытки с 1000 пользователей, чтобы было с чем сверить результат выгрузки из 20 пользователей:

# %%
users_for_checking = data['response']['items'][:20]  
print(users_for_checking)  
# => [5, 6, 10, 19, 34, 47, 54, 79, 177, 193, 205, 219, 239, 243, 345, 404, 406, 407, 467, 485]
# Out:
# [5, 6, 10, 19, 34, 47, 54, 79, 177, 193, 198, 205, 219, 239, 243, 254, 345, 404, 406, 407]

# %% [markdown]
# Теперь используем count и offset, чтобы получить те же id по 5 за раз

# %%
count = 5  
offset = 0  
user_ids = []
max_count = 20 

while offset < max_count:  
    print('Выгружаю {} пользователей с offset = {}'.format(count, offset))     
    params = {  
        'group_id': 'vk',  
        'v': 5.95,  
        'count': count,  
        'offset': offset,  
        'access_token': TOKEN  
    }     
    # такой же запрос как в прошлый раз  
    r = requests.get(url, params=params)  
    data = r.json()     
    user_ids += data['response']['items']   
  
    # увеличиваем смещение на количество строк выгрузки  
    offset += count  
      
# Выгружаю 5 пользователей с offset = 0  
# Выгружаю 5 пользователей с offset = 5  
# Выгружаю 5 пользователей с offset = 10  
# Выгружаю 5 пользователей с offset = 15  

print(user_ids)  
# => [5, 6, 10, 19, 34, 47, 54, 79, 177, 193, 205, 219, 239, 243, 345, 404, 406, 407, 467, 485]
  
user_ids == users_for_checking  
# => True
# Out:
# Выгружаю 5 пользователей с offset = 0
# Выгружаю 5 пользователей с offset = 5
# Выгружаю 5 пользователей с offset = 10
# Выгружаю 5 пользователей с offset = 15
# [5, 6, 10, 19, 34, 47, 54, 79, 177, 193, 198, 205, 219, 239, 243, 254, 345, 404, 406, 407]
# True

# %% [markdown]
# Видим, что подход корректно работает. Теперь мы можем получить всех пользователей, выставив count = 1000 и max_count = data['response']['count'].

# %% [markdown]
# **Задание 1 - Юбилейный пользователь**
#
# Используя API, определите id стотысячного пользователя в группе vk . Т.е. если бы у нас не было ограничения на размер запроса, то мы бы запросили data['response']['items'][99999] .

# %%
count = 1000  
offset = 0  
user_ids = []
max_count = 100000 

while offset < max_count:  
    print('Выгружаю {} пользователей с offset = {}'.format(count, offset))     
    params = {  
        'group_id': 'vk',  
        'v': 5.95,  
        'count': count,  
        'offset': offset,  
        'access_token': TOKEN  
    }     
    # такой же запрос как в прошлый раз  
    r = requests.get(url, params=params)  
    data = r.json()      
  
    # увеличиваем смещение на количество строк выгрузки  
    offset += count
# Out:
# Выгружаю 1000 пользователей с offset = 0
# Выгружаю 1000 пользователей с offset = 1000
# Выгружаю 1000 пользователей с offset = 2000
# Выгружаю 1000 пользователей с offset = 3000
# Выгружаю 1000 пользователей с offset = 4000
# Выгружаю 1000 пользователей с offset = 5000
# Выгружаю 1000 пользователей с offset = 6000
# Выгружаю 1000 пользователей с offset = 7000
# Выгружаю 1000 пользователей с offset = 8000
# Выгружаю 1000 пользователей с offset = 9000
# Выгружаю 1000 пользователей с offset = 10000
# Выгружаю 1000 пользователей с offset = 11000
# Выгружаю 1000 пользователей с offset = 12000
# Выгружаю 1000 пользователей с offset = 13000
# Выгружаю 1000 пользователей с offset = 14000
# Выгружаю 1000 пользователей с offset = 15000
# Выгружаю 1000 пользователей с offset = 16000
# Выгружаю 1000 пользователей с offset = 17000
# Выгружаю 1000 пользователей с offset = 18000
# Выгружаю 1000 пользователей с offset = 19000
# Выгружаю 1000 пользователей с offset = 20000
# Выгружаю 1000 пользователей с offset = 21000
# Выгружаю 1000 пользователей с offset = 22000
# Выгружаю 1000 пользователей с offset = 23000
# Выгружаю 1000 пользователей с offset = 24000
# Выгружаю 1000 пользователей с offset = 25000
# Выгружаю 1000 пользователей с offset = 26000
# Выгружаю 1000 пользователей с offset = 27000
# Выгружаю 1000 пользователей с offset = 28000
# Выгружаю 1000 пользователей с offset = 29000
# Выгружаю 1000 пользователей с offset = 30000
# Выгружаю 1000 пользователей с offset = 31000
# Выгружаю 1000 пользователей с offset = 32000
# Выгружаю 1000 пользователей с offset = 33000
# Выгружаю 1000 пользователей с offset = 34000
# Выгружаю 1000 пользователей с offset = 35000
# Выгружаю 1000 пользователей с offset = 36000
# Выгружаю 1000 пользователей с offset = 37000
# Выгружаю 1000 пользователей с offset = 38000
# Выгружаю 1000 пользователей с offset = 39000
# Выгружаю 1000 пользователей с offset = 40000
# Выгружаю 1000 пользователей с offset = 41000
# Выгружаю 1000 пользователей с offset = 42000
# Выгружаю 1000 пользователей с offset = 43000
# Выгружаю 1000 пользователей с offset = 44000
# Выгружаю 1000 пользователей с offset = 45000
# Выгружаю 1000 пользователей с offset = 46000
# Выгружаю 1000 пользователей с offset = 47000
# Выгружаю 1000 пользователей с offset = 48000
# Выгружаю 1000 пользователей с offset = 49000
# Выгружаю 1000 пользователей с offset = 50000
# Выгружаю 1000 пользователей с offset = 51000
# Выгружаю 1000 пользователей с offset = 52000
# Выгружаю 1000 пользователей с offset = 53000
# Выгружаю 1000 пользователей с offset = 54000
# Выгружаю 1000 пользователей с offset = 55000
# Выгружаю 1000 пользователей с offset = 56000
# Выгружаю 1000 пользователей с offset = 57000
# Выгружаю 1000 пользователей с offset = 58000
# Выгружаю 1000 пользователей с offset = 59000
# Выгружаю 1000 пользователей с offset = 60000
# Выгружаю 1000 пользователей с offset = 61000
# Выгружаю 1000 пользователей с offset = 62000
# Выгружаю 1000 пользователей с offset = 63000
# Выгружаю 1000 пользователей с offset = 64000
# Выгружаю 1000 пользователей с offset = 65000
# Выгружаю 1000 пользователей с offset = 66000
# Выгружаю 1000 пользователей с offset = 67000
# Выгружаю 1000 пользователей с offset = 68000
# Выгружаю 1000 пользователей с offset = 69000
# Выгружаю 1000 пользователей с offset = 70000
# Выгружаю 1000 пользователей с offset = 71000
# Выгружаю 1000 пользователей с offset = 72000
# Выгружаю 1000 пользователей с offset = 73000
# Выгружаю 1000 пользователей с offset = 74000
# Выгружаю 1000 пользователей с offset = 75000
# Выгружаю 1000 пользователей с offset = 76000
# Выгружаю 1000 пользователей с offset = 77000
# Выгружаю 1000 пользователей с offset = 78000
# Выгружаю 1000 пользователей с offset = 79000
# Выгружаю 1000 пользователей с offset = 80000
# Выгружаю 1000 пользователей с offset = 81000
# Выгружаю 1000 пользователей с offset = 82000
# Выгружаю 1000 пользователей с offset = 83000
# Выгружаю 1000 пользователей с offset = 84000
# Выгружаю 1000 пользователей с offset = 85000
# Выгружаю 1000 пользователей с offset = 86000
# Выгружаю 1000 пользователей с offset = 87000
# Выгружаю 1000 пользователей с offset = 88000
# Выгружаю 1000 пользователей с offset = 89000
# Выгружаю 1000 пользователей с offset = 90000
# Выгружаю 1000 пользователей с offset = 91000
# Выгружаю 1000 пользователей с offset = 92000
# Выгружаю 1000 пользователей с offset = 93000
# Выгружаю 1000 пользователей с offset = 94000
# Выгружаю 1000 пользователей с offset = 95000
# Выгружаю 1000 пользователей с offset = 96000
# Выгружаю 1000 пользователей с offset = 97000
# Выгружаю 1000 пользователей с offset = 98000
# Выгружаю 1000 пользователей с offset = 99000

# %%
# выберем последнего пользователя
data['response']['items'][-1]
# Out:
# 6230213

# %% [markdown]
# # Ограничение по частоте запросов
#
# В API частот добавляют ограничение по частоте запросов, чтобы отдельно взятые пользователи слишком сильно не перегружали  сервер. Подобное ограничение есть и у ВКонтакте, в документации https://vk.com/dev/api_requests?f=3.1.%20Частотные%20ограничения() которой указано, что можно делать не более 3-х запросов в секунду.
#
# Чтобы не следить за частотой отправки запросов с секундомером в руках, мы можем после каждого запроса делать паузу. В этом случае, даже если код будет выполняться на самом быстром компьютере, мы не нарушим установленное ограничение, т.к. периодичность отправки запросов будет искусственно замедлена. Воспользуемся библиотекой time и методом sleep (пауза в 0.5 секунды добавлена в конце цикла):

# %%
import time  
  
count = 1000  
offset = 0  
user_ids = []  
while offset < 10000:  
    print('Выгружаю {} пользователей с offset = {}'.format(count, offset))     
    params = {  
        'group_id': 'vk',  
        'v': 5.95,  
        'count': count,  
        'offset': offset,  
        'access_token': TOKEN  
    }    
    # такой же запрос, как в прошлый раз  
    r = requests.get(url, params = params)  
    data = r.json()     
    user_ids += data['response']['items']    
  
    # увеличиваем смещение на количество строк выгрузки  
    offset += count  
    
    print('Ожидаю 0.5 секунды...')  
    time.sleep(0.5)
# Out:
# Выгружаю 1000 пользователей с offset = 0
# Ожидаю 0.5 секунды...
# Выгружаю 1000 пользователей с offset = 1000
# Ожидаю 0.5 секунды...
# Выгружаю 1000 пользователей с offset = 2000
# Ожидаю 0.5 секунды...
# Выгружаю 1000 пользователей с offset = 3000
# Ожидаю 0.5 секунды...
# Выгружаю 1000 пользователей с offset = 4000
# Ожидаю 0.5 секунды...
# Выгружаю 1000 пользователей с offset = 5000
# Ожидаю 0.5 секунды...
# Выгружаю 1000 пользователей с offset = 6000
# Ожидаю 0.5 секунды...
# Выгружаю 1000 пользователей с offset = 7000
# Ожидаю 0.5 секунды...
# Выгружаю 1000 пользователей с offset = 8000
# Ожидаю 0.5 секунды...
# Выгружаю 1000 пользователей с offset = 9000
# Ожидаю 0.5 секунды...

# %% [markdown]
# # Лайки, репосты и комментарии
#
# Ещё одна полезная вещь, которую можно получить,  —  это количество взаимодействий с постами через API новостной ленты (https://vk.com/dev/wall). На данном этапе будем использовать самый простой вариант: берем последние 10 постов группы. Мы продолжаем работать с группой https://vk.com/vk.
#
# Начнем с  формирования запроса к API ВКонтакте методом wall.get():

# %%
import requests  
from pprint import pprint  
  
url = 'https://api.vk.com/method/wall.get'  
params = {  
    'domain': 'vk',  
    'filter': 'owner',  
    'count': 10,  
    'offset': 0,  
    'access_token': TOKEN,  
    'v': 5.95  
}  
response = requests.get(url, params = params)  
response.json()
# => {'response': {'count': 421,
#      'items': [{'id': 1132798, 
#        'from_id': -22822305,
#        'owner_id': -22822305,
#        'date': 1603796912, 
#        'marked_as_ads': 0,  
#        'post_type': 'post',
#        'text': 'Встречайте музыкальных кураторов...
# Out:
# {'response': {'count': 430,
#   'items': [{'id': 1167538,
#     'from_id': -22822305,
#     'owner_id': -22822305,
#     'date': 1617262100,
#     'marked_as_ads': 0,
#     'post_type': 'post',
#     'text': '',
#     'copy_history': [{'id': 362,
#       'owner_id': 92933,
#       'from_id': 92933,
#       'date': 1617261054,
#       'post_type': 'post',
#       'text': 'Наша команда любит шутить на 1 апреля. Каждый год мы делаем на сайте или в приложении какие-нибудь забавные мелочи. В этот раз поднимем настроение абсолютно серьёзной новостью: спустя пять лет ВКонтакте обновляет приложение для iPad. Это не шутка! \n\nМы видели, с каким энтузиазмом многие ждали этого момента, ожидание даже стало мемом. И хотя планшетами пользуются несоизмеримо реже, чем смартфонами или ноутбуками, мы всегда учитываем отзывы и пожелания, которые получаем. Это помогает запускать действительно востребованные продукты. Обновлённое приложение поможет общаться и решать повседневные вопросы — будь то быт, работа или учёба — с любого устройства.\n\nВ прошлом году мы масштабно обновили приложение на смартфонах и запустили ВКонтакте больше двух сотен больших обновлений. Все они теперь доступны и на iPad. Например, «Клипы» — короткие вертикальные видео с AR-эффектами. Или бесплатные групповые звонки на 128 человек без ограничения по времени. А ещё — распознавание голосовых сообщений в мессенджере и обновлённые рекомендации в Музыке. На iPad работает и платформа сервисов — в том числе Такси ВКонтакте, Еда ВКонтакте и другие мини-приложения. \n\nЗа последний год ВКонтакте круто выросла и по аудитории, и по продуктовым показателям, и в плане технологий. За год количество пользователей в России увеличилось на 4,5% — нас уже 73,4 млн. Каждый день клипы смотрят 16 млн человек, каждый месяц голосовыми сообщениями обмениваются 33 млн человек, а общее число сообщений выросло на 50% — до 15 млрд в сутки. \n\nБудем радовать и другими долгожданными новинками — с такой сильной командой, уверена, для нас нет ничего невозможного.',
#       'attachments': [{'type': 'photo',
#         'photo': {'album_id': -7,
#          'date': 1617260986,
#          'id': 457239972,
#          'owner_id': 92933,
#          'has_tags': False,
#          'access_key': '7dfbea4574b4a5e907',
#          'sizes': [{'height': 122,
#            'url': 'https://sun9-68.userapi.com/impg/sP_-VfmKoESuwFkNrUTRixb48ZN6OOW-9MHa7A/X3AaTw43JV8.jpg?size=130x122&quality=96&sign=e3055748b784f08a0557a01a6b72937a&c_uniq_tag=DcsjOz8QHCPyGpEsM_K1pzqSqn_RKBS4kj-0cRPjtLg&type=album',
#            'type': 'm',
#            'width': 130},
#           {'height': 122,
#            'url': 'https://sun9-68.userapi.com/impg/sP_-VfmKoESuwFkNrUTRixb48ZN6OOW-9MHa7A/X3AaTw43JV8.jpg?size=130x122&quality=96&sign=e3055748b784f08a0557a01a6b72937a&c_uniq_tag=DcsjOz8QHCPyGpEsM_K1pzqSqn_RKBS4kj-0cRPjtLg&type=album',
#            'type': 'o',
#            'width': 130},
#           {'height': 188,
#            'url': 'https://sun9-68.userapi.com/impg/sP_-VfmKoESuwFkNrUTRixb48ZN6OOW-9MHa7A/X3AaTw43JV8.jpg?size

#           'type': 'p',
#           'width': 200},
#          {'height': 213,
#           'url': 'https://sun4-10.userapi.com/impg/6g5_Dwx9HStP46u4sdreORK9IpmndXsvTAF5Qg/6MYnJ-EGK5U.jpg?size=320x213&quality=96&crop=131,0,1289,858&sign=8286523416627fa510956a24503cecb9&c_uniq_tag=8YKfsmffhO-5fxV0GMAVMi14C9uDSEAqp87xnsx2J-g&type=album',
#           'type': 'q',
#           'width': 320},
#          {'height': 340,
#           'url': 'https://sun4-10.userapi.com/impg/6g5_Dwx9HStP46u4sdreORK9IpmndXsvTAF5Qg/6MYnJ-EGK5U.jpg?size=510x340&quality=96&crop=132,0,1287,858&sign=9f0bd3e208ff6438b60c086969177886&c_uniq_tag=louH-6xUzjm4-xr-UEkPbRe1PKpmStEl1q6Sqxw1Bns&type=album',
#           'type': 'r',
#           'width': 510},
#          {'height': 42,
#           'url': 'https://sun4-10.userapi.com/impg/6g5_Dwx9HStP46u4sdreORK9IpmndXsvTAF5Qg/6MYnJ-EGK5U.jpg?size=75x41&quality=96&sign=a4330c5294051dbfdd04396fd291fc60&c_uniq_tag=Z8GJoDGoo2LKaakRwKPx9WHAX14qz0m_QHsFSNYRt0E&type=album',
#           'type': 's',
#           'width': 75},
#          {'height': 858,
#           'url': 'https://sun4-10.userapi.com/impg/6g5_Dwx9HStP46u4sdreORK9IpmndXsvTAF5Qg/6MYnJ-EGK5U.jpg?size=1552x858&quality=96&sign=a4c9aecc259537f49932c694dbb89767&c_uniq_tag=DawSDe0TaC3D5BWR1MOH-khBzhXsPX3xceVZ5qJrTvk&type=album',
#           'type': 'w',
#           'width': 1552},
#          {'height': 334,
#           'url': 'https://sun4-10.userapi.com/impg/6g5_Dwx9HStP46u4sdreORK9IpmndXsvTAF5Qg/6MYnJ-EGK5U.jpg?size=604x334&quality=96&sign=01a61fe7687805f3f8a115becd526ece&c_uniq_tag=50TRGmM8BiOS88L9wb9KbKgwwpstP8XrS9FKI8DIANM&type=album',
#           'type': 'x',
#           'width': 604},
#          {'height': 446,
#           'url': 'https://sun4-10.userapi.com/impg/6g5_Dwx9HStP46u4sdreORK9IpmndXsvTAF5Qg/6MYnJ-EGK5U.jpg?size=807x446&quality=96&sign=e89121ee847937b4b80705b2fdfdc7ce&c_uniq_tag=RBc8pfIMoOpb5pJm8BThUJQPcq913F6rL2C4lXjBVfU&type=album',
#           'type': 'y',
#           'width': 807},
#          {'height': 708,
#           'url': 'https://sun4-10.userapi.com/impg/6g5_Dwx9HStP46u4sdreORK9IpmndXsvTAF5Qg/6MYnJ-EGK5U.jpg?size=1280x708&quality=96&sign=1c851b92b537973731e8e8383b6b52e5&c_uniq_tag=vgXlGR7JXBSXjtO-yVJIdVp-mz4mnlz69v-YDbK49SQ&type=album',
#           'type': 'z',
#           'width': 1280}],
#         'text': ''},
#        'button': {'title': 'Read',
#         'action': {'type': 'open_url', 'url': 'https://vk.com/blog/2020'}}}}],
#     'post_source': {'type': 'vk'},
#     'comments': {'count': 6115, 'can_post': 1, 'groups_can_post': True},
#     'likes': {'count': 2758, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#     'reposts': {'count': 721, 'user_reposted': 0},
#     'views': {'count': 1353212}},
#    {'id': 1148195,
#     'from_id': -22822305,
#     'owner_id': -22822305,
#     'date': 1608897114,
#     'marked_as_ads': 0,
#     'post_type': 'post',
#     'text': 'Вот уже четвёртый год мы поддерживаем добрые традиции — создаём особенный подарок и все средства от его продажи направляем на благотворительность. В 2020-м героем стал бычок Борис. \n\nВ наступающем году мы отправим собранные деньги фондам:\n• [club38922126|свет.дети] — помогает в лечении ребятам с онкологическими заболеваниями;\n• [club62672621|Антон тут рядом] — поддерживает людей с аутизмом; \n• [club20012308|Мята] — воплощает мечты воспитанников детских домов и раскрывает их таланты.\n\nЭтот год был не самым простым и для благотворительных организаций, поэтому поддержка нужна как никогда. Стоимость подарка стандартная — пять голосов. Его можно отправлять до 15 января сколько угодно раз. Поздравляйте близких и помогайте тем, кто нуждается в этом.',
#     'attachments': [{'type': 'photo',
#       'photo': {'album_id': -7,
#        'date': 1608897075,
#        'id': 457315551,
#        'owner_id': -22822305,
#        'has_tags': False,
#        'access_key': '5cc8553bed742a7845',
#        'post_id': 1148195,
#        'sizes': [{'height': 89,
#          'url': 'https://sun4-16.userapi.com/impg/oevzo55AH2Fvj2O4mAfRagaZDkgsG0KFfBRmnw/Z389Qx1saTk.jpg?size=130x89&quality=96&sign=fb00c4d369063f86c248d254d56bcc5c&c_uniq_tag=StBzQL73OCmCHQrhua1Os_MstNqgmmIVmUw3IX9oLw8&type=album',
#          'type': 'm',
#          'width': 130},
#         {'height': 89,
#          'url': 'https://sun4-16.userapi.com/impg/oevzo55AH2Fvj2O4mAfRagaZDkgsG0KFfBRmnw/Z389Qx1saTk.jpg?size=130x89&quality=96&sign=fb00c4d369063f86c248d254d56bcc5c&c_uniq_tag=StBzQL73OCmCHQrhua1Os_MstNqgmmIVmUw3IX9oLw8&type=album',
#          'type': 'o',
#          'width': 130},
#         {'height': 137,
#          'url': 'https://sun4-16.userapi.com/impg/oevzo55AH2Fvj2O4mAfRagaZDkgsG0KFfBRmnw/Z389Qx1saTk.jpg?size=200x137&quality=96&sign=ddbf50b8dfac4b956cc260a9ec8845fd&c_uniq_tag=L1fCkO4XXDqfrJ19d-cOsHlgY3bGYTnqnNRsGRjg-vQ&type=album',
#          'type': 'p',
#          'width': 200},
#         {'height': 219,
#          'url': 'https://sun4-16.userapi.com/impg/oevzo55AH2Fvj2O4mAfRagaZDkgsG0KFfBRmnw/Z389Qx1saTk.jpg?size=320x219&quality=96&sign=0a024ffd99ade6d8ee6ee0b6fca78565&c_uniq_tag=1-vylTwR_E94f2W73JnG6In52O8jrvAcmdyfUJ_v0SY&type=album',
#          'type': 'q',
#          'width': 320},
#         {'height': 349,
#          'url': 'https://sun4-16.userapi.com/impg/oevzo55AH2Fvj2O4mAfRagaZDkgsG0KFfBRmnw/Z389Qx1saTk.jpg?size=510x349&quality=96&sign=4227a1c29d2d234d0c65cd30d9d58fd5&c_uniq_tag=4D-r6l8ZzIus5NsFNDZLyAMOaGFMOkXeZ5l5f5ZZzYI&type=album',
#          'type': 'r',
#          'width': 510},
#         {'height': 51,
#          'url': 'https://sun4-16.userapi.com/impg/oevzo55AH2Fvj2O4mAfRagaZDkgsG0KFfBRmnw/Z389Qx1saTk.jpg?size=75x51&quality=96&sign=200dabe60856628a04dfcd0e6204974d&c_uniq_tag=bdwN15n4rLnspNpYimJmtZSSTxrk_GRJ4ZkP1KU-BUQ&type=album',
#          'type': 's',
#          'width': 75},
#         {'height': 1505,
#          'url': 'https://sun4-16.userapi.com/impg/oevzo55AH2Fvj2O4mAfRagaZDkgsG0KFfBRmnw/Z389Qx1saTk.jpg?size=2200x1505&quality=96&sign=adc1b3b44fef46d3f7f0be0b462d6117&c_uniq_tag=nTBZubaMAVqJuI8S4fDtX01dVUI_yHcJZhn9NMWTekY&type=album',
#          'type': 'w',
#          'width': 2200},
#         {'height': 413,
#          'url': 'https://sun4-16.userapi.com/impg/oevzo55AH2Fvj2O4mAfRagaZDkgsG0KFfBRmnw/Z389Qx1saTk.jpg?size=604x413&quality=96&sign=dbed76139599da5af268d57222448622&c_uniq_tag=sm3r70YyXE7X_fx8uit8hki-LsxGoJLaespN-Pn1j1o&type=album',
#          'type': 'x',
#          'width': 604},
#         {'height': 552,
#          'url': 'https://sun4-16.userapi.com/impg/oevzo55AH2Fvj2O4mAfRagaZDkgsG0KFfBRmnw/Z389Qx1saTk.jpg?size=807x552&quality=96&sign=e1ff808d046d3c16d09852605e1cefac&c_uniq_tag=-B6YDBTp5XysGBpQe3BtdSeWWesBPFhQHelLLpmrU6A&type=album',
#          'type': 'y',
#          'width': 807},
#         {'height': 876,
#          'url': 'https://sun4-16.userapi.com/impg/oevzo55AH2Fvj2O4mAfRagaZDkgsG0KFfBRmnw/Z389Qx1saTk.jpg?size=1280x876&quality=96&sign=0bce97ce9d9ae23971afd496004e6370&c_uniq_tag=JeEObN0xrIZroIH3qcsxMPHhu62Ka662KpY1rPCmZEc&type=album',
#          'type': 'z',
#          'width': 1280}],
#        'text': '',
#        'user_id': 100}}],
#     'post_source': {'type': 'vk'},
#     'comments': {'count': 3115, 'can_post': 1, 'groups_can_post': True},
#     'likes': {'count': 4610, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#     'reposts': {'count': 727, 'user_reposted': 0},
#     'views': {'count': 1898522}},
#    {'id': 1148026,
#     'from_id': -22822305,
#     'owner_id': -22822305,
#     'date': 1608892335,
#     'marked_as_ads': 0,
#     'post_type': 'post',
#     'text': '',
#     'copy_history': [{'id': 18910,
#       'owner_id': 6492,
#       'from_id': 6492,
#       'date': 1608892202,
#       'post_type': 'post',
#       'text': '2020-й запомнится мне как год, полный противоречий. \n\nМы испытали на себе все прелести форс-мажоров. Многое пришлось менять, и некоторые решения принимались буквально на лету — от мгновенного перехода всей [club147415323|Команды] на удалёнку до серьёзного пересмотра планов компании.\n\nВ то же время в новой реальности ВКонтакте стала центром притяжения: сюда перетекли бизнесы, встречи, обсуждения, именно здесь многие следили за новостями про COVID-19, рассказывали о своих маленьких радостях или сложностях, поддерживали близких. А мы предоставили для этого всё нужное. Год выдался насыщенным — итогов набралось на целый раздел: vk.com/2020\n\nА здесь хочу выделить три ключевых события, которые впечатлили меня больше всего.\n \n• Мы сделали рекордное количество продуктовых изменений за всю историю компании. Запускали новые сервисы, улучшали существующие, исправляли и оптимизировали. Всего успели представить больше 220 только крупных обновлений.\n\n• Мы доказали, что идея суперприложения работает. Последние три года мы последовательно шли к реализации супераппа, развивая платформу [https://vk.com/services|мини-приложений]. Результаты 2020-го нас поразили — например, уже сегодня люди не выходя из VK совершают миллион поездок на Такси ВКонтакте в неделю. Это доказывает, что мы на правильном пути. \n\n• Мы рискнули и сделали ставку на формат коротких вертикальных видео. Запрос на него мы видели давно. В этом году удалось за несколько месяцев поднять технически сложный проект Клипы ВКонтакте — и уже спустя полгода им пользуются 14 миллионов человек ежедневно. Мы верим, что у формата коротких видео большое будущее.\n\nИ самое важное: мы не просто закрывали задачи, а помогали окружающим. Информировали, развлекали, давали возможность общаться — даже тем, кто не зарегистрирован ВКонтакте. Занимались благотворительностью, ездили сдавать кровь, вместе с пользователями [https://vk.com/press/birthday-14-results|собрали] 15 миллионов рублей для фонда «Подари жизнь». Поддерживали предпринимателей: за четыре месяца [https://vk.com/wall-19542789_119123|акции] начислили им больше 242 миллионов рублей на рекламные кампании. \n\nВесь год мы работали, чтобы каждый переносил самоизоляцию чуть легче и мог общаться с друзьями и близкими, где бы они ни находились. Спасибо всем, кто был рядом и проводил это сложное время с нами. Мы дорожим вашим доверием и в новом году постараемся стать ещё лучше. С наступающим!',
#       'attachments': [{'type': 'photo',
#         'photo': {'album_id': -7,
#          'date': 1608880944,
#          'id': 457256674,
#          'owner_id': 6492,
#          'has_tags': False,
#          'access_key': '0bb8c72cc89ee111ec',
#          'post_id': 18910,
#          'sizes': [{'height': 94,
#            'url': 'https://sun4-17.userapi.com/impg/GB8wOFeAkepgDQnH_Y1Gm-RH0mKMbtWbOiksCg/oRHnxFu4W4k.jpg?size=130x94&quality=96&sign=849229778ea52a4f9bc4befe598dee0a&c_uniq_tag=lLB_AU7h7vz0PiGYS-9L1gD3qZrc-sAykBVE_tbPOh8&type=album',
#            'type': 'm',
#            'width': 130},
#           {'height': 94,
#            'url': 'https://sun4-17.userapi.com/impg/GB8wOFeAkepgDQnH_Y1Gm-RH0mKMbtWbOiksCg/oRHnxFu4W4k.jpg?size=130x94&quality=96&sign=849229778ea52a4f9bc4befe598dee0a&c_uniq_tag=lLB_AU7h7vz0PiGYS-9L1gD3qZrc-sAykBVE_tbPOh8&type=album',
#            'type': 'o',
#            'width': 130},
#           {'height': 145,
#            'url': 'https://sun4-17.userapi.com/impg/GB8wOFeAkepgDQnH_Y1Gm-RH0mKMbtWbOiksCg/oRHnxFu4W4k.jpg?size=200x145&quality=96&sign=0b9be887af0182a5934e953417340efb&c_uniq_tag=7IKwRGmqa2xvOuYoQRZRGR1zQyTm6s2Ke2FrZPu54iQ&type=album',
#            'type': 'p',
#            'width': 200},
#           {'height': 232,
#            'url': 'https://sun4-17.userapi.com/impg/GB8wOFeAkepgDQnH_Y1Gm-RH0mKMbtWbOiksCg/oRHnxFu4W4k.jpg?size=320x232&quality=96&sign=dd2a0951ee929ccdd2d24f39db906716&c_uniq_tag=AxLRlXGGhp5-05kYaxtOof5IDW947HQvVgxTPzFpOc0&type=album',
#            'type': 'q',
#            'width': 320},
#           {'height': 370,
#            'url': 'https://sun4-17.userapi.com/impg/GB8wOFeAkepgDQnH_Y1Gm-RH0mKMbtWbOiksCg/oRHnxFu4W4k.jpg?size=510x370&quality=96&sign=4e7ee4ca49dd8301dc9edd2b23976f0a&c_uniq_tag=A_Yj5QR3IuFdGGHCNmg2klDBPUpVcW9iGUFHvM3JlQM&type=album',
#            'type': 'r',
#            'width': 510},
#           {'height': 54,
#            'url': 'https://sun4-17.userapi.com/impg/GB8wOFeAkepgDQnH_Y1Gm-RH0mKMbtWbOiksCg/oRHnxFu4W4k.jpg?size=75x54&quality=96&sign=8d2616fd3189f42125233bab27bc25d7&c_uniq_tag=Pjn4MyYrvU15JTnsUG6dMMa9KqlM7ELNsQJoCWIAWwo&type=album',
#            'type': 's',
#            'width': 75},
#           {'height': 1389,
#            'url': 'https://sun4-17.userapi.com/impg/GB8wOFeAkepgDQnH_Y1Gm-RH0mKMbtWbOiksCg/oRHnxFu4W4k.jpg?size=1915x1389&quality=96&sign=f515ade9d8b0c246ca870901d58a883e&c_uniq_tag=Rz3QEoK2FqeHiniqNi2uWwmSPvnvU1q5MZnTyUDAgs0&type=album',
#            'type': 'w',
#            'width': 1915},
#           {'height': 438,
#            'url': 'https://sun4-17.userapi.com/impg/GB8wOFeAkepgDQnH_Y1Gm-RH0mKMbtWbOiksCg/oRHnxFu4W4k.jpg?size=604x438&quality=96&sign=6f04f3962433f9d88440d4b02153d655&c_uniq_tag=1NB-dgAzf-9lYmaoWlVHfCl1pNLxiQI0Bx6j1P5AIgQ&type=album',
#            'type': 'x',
#            'width': 604},
#           {'height': 585,
#            'url': 'https://sun4-17.userapi.com/impg/GB8wOFeAkepgDQnH_Y1Gm-RH0mKMbtWbOiksCg/oRHnxFu4W4k.jpg?size=807x585&quality=96&sign=6d3b5e9c7c699200c1700e6af0f67c69&c_uniq_tag=ZmnYIBPdh78aZHQo1_N2OifWqmrZiZlMBSEfKNF2L7g&type=album',
#            'type': 'y',
#            'width': 807},
#           {'height': 928,
#            'url': 'https://sun4-17.userapi.com/impg/GB8wOFeAkepgDQnH_Y1Gm-RH0mKMbtWbOiksCg/oRHnxFu4W4k.jpg?size=1280x928&quality=96&sign=b68c92965f0fb29c2aeedb3a9026085f&c_uniq_tag=Dn80hSuRKPd-9x-FwyJc-6bUKM1HVJEtf9sF1lCsVuM&type=album',
#            'type': 'z',
#            'width': 1280}],
#          'text': ''}}],
#       'post_source': {'type': 'vk'}}],
#     'post_source': {'type': 'api', 'platform': 'android'},
#     'comments': {'count': 625, 'can_post': 1, 'groups_can_post': True},
#     'likes': {'count': 1709, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#     'reposts': {'count': 336, 'user_reposted': 0},
#     'views': {'count': 950991}},
#    {'id': 1146176,
#     'from_id': -22822305,
#     'owner_id': -22822305,
#     'date': 1608548489,
#     'marked_as_ads': 0,
#     'post_type': 'post',
#     'text': 'Что поможет найти лучший автосервис в городе, кафе с самыми свежими булочками, художника, который будет дарить вдохновение каждый день, или группу, музыку которой захочется оставить на повторе? Конечно, совет друзей — тех, кто знает вас лучше всего и чьему мнению можно доверять.\n\nНо далеко не всегда у нас есть время, чтобы написать отзыв у себя в профиле или поделиться им в чате. Поэтому мы добавили в сообщества кнопку «Рекомендовать». С её помощью можно отметить понравившиеся группы и публичные страницы, не подписываясь на их обновления. Работает как
type=album',
#          'type': 'y',
#          'width': 807},
#         {'height': 1024,
#          'url': 'https://sun4-11.userapi.com/impg/bhyVeKT81ybTL0RziUcQRLXhpPNAkddKpV-4jg/NiW_lu5g8mM.jpg?size=1280x1024&quality=96&sign=9d9a3ce8a799cf883273be78cda70143&c_uniq_tag=pSHxhG5Uv6TOCOIWVX5QjtxJqKIaO6mHUgbV3NqY94A&type=album',
#          'type': 'z',
#          'width': 1280}],
#        'text': '',
#        'user_id': 100}}],
#     'post_source': {'type': 'vk'},
#     'comments': {'count': 768, 'can_post': 1, 'groups_can_post': True},
#     'likes': {'count': 2330, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#     'reposts': {'count': 340, 'user_reposted': 0},
#     'views': {'count': 1017754},
#     'edited': 1610985451},
#    {'id': 1140804,
#     'from_id': -22822305,
#     'owner_id': -22822305,
#     'date': 1608033618,
#     'marked_as_ads': 0,
#     'post_type': 'post',
#     'text': 'В наступающий год — со свежим дизайном!\n\nВо время тестирования нового фирменного стиля ВКонтакте мы получили много обращений с просьбами включить его для всех пользователей. Сделано! Внешний вид сайта изменится уже сегодня. Актуальный логотип, собственный шрифт и лёгкая цветовая гамма сделают все версии VK визуально едиными и узнаваемыми.\n\nВ октябре новую версию ВКонтакте для компьютера оценили 100 тысяч добровольцев, из них 78% продолжили использовать свежий дизайн. Пробный запуск помог нам понять, что переход будет плавным: статистика показывает, что тестовой группе не пришлось менять свои привычки.\n\nЧитайте про обновление дизайна в нашем [vk.com/blog/design-2020|блоге].',
#     'attachments': [{'type': 'photo',
#       'photo': {'album_id': -7,
#        'date': 1608033464,
#        'id': 457314448,
#        'owner_id': -22822305,
#        'has_tags': False,
#        'access_key': 'f5c6d445d83e146d56',
#        'post_id': 1140804,
#        'sizes': [{'height': 100,
#          'url': 'https://sun4-11.userapi.com/impg/fk_4bvWLnCDfmtKHPedHLKY_xRW638IxCBXNIQ/vAkd86TVEfM.jpg?size=130x100&quality=96&sign=1377034afb55696ede2c281462a1d683&c_uniq_tag=Oe9cFwzRKgM174IeNZKLNSjV6IwHEjeWqh_pvVFywBg&type=album',
#          'type': 'm',
#          'width': 130},
#         {'height': 100,
#          'url': 'https://sun4-11.userapi.com/impg/fk_4bvWLnCDfmtKHPedHLKY_xRW638IxCBXNIQ/vAkd86TVEfM.jpg?size=130x100&quality=96&sign=1377034afb55696ede2c281462a1d683&c_uniq_tag=Oe9cFwzRKgM174IeNZKLNSjV6IwHEjeWqh_pvVFywBg&type=album',
#          'type': 'o',
#          'width': 130},
#         {'height': 153,
#          'url': 'https://sun4-11.userapi.com/impg/fk_4bvWLnCDfmtKHPedHLKY_xRW638IxCBXNIQ/vAkd86TVEfM.jpg?size=200x153&quality=96&sign=b5a1220567228fde00c35ab75d293c0a&c_uniq_tag=AfjWtbQgsjC7D-yDVeCVuF_ul3rcuKeqjoIm7xfaj60&type=album',
#          'type': 'p',
#          'width': 200},
#         {'height': 245,
#          'url': 'https://sun4-11.userapi.com/impg/fk_4bvWLnCDfmtKHPedHLKY_xRW638IxCBXNIQ/vAkd86TVEfM.jpg?size=320x245&quality=96&sign=4a177121e78f1890b137f30a46db6e5f&c_uniq_tag=0VEBtp9z587O9tLVsj-rv4WihoD1kJfOvoQd97DK2GA&type=album',
#          'type': 'q',
#          'width': 320},
#         {'height': 391,
#          'url': 'https://sun4-11.userapi.com/impg/fk_4bvWLnCDfmtKHPedHLKY_xRW638IxCBXNIQ/vAkd86TVEfM.jpg?size=510x391&quality=96&sign=dfad39aff93623d76bd3c6a702ac23ba&c_uniq_tag=TbxRwxp9oTEDkVJcDUCxYB5kScY-cyk680GGSAAhvm8&type=album',
#          'type': 'r',
#          'width': 510},
#         {'height': 58,
#          'url': 'https://sun4-11.userapi.com/impg/fk_4bvWLnCDfmtKHPedHLKY_xRW638IxCBXNIQ/vAkd86TVEfM.jpg?size=75x57&quality=96&sign=b5b7f6e4c9c991526984fbbb2d6a5c1c&c_uniq_tag=fhwHUgtDzHRbYX3Qhi33UnPFuMpuuNhbul8-eOX2m2k&type=album',
#          'type': 's',
#          'width': 75},
#         {'height': 1963,
#          'url': 'https://sun4-11.userapi.com/impg/fk_4bvWLnCDfmtKHPedHLKY_xRW638IxCBXNIQ/vAkd86TVEfM.jpg?size=2560x1963&quality=96&sign=b028fe3f6d81badb1d513113d1187ece&c_uniq_tag=yNcVIic0hBqrG9bFSmP_5aPBih-slQpOzg9W9KJa2bw&type=album',
#          'type': 'w',
#          'width': 2560},
#         {'height': 463,
#          'url': 'https://sun4-11.userapi.com/impg/fk_4bvWLnCDfmtKHPedHLKY_xRW638IxCBXNIQ/vAkd86TVEfM.jpg?size=604x463&quality=96&sign=6fb58ca40402363c1a3ccb0a4c05b52b&c_uniq_tag=Q8YdjtuoGuX8rJ41m0rCpQvMuqapSAqGGOdCwF3BtmI&type=album',
#          'type': 'x',
#          'width': 604},
#         {'height': 618,
#          'url': 'https://sun4-11.userapi.com/impg/fk_4bvWLnCDfmtKHPedHLKY_xRW638IxCBXNIQ/vAkd86TVEfM.jpg?size=807x619&quality=96&sign=9a2735a6f4ae9155822c3eb0ba74744f&c_uniq_tag=EXJimaAgQbw-yxBqQZHkkOxZDvKxkvCqgNjlAgynCaw&type=album',
#          'type': 'y',
#          'width': 807},
#         {'height': 981,
#          'url': 'https://sun4-11.userapi.com/impg/fk_4bvWLnCDfmtKHPedHLKY_xRW638IxCBXNIQ/vAkd86TVEfM.jpg?size=1280x981&quality=96&sign=972aa25ad0f77da38a3cfe3145eae104&c_uniq_tag=rvnD6-xRneQLb8Ti25XySgnDQ5rU9DrpvMwLzzNE0FE&type=album',
#          'type': 'z',
#          'width': 1280}],
#        'text': '',
#        'user_id': 100}}],
#     'post_source': {'type': 'vk'},
#     'comments': {'count': 3251, 'can_post': 1, 'groups_can_post': True},
#     'likes': {'count': 5066, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#     'reposts': {'count': 1766, 'user_reposted': 0},
#     'views': {'count': 1297154}},
#    {'id': 1140438,
#     'from_id': -22822305,
#     'owner_id': -22822305,
#     'date': 1607943610,
#     'marked_as_ads': 0,
#     'post_type': 'post',
#     'text': 'В этом году у нас было много тем для обсуждения. Составили список событий и персон, о которых чаще всего говорили в комментариях и записях ВКонтакте. \n\nГлавной темой ожидаемо стала пандемия COVID-19. Почти все писали о коронавирусе и о том, как важно соблюдать меры предосторожности и оставаться дома. Также в течение всего года не утихали политические дискуссии. В тройку самых волнующих событий вошли протесты в Беларуси, Хабаровске и голосование по поправкам к Конституции России. \n\nВ десятке самых упоминаемых персон ВКонтакте оказались пять политиков, три музыканта и два спортсмена. Уже несколько лет подряд первое место в рейтинге занимает президент России Владимир Путин. Вторая позиция досталась звёздам k-pop — группе BTS, а третья — рэперу MORGENSHTERN. На фоне событий в Беларуси и выборов в США часто говорили про Александра Лукашенко и Дональда Трампа.\n\n2020-й отметился ещё и громкими игровыми событиями: ВКонтакте активно обсуждали выход консолей PlayStation, Xbox и игру Fortnite. Из значимых культурных мероприятий в рейтинге — премия «Оскар», а из спортивных — Лига чемпионов.\n\nЗаглядывайте в специальный раздел, где мы продолжаем делиться итогами года ВКонтакте: vk.com/2020',
#     'attachments': [{'type': 'link',
#       'link': {'url': 'http://vk.com/2020',
#        'title': 'Итоги года ВКонтакте',
#        'caption': 'vk.com',
#        'description': 'Музыка, люди и события, которыми запомнится 2020-й',
#        'photo': {'album_id': -26,
#         'date': 1607711313,
#         'id': 457315789,
#         'owner_id': 2000013407,
#         'has_tags': False,
#         'sizes': [{'height': 480,
#           'url': 'https://sun9-12.userapi.com/impg/c857424/v857424176/23c0f8/i8RdmetIfrs.jpg?size=1074x480&quality=96&sign=13fe2bdd398428452ef6d297cf7dd14c&c_uniq_tag=Ivrczz5oc8eVhTaxj8rfv95Mf4OSvUu1SGweJTGWXec&type=share',
#           'type': 'k',
#           'width': 1074},
#          {'height': 240,
#           'url': 'https://sun9-12.userapi.com/impg/c857424/v857424176/23c0f8/i8RdmetIfrs.jpg?size=537x240&quality=96&sign=e7a0b8daf0c65a5c9bc73058c8747405&c_uniq_tag=fXW8zseo3kdTblk9I9HskTHvz4ObF5SrchNAZU7UssM&type=share',
#           'type': 'l',
#           'width': 537},
#          {'height': 70,
#           'url': 'https://sun9-12.userapi.com/impg/c857424/v857424176/23c0f8/i8RdmetIfrs.jpg?size=130x80&quality=96&crop=147,0,780,480&sign=fcbf21d74842a0d3b190a358035e859a&c_uniq_tag=DDcyPca-mhWGDF9By2i5chDl3ncOMWL3Cw0jkIal9WM&type=share',
#           'type': 'm',
#           'width': 130},
#          {'height': 140,
#           'url': 'https://sun9-12.userapi.com/impg/c857424/v857424176/23c0f8/i8RdmetIfrs.jpg?size=260x140&quality=96&crop=91,0,891,480&sign=0803de5c161506d202a615277debeeba&c_uniq_tag=enotv_AW5EJGBgMG6jfEuD9Td3vD-pY_84JP88OB3K0&type=share',
#           'type': 'p',
#           'width': 260},
#          {'height': 35,
#           'url': 'https://sun9-12.userapi.com/impg/c857424/v857424176/23c0f8/i8RdmetIfrs.jpg?size=75x35&quality=96&crop=22,0,1029,480&sign=f981af0df53996e1be62d6d77444cc2b&c_uniq_tag=ImZceLRXeORrQR19qLNkg18xxbUSQ79_wYTtmhWcbYQ&type=share',
#           'type': 's',
#           'width': 75},
#          {'height': 80,
#           'url': 'https://sun9-12.userapi.com/impg/c857424/v857424176/23c0f8/i8RdmetIfrs.jpg?size=150x80&quality=96&crop=87,0,900,480&sign=b2f723b6f2a0e7bce2a2a92966803fba&c_uniq_tag=HqC8TdhQ9SYyI8YJi057ikC71RYAqNJmKVxfwUNUurI&type=share',
#           'type': 'x',
#           'width': 150}],
#         'text': '',
#         'user_id': 100}}}],
#     'post_source': {'type': 'vk'},
#     'comments': {'count': 268, 'can_post': 1, 'groups_can_post': True},
#     'likes': {'count': 1862, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#     'reposts': {'count': 215, 'user_reposted': 0},
#     'views': {'count': 512715}},
#    {'id': 1139363,
#     'from_id': -22822305,
#     'owner_id': -22822305,
#     'date': 1607689227,
#     'marked_as_ads': 0,
#     'post_type': 'post',
#     'text': 'Мы решили не ждать курантов и поделиться музыкальными итогами 2020-го уже сейчас! Самым заметным артистом года стал [https://vk.com/artist/morgenshtern|MORGENSHTERN], а его записанная за неделю «ЛЕГЕНДАРНАЯ ПЫЛЬ» получает звание «Альбом года». Кроме того, трек Cadillac пользователи чаще всего добавляли в свои клипы ВКонтакте, так что MORGENSHTERN побеждает и в номинации «Хит года в Клипах». \n\nНастоящим прорывом оказался [https://vk.com/artist/slavamarlow|SLAVA MARLOW]: аудитория фрешмена росла быстрее всех. Он начинал как битмейкер, а когда начал работать сольно, пообещал записывать по треку каждый день в течение года. Мног
# %%
response.json()['response']['items'][0]
# Out:
# {'id': 1167538,
#  'from_id': -22822305,
#  'owner_id': -22822305,
#  'date': 1617262100,
#  'marked_as_ads': 0,
#  'post_type': 'post',
#  'text': '',
#  'copy_history': [{'id': 362,
#    'owner_id': 92933,
#    'from_id': 92933,
#    'date': 1617261054,
#    'post_type': 'post',
#    'text': 'Наша команда любит шутить на 1 апреля. Каждый год мы делаем на сайте или в приложении какие-нибудь забавные мелочи. В этот раз поднимем настроение абсолютно серьёзной новостью: спустя пять лет ВКонтакте обновляет приложение для iPad. Это не шутка! \n\nМы видели, с каким энтузиазмом многие ждали этого момента, ожидание даже стало мемом. И хотя планшетами пользуются несоизмеримо реже, чем смартфонами или ноутбуками, мы всегда учитываем отзывы и пожелания, которые получаем. Это помогает запускать действительно востребованные продукты. Обновлённое приложение поможет общаться и решать повседневные вопросы — будь то быт, работа или учёба — с любого устройства.\n\nВ прошлом году мы масштабно обновили приложение на смартфонах и запустили ВКонтакте больше двух сотен больших обновлений. Все они теперь доступны и на iPad. Например, «Клипы» — короткие вертикальные видео с AR-эффектами. Или бесплатные групповые звонки на 128 человек без ограничения по времени. А ещё — распознавание голосовых сообщений в мессенджере и обновлённые рекомендации в Музыке. На iPad работает и платформа сервисов — в том числе Такси ВКонтакте, Еда ВКонтакте и другие мини-приложения. \n\nЗа последний год ВКонтакте круто выросла и по аудитории, и по продуктовым показателям, и в плане технологий. За год количество пользователей в России увеличилось на 4,5% — нас уже 73,4 млн. Каждый день клипы смотрят 16 млн человек, каждый месяц голосовыми сообщениями обмениваются 33 млн человек, а общее число сообщений выросло на 50% — до 15 млрд в сутки. \n\nБудем радовать и другими долгожданными новинками — с такой сильной командой, уверена, для нас нет ничего невозможного.',
#    'attachments': [{'type': 'photo',
#      'photo': {'album_id': -7,
#       'date': 1617260986,
#       'id': 457239972,
#       'owner_id': 92933,
#       'has_tags': False,
#       'access_key': '7dfbea4574b4a5e907',
#       'sizes': [{'height': 122,
#         'url': 'https://sun9-68.userapi.com/impg/sP_-VfmKoESuwFkNrUTRixb48ZN6OOW-9MHa7A/X3AaTw43JV8.jpg?size=130x122&quality=96&sign=e3055748b784f08a0557a01a6b72937a&c_uniq_tag=DcsjOz8QHCPyGpEsM_K1pzqSqn_RKBS4kj-0cRPjtLg&type=album',
#         'type': 'm',
#         'width': 130},
#        {'height': 122,
#         'url': 'https://sun9-68.userapi.com/impg/sP_-VfmKoESuwFkNrUTRixb48ZN6OOW-9MHa7A/X3AaTw43JV8.jpg?size=130x122&quality=96&sign=e3055748b784f08a0557a01a6b72937a&c_uniq_tag=DcsjOz8QHCPyGpEsM_K1pzqSqn_RKBS4kj-0cRPjtLg&type=album',
#         'type': 'o',
#         'width': 130},
#        {'height': 188,
#         'url': 'https://sun9-68.userapi.com/impg/sP_-VfmKoESuwFkNrUTRixb48ZN6OOW-9MHa7A/X3AaTw43JV8.jpg?size=200x188&quality=96&sign=42077b5f06992a53ec8f958a58ad4996&c_uniq_tag=vYKwYUYnjnQwxC_1oiwN4QeKnPqbup-Bs6nxyYb4irI&type=album',
#         'type': 'p',
#         'width': 200},
#        {'height': 301,
#         'url': 'https://sun9-68.userapi.com/impg/sP_-VfmKoESuwFkNrUTRixb48ZN6OOW-9MHa7A/X3AaTw43JV8.jpg?size=320x300&quality=96&sign=d7b1efa5b628dcbffc633c486a4362a3&c_uniq_tag=W_4zmS8TVBBe40qsjMwHLMvEtSI9H7Hx8zL7PFm1VSA&type=album',
#         'type': 'q',
#         'width': 320},
#        {'height': 479,
#         'url': 'https://sun9-68.userapi.com/impg/sP_-VfmKoESuwFkNrUTRixb48ZN6OOW-9MHa7A/X3AaTw43JV8.jpg?size=510x479&quality=96&sign=353e7429a9c515b6910522d80149d468&c_uniq_tag=VArRU_QSFos9d_Twk3h7EyCgxTFdHFISW2Py2W5mm9k&type=album',
#         'type': 'r',
#         'width': 510},
#        {'height': 70,
#         'url': 'https://sun9-68.userapi.com/impg/sP_-VfmKoESuwFkNrUTRixb48ZN6OOW-9MHa7A/X3AaTw43JV8.jpg?size=75x70&quality=96&sign=be6908d112e28d36b6fbf4c0063bf6e2&c_uniq_tag=u5W7Cki6TpGuxBsMEm37o267tGPGltIB1TkWEsCHBRg&type=album',
#         'type': 's',
#         'width': 75},
#        {'height': 2160,
#         'url': 'https://sun9-68.userapi.com/impg/sP_-VfmKoESuwFkNrUTRixb48ZN6OOW-9MHa7A/X3AaTw43JV8.jpg?size=2301x2160&quality=96&sign=ed6438aa2151ae6919f9c381bb5765eb&c_uniq_tag=csICc-rKZdrPAC2yuOSGIOBUXbLeVAPRFTHqGO7sr6o&type=album',
#         'type': 'w',
#         'width': 2301},
#        {'height': 567,
#         'url': 'https://sun9-68.userapi.com/impg/sP_-VfmKoESuwFkNrUTRixb48ZN6OOW-9MHa7A/X3AaTw43JV8.jpg?size=604x567&quality=96&sign=1002edac7b996c136ecb725cb7155417&c_uniq_tag=o4qAvRJJ71verU3AaG1T41smTRp3EgY8p3xMMjd8ry0&type=album',
#         'type': 'x',
#         'width': 604},
#        {'height': 758,
#         'url': 'https://sun9-68.userapi.com/impg/sP_-VfmKoESuwFkNrUTRixb48ZN6OOW-9MHa7A/X3AaTw43JV8.jpg?size=807x758&quality=96&sign=e9c130a596e3f34d504a9dff3db04671&c_uniq_tag=zuqGZrbvRjlcO6GPElQe07gQ1ueTtihX8LonsFfNxBM&type=album',
#         'type': 'y',
#         'width': 807},
#        {'height': 1080,
#         'url': 'https://sun9-68.userapi.com/impg/sP_-VfmKoESuwFkNrUTRixb48ZN6OOW-9MHa7A/X3AaTw43JV8.jpg?size=1280x1202&quality=96&sign=998141a5f4962ccdfcab371d68d7d03c&c_uniq_tag=HwyiAJojcTU_q7Dkna1c8jmt-nHzhMxknwoptnbxZxU&type=album',
#         'type': 'z',
#         'width': 1150}],
#       'text': ''}}],
#    'post_source': {'type': 'vk'}}],
#  'post_source': {'type': 'vk'},
#  'comments': {'count': 1091, 'can_post': 1, 'groups_can_post': True},
#  'likes': {'count': 1607, 'user_likes': 0, 'can_like': 1, 'can_publish': 1},
#  'reposts': {'count': 564, 'user_reposted': 0},
#  'views': {'count': 576852}}

# %%
stats = {}  
              
for record in response.json()['response']['items'][:]:  
    title = record['text'][:30]  
    if title:  
        stats[title] = [record['comments']['count'], record['likes']['count'], record['reposts']['count'], record['date'] ]  
pprint(stats)
# Out:
# {'Благодаря форс-мажорному 2020-': [6115, 2758, 721, 1608903643],
#  'В наступающий год — со свежим ': [3251, 5066, 1766, 1608033618],
#  'В этом году у нас было много т': [268, 1862, 215, 1607943610],
#  'Вот уже четвёртый год мы подде': [3115, 4610, 727, 1608897114],
#  'Встречайте музыкальных куратор': [2098, 2750, 550, 1603796912],
#  'Мы решили не ждать курантов и ': [968, 2957, 266, 1607689227],
#  'Сообщества были и остаются одн': [768, 2330, 340, 1608105691],
#  'Что поможет найти лучший автос': [1133, 14052, 10647, 1608548489]}

# %% [markdown]
# **Задание 1 - SMM index**
#
# Напишите функцию get_smm_index(group_name, token), которая по имени группы и авторизационному токену API возвращает smm_index группы - сумму лайков, комментариев и репостов для последних 10 постов, поделённую на количество участников в группе.

# %%
def get_smm_index(group_name, token):
    url = 'https://api.vk.com/method/groups.getMembers'  
    params = {  
        'group_id': group_name,  
        'v': 5.95,  
        'access_token': token  
    }  
    response = requests.get(url, params=params)  
    data = response.json() 
    
    # Получим количество участников в группе
    group_members_count = data['response']['count']

    
    url = 'https://api.vk.com/method/wall.get'  
    params = {  
        'domain': group_name,  
        'filter': 'owner',  
        'count': 10,  
        'offset': 0,  
        'access_token': token,  
        'v': 5.95  
    }  
    response = requests.get(url, params=params)  
    response.json()
    
    # Посчитаем суммы лайков, репостов, комментариев
    comments_sum, likes_sum, reposts_sum = 0, 0, 0       
    for record in response.json()['response']['items'][:]:  
        comments_sum += record['comments']['count']
        likes_sum += record['likes']['count']
        reposts_sum += record['reposts']['count']
        
    #smm_index группы - сумму лайков, комментариев и репостов, поделённую на количество участников в группе.   
    smm_index = (comments_sum + likes_sum + reposts_sum) / group_members_count
    
    return smm_index

# %%
get_smm_index('vk', TOKEN)
# => 0.00337003
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-119-ac9e261e78fa> in <module>
# ----> 1 get_smm_index('vk', TOKEN)
#       2 # => 0.00337003
#
# <ipython-input-117-7d7c2c1c33d9> in get_smm_index(group_name, token)
#      10
#      11     # Получим количество участников в группе
# ---> 12     group_members_count = data['response']['count']
#      13
#      14
#
# KeyError: 'response'

# %% [markdown]
# # Возможности API
#
# Мы рассмотрели базовое взаимодействие с пользователями и группами. ВКонтакте предоставляет достаточно широкие возможности в своём API: по сути, всё, что можно делать руками через браузер, доступно и в API. Обратим внимание: если вы размещаете рекламу в Вконтакте, то можно выгружать всю статистику через ads API (https://vk.com/dev/ads).
#
# Полный список методов можно посмотреть в документации - https://vk.com/dev/methods
